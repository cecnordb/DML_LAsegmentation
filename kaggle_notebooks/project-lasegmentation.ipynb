# %% [markdown]
# ## Imports

# %%
import os
import io
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import SimpleITK as sitk
import imageio
from PIL import Image
from IPython.display import display, Image as IPImage

# %%
#!pip install nibabel
import nibabel as nib

# %% [markdown]
# ## Load & visualize data

# %%
# Visualize shape of one example file
example_img = sitk.ReadImage('/kaggle/input/la-segmentation/Task02_Heart/imagesTr/la_005.nii')
example_img = sitk.GetArrayFromImage(example_img)
example_label = sitk.ReadImage('/kaggle/input/la-segmentation/Task02_Heart/labelsTr/la_005.nii')
example_label = sitk.GetArrayFromImage(example_label)

print(f"Image shape: {example_img.shape}")
# Shape will be (slices, height, width)
# Images are (n,320,320) where number of slices (n) differs

# %%
def overlay_segmentation(img, label, transparency=0.3, color=(1, 0, 0)):
    """
    img: Original image (grayscale)
    label: Segmentation label (binary)
    transparency: Transparency factor (0: fully transparent, 1: fully opaque)
    color: Color of overlay, RGB tuple
    """
    img = img / img.max()  # Normalize the image
    img_aux = img.copy()

    overlay_image = np.stack((img, img, img), axis=-1)

    # Define color of overlay
    color_mask = np.zeros_like(overlay_image)
    for i in range(3):
        color_mask[..., i] = color[i]  
    
    # Apply transparency to overlay
    overlay_image[label == 1] = (1 - transparency) * overlay_image[label == 1] + transparency * color_mask[label == 1]

    return overlay_image

def display_slice(slice_index, example_img, example_label, transparency=0.3, color=(1,0,0)):
    # Extract the MRI image and label for the given slice index
    slice_img = example_img[slice_index, :, :] 
    flipped_slice_img = np.flip(slice_img, axis=(0, 1))  # Flip both vertically and horizontally

    slice_label = example_label[slice_index, :, :] 
    flipped_slice_label = np.flip(slice_label, axis=(0, 1))  # Flip both vertically and horizontally

    # Overlay the segmentation mask on the MRI image with transparency
    overlay = overlay_segmentation(flipped_slice_img, flipped_slice_label, transparency=transparency, color=color)

    fig, axes = plt.subplots(1, 3, figsize=(15, 6))  
    axes[0].imshow(flipped_slice_img, cmap='gray')
    axes[0].set_title(f'Image (slice: {slice_index})')
    axes[0].axis('off')

    axes[1].imshow(flipped_slice_label, cmap='gray')
    axes[1].set_title(f'Label (slice: {slice_index})')
    axes[1].axis('off')

    axes[2].imshow(overlay)
    axes[2].set_title(f'Segmentation overlay (slice: {slice_index})')
    axes[2].axis('off')

    plt.show()

mid_slice = example_img.shape[0] // 2 
display_slice(mid_slice, example_img, example_label, transparency=0.3, color=(1,0,0))

# %%
def create_gif(image_path, gif_filename='image.gif', duration=0.05, save=False):
    """
    Creates a GIF from all slices of a 3D medical image.
    
    Parameters:
    - image_path: str, path to the 3D image file (.nii format)
    - gif_filename: str, name of the output GIF file
    - duration: float, duration (in seconds) between each frame in the GIF
    """
    # Load the 3D image
    example_img = sitk.ReadImage(image_path)
    example_img = sitk.GetArrayFromImage(example_img)

    # Get the number of slices (shape is (slices, height, width))
    num_slices = example_img.shape[0]

    # Create a list to store frames
    frames = []

    # Loop through each slice and save as an image
    for i in range(num_slices):
        slice_img = example_img[i, :, :]
        slice_img = np.flip(slice_img, axis=(0, 1)) #Flip both vertically and horizontally

        # Normalize the slice for visualization (convert to range 0-255)
        slice_img = (slice_img - np.min(slice_img)) / (np.max(slice_img) - np.min(slice_img)) * 255
        slice_img = slice_img.astype(np.uint8)

        # Convert the numpy array to a PIL Image and append to frames
        pil_img = Image.fromarray(slice_img)
        frames.append(pil_img)

    # Create the GIF in memory
    gif_bytes = io.BytesIO()
    frames[0].save(gif_bytes, format='GIF', save_all=True, append_images=frames[1:], duration=duration*1000, loop=0)
    gif_bytes.seek(0)
    
    # Save the GIF locally if requested
    if save:
        with open(gif_filename, 'wb') as f:
            f.write(gif_bytes.getvalue())
        print(f"GIF saved as {gif_filename}")

    return gif_bytes


def display_gif(gif_bytes):
    """
    Displays a GIF from a BytesIO object in Jupyter Notebooks or IPython environments.
    
    Parameters:
    - gif_bytes: BytesIO object containing GIF data
    """ 
    
    display(IPImage(gif_bytes.getvalue()))

# %%
gif_data = create_gif('/kaggle/input/la-segmentation/Task02_Heart/imagesTr/la_005.nii', 'heart_slices.gif', duration=0.07, save=False)
display_gif(gif_data)

# %%
# Full TRAIN data visualization
train_path = '/kaggle/input/la-segmentation/Task02_Heart/imagesTr/'
train_files = [f for f in os.listdir(train_path) if f.endswith('.nii')]

train_images = []
train_names = []  
for file_name in train_files:
    image_path = os.path.join(train_path, file_name)
    img = sitk.ReadImage(image_path)
    img_array = sitk.GetArrayFromImage(img)
    
    slice_idx = img_array.shape[0] // 2  # Middle slice
    img_slice = img_array[slice_idx]
    img_slice = np.flip(img_slice, axis=(0, 1)) #Flip both vertically and horizontally
    img_slice_normalized = (img_slice - np.min(img_slice)) / (np.max(img_slice) - np.min(img_slice))
    train_images.append(img_slice_normalized)
    train_names.append(file_name)

fig, axes = plt.subplots(3, 5, figsize=(13, 9))

for i, ax in enumerate(axes.flat):
    ax.imshow(train_images[i], cmap='gray')
    ax.axis('off')  
    ax.set_title(train_names[i], fontsize=10)  

plt.subplots_adjust(wspace=0.01, hspace=0.01) 
plt.show()

# %%
# Full TEST data visualization
test_path = '/kaggle/input/la-segmentation/Task02_Heart/imagesTs/'
test_files = [f for f in os.listdir(test_path) if f.endswith('.nii')]

test_images = []
test_names = []  
for file_name in test_files:
    image_path = os.path.join(test_path, file_name)
    img = sitk.ReadImage(image_path)
    img_array = sitk.GetArrayFromImage(img)
    
    slice_idx = img_array.shape[0] // 2  # Middle slice
    img_slice = img_array[slice_idx]
    img_slice = np.flip(img_slice, axis=(0, 1)) #Flip both vertically and horizontally
    img_slice_normalized = (img_slice - np.min(img_slice)) / (np.max(img_slice) - np.min(img_slice))
    test_images.append(img_slice_normalized)
    test_names.append(file_name)

fig, axes = plt.subplots(2, 5, figsize=(13, 6))

for i, ax in enumerate(axes.flat):
    ax.imshow(test_images[i], cmap='gray')
    ax.axis('off')  
    ax.set_title(test_names[i], fontsize=10)  

plt.subplots_adjust(wspace=0.01, hspace=0.01) 
plt.show()

# %% [markdown]
# ## Dataset + preprocessing / augmentation

# %% [markdown]
# Rotating, Gaussian blur, normalization per patient (over full volume), crop image to remove deadspace
# Flipping doesn not have a great effect on tumor segmentation
#
# **Tips for training 3d-UNet:**
# * Before training make sure that the data you want to train is normalized and resized for the model.
# * Main purpose of normalization is to make computation efficient by reducing values between 0 to 1 as well as removing noise in data.
# * Images used for medical image segmentation are high-resolution three-dimensional (3D) images. To reduce the memory usage on GPU’s, we can use a patch-based method, which divides a large image into small patches and trains the models with these small patches.
#
# **TODO:**
# * Bestäm ett rimligt område för crop baserat på visualisering av bilder

# %%
import sys

scripts_dir = '/kaggle/input/scripts/other/default/1'
#print(os.listdir(scripts_dir)) - Files in dir
sys.path.append(scripts_dir)

#from train import train, validate, patched_forward
#from utils import CombinedLoss

# %%
import glob

# Load images in directories 
data_dir = "/kaggle/input/la-segmentation/Task02_Heart"

train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTr", "*.nii")))
train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTr", "*.nii")))
train_data_dict = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]

val_images = sorted(glob.glob(os.path.join(data_dir, "imagesVl", "*.nii")))
val_labels = sorted(glob.glob(os.path.join(data_dir, "labelsVl", "*.nii")))
val_data_dict = [{"image": image_name, "label": label_name} for image_name, label_name in zip(val_images, val_labels)]

# Display first image and label in train dict
train_data_dict[15]
# Out:
# {'image': '/kaggle/input/la-segmentation/Task02_Heart/imagesTr/la_023.nii',
#  'label': '/kaggle/input/la-segmentation/Task02_Heart/labelsTr/la_023.nii'}

# %% [markdown]
# ### Transforms

# %%
# !pip install monai
# Out:
# Requirement already satisfied: monai in /opt/conda/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.24 in /opt/conda/lib/python3.10/site-packages (from monai) (1.26.4)
# Requirement already satisfied: torch>=1.9 in /opt/conda/lib/python3.10/site-packages (from monai) (2.4.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9->monai) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9->monai) (1.3.0)

# %%
# TODO, take slice index as input
from monai.transforms import Rotated, RandRotated, RandZoomd, RandAffined, RandGaussianNoised, RandGaussianSmoothd

def visualize_transform(data_dict, img_idx=0, transform=None):
    image, label = data_dict[img_idx]["image"], data_dict[img_idx]["label"]
    
    image_array = sitk.GetArrayFromImage(sitk.ReadImage(image))
    label_array = sitk.GetArrayFromImage(sitk.ReadImage(label))
    
    data = {"image": image_array, "label": label_array}
    
    # Apply transform if provided
    if transform:
        transformed = transform(data)
        image_array, label_array = transformed["image"], transformed["label"]

    mid_slice = image_array.shape[0] // 2
    slice_img = image_array[mid_slice, :, :] 
    slice_label = label_array[mid_slice, :, :] 
    flipped_slice_img = np.flip(slice_img, axis=(0, 1))
    flipped_slice_label = np.flip(slice_label, axis=(0, 1))

    fig, axes = plt.subplots(1, 2, figsize=(6, 3))  
    axes[0].imshow(flipped_slice_img, cmap='gray')
    axes[0].set_title(f'Transformed image (slice: {mid_slice})')
    axes[0].axis('off')

    axes[1].imshow(flipped_slice_label, cmap='gray')
    axes[1].set_title(f'Transformed label (slice: {mid_slice})')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()

# TODO - FIX multiple transforms
#transform = Rotated(keys=["image","label"], angle=0.2, mode=["bilinear", "nearest"])
transform = RandRotated(keys=["image","label"], prob=0.4, range_x=[-0.3, 0.3], mode=["bilinear", "nearest"])
#transform = RandZoomd(keys=["image","label"], prob=0.4, min_zoom=1.1, max_zoom=1.5, mode=["area", "nearest"])
#transform =RandAffined(keys=["image","label"], prob=0.5, shear_range=(0.4,0.4), mode=["bilinear", "nearest"],padding_mode="zeros")
#transform = RandGaussianNoised(keys=["image"], prob=0.9, mean=0, std=0.1)
#transform = RandGaussianSmoothd(keys="image",prob=1.0, sigma_x=(0,3))
visualize_transform(train_data_dict, img_idx=0, transform=transform)

# %% [markdown]
# ### Dataset and loader

# %%
import torch
from glob import glob
from torch.utils.data import Dataset
import SimpleITK as sitk
import numpy as np

class TrainDataset(Dataset): 
    """
    require_target = True => all returned patches contain atleast some of the target
    preoad_all_images = True => all images are loaded into memory at the start
    """

    def __init__(self, data_dir, labels_dir, patch_size, require_target=False,transform=None, preload_all_images=True, num_patches_per_image=1):
        self.patch_size = patch_size
        self.transform = transform
        self.require_target = require_target
        
        self.data_paths = sorted(glob(data_dir + '/*.nii'))
        self.label_paths = sorted(glob(labels_dir + '/*.nii'))

        self.preload_all_images = preload_all_images
        if preload_all_images:
            self.data = {path_: sitk.GetArrayFromImage(sitk.ReadImage(path_)).astype('float32') for path_ in self.data_paths}
            self.labels = {path_: sitk.GetArrayFromImage(sitk.ReadImage(path_)).astype('int64') for path_ in self.label_paths}

        self.num_patches_per_image = num_patches_per_image

    def __len__(self):
        return len(self.data_paths)
    
    def __getitem__(self, idx):
        if self.preload_all_images:
            image_np = self.data[self.data_paths[idx]]
            label_np = self.labels[self.label_paths[idx]]
        else:
            image  = sitk.ReadImage(self.data_paths[idx])
            label = sitk.ReadImage(self.label_paths[idx])

            image_np = sitk.GetArrayFromImage(image).astype('float32')
            label_np = sitk.GetArrayFromImage(label).astype('int64')

        patches = []
        labels = []
        for _ in range(self.num_patches_per_image):
            if self.require_target:
                image_patch, label_patch = self.random_crop_3d_target(image_np, label_np, self.patch_size)
            else:
                image_patch, label_patch = self.random_crop_3d(image_np, label_np, self.patch_size)
            
            if self.transform:
                array_data = {"image_patch": image_patch, "label_patch": label_patch}
                transformed = self.transform(array_data)
                image_patch, label_patch = transformed["image_patch"], transformed["label_patch"]
                
            image_tensor = torch.as_tensor(image_patch, dtype=torch.float32).unsqueeze(0)
            label_tensor = torch.as_tensor(label_patch, dtype=torch.float32)
            patches.append(image_tensor)
            labels.append(label_tensor)

        return torch.stack(patches, dim=0), torch.stack(labels, dim=0)
    
    def random_crop_3d(self, image, label, patch_size):
        z, y, x = image.shape
        pz, py, px = patch_size
        sz = torch.randint(0, z - pz, (1,)).item()
        sy = torch.randint(0, y - py, (1,)).item()
        sx = torch.randint(0, x - px, (1,)).item()
        return image[sz:sz+pz, sy:sy+py, sx:sx+px], label[sz:sz+pz, sy:sy+py, sx:sx+px]
    
    def random_crop_3d_target(self, image, label, patch_size):
        z, y, x = image.shape
        pz, py, px = patch_size
        
        ones_indices = np.argwhere(label)
        z_min, y_min, x_min = ones_indices.min(axis=0)
        z_max, y_max, x_max = ones_indices.max(axis=0)

        z_patch_min, y_patch_min, x_patch_min = max(0, z_min - pz), max(0, y_min - py), max(0, x_min - px)
        z_patch_max, y_patch_max, x_patch_max = min(z - pz, z_max), min(y - py, y_max), min(x - px, x_max)

        sz = torch.randint(z_patch_min, z_patch_max + 1, (1,)).item()
        sy = torch.randint(y_patch_min, y_patch_max + 1, (1,)).item()
        sx = torch.randint(x_patch_min, x_patch_max + 1, (1,)).item()

        return image[sz:sz+pz, sy:sy+py, sx:sx+px], label[sz:sz+pz, sy:sy+py, sx:sx+px]

        
class TestDataset(Dataset): 
    """
    Test dataset loads the entire image 
    """
    def __init__(self, data_dir, labels_dir=None, transform=None):
        self.transform = transform
        
        self.data_paths = sorted(glob(data_dir + '/*'))
        self.label_paths = sorted(glob(labels_dir + '/*')) if labels_dir is not None else None

    def __len__(self):
        return len(self.data_paths)
    
    def __getitem__(self, index):
        image = sitk.ReadImage(self.data_paths[index])
        image_np = sitk.GetArrayFromImage(image).astype('float32')

        if self.label_paths is not None:
            label = sitk.ReadImage(self.label_paths[index])
            label_np = sitk.GetArrayFromImage(label).astype('int64')
        else:
            label_np = None
        
        #if self.transform:
        #    image_np = self.transform(image_np)

        image_tensor = torch.tensor(image_np, dtype=torch.float32).unsqueeze(0)

        if label_np is not None:
            label_tensor = torch.tensor(label_np, dtype=torch.int64)
            return image_tensor, label_tensor
        else:
            return image_tensor

# %%
patch_size = (64, 128, 128)
transform = RandRotated(keys=["image","label"], prob=0.5, range_x=[-0.3, 0.3], mode=["bilinear", "nearest"])
#transform =RandAffined(keys=["image_patch","label_patch"], prob=1.0, shear_range=(0.3,0.3), mode=["bilinear", "nearest"],padding_mode="zeros")
#transform = RandZoomd(keys=["image_patch","label_patch"], prob=0.4, min_zoom=1.1, max_zoom=1.5, mode=["area", "nearest"])
transform = None

train_image_path = '/kaggle/input/la-segmentation/Task02_Heart/imagesTr'
train_label_path = '/kaggle/input/la-segmentation/Task02_Heart/labelsTr'
val_image_path = '/kaggle/input/la-segmentation/Task02_Heart/imagesVl'
val_label_path = '/kaggle/input/la-segmentation/Task02_Heart/labelsVl'

train_dataset = TrainDataset(train_image_path, train_label_path, patch_size, require_target=True, transform=transform, preload_all_images=True, num_patches_per_image=2)
val_dataset = TestDataset(val_image_path, val_label_path)

batch_size = 2
# The effective batch size will be batch_size * num_patches_per_image
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=2)

# %%
'''
import torch
from glob import glob
from torch.utils.data import Dataset
import SimpleITK as sitk
import numpy as np

class TrainDataset(Dataset): 
    """
    require_target = True => all returned patches contain atleast some of the target
    preoad_all_images = True => all images are loaded into memory at the start
    """

    def __init__(self, train_dict, patch_size, require_target=False,transform=None, preload_all_images=True, num_patches_per_image=1):
        self.patch_size = patch_size
        self.transform = transform
        self.require_target = require_target
        
        self.train_images = [item["image"] for item in train_dict]
        self.train_labels = [item["label"] for item in train_dict]

        self.preload_all_images = preload_all_images
        if preload_all_images:
            self.data = {path_: sitk.GetArrayFromImage(sitk.ReadImage(path_)).astype('float32') for path_ in self.train_images}
            self.labels = {path_: sitk.GetArrayFromImage(sitk.ReadImage(path_)).astype('int64') for path_ in self.train_labels}

        self.num_patches_per_image = num_patches_per_image

    def __len__(self):
        return len(self.train_images)
    
    def __getitem__(self, idx):
        if self.preload_all_images:
            image_np = self.data[self.train_images[idx]]
            label_np = self.labels[self.train_labels[idx]]
        else:
            image = sitk.ReadImage(self.train_images[idx])
            label = sitk.ReadImage(self.train_labels[idx])

            image_np = sitk.GetArrayFromImage(image).astype('float32')
            label_np = sitk.GetArrayFromImage(label).astype('int64')
            
        array_data = {"image": image_np, "label": label_np}
    
        # Apply transform if provided
        if self.transform: 
            transformed = self.transform(array_data)
            image_np, label_np = transformed["image"], transformed["label"]

        patches = []
        labels = []
        for _ in range(self.num_patches_per_image):
            if self.require_target:
                image_patch, label_patch = self.random_crop_3d_target(image_np, label_np, self.patch_size)
            else:
                image_patch, label_patch = self.random_crop_3d(image_np, label_np, self.patch_size)

            image_tensor = torch.as_tensor(image_patch, dtype=torch.float32).unsqueeze(0)
            label_tensor = torch.as_tensor(label_patch, dtype=torch.float32)

            patches.append(image_tensor)
            labels.append(label_tensor)

        return torch.stack(patches, dim=0), torch.stack(labels, dim=0)
    
    def random_crop_3d(self, image, label, patch_size):
        z, y, x = image.shape
        pz, py, px = patch_size
        sz = torch.randint(0, z - pz, (1,)).item()
        sy = torch.randint(0, y - py, (1,)).item()
        sx = torch.randint(0, x - px, (1,)).item()
        return image[sz:sz+pz, sy:sy+py, sx:sx+px], label[sz:sz+pz, sy:sy+py, sx:sx+px]
    
    def random_crop_3d_target(self, image, label, patch_size):
        z, y, x = image.shape
        pz, py, px = patch_size
        
        ones_indices = np.argwhere(label)
        z_min, y_min, x_min = ones_indices.min(axis=0)
        z_max, y_max, x_max = ones_indices.max(axis=0)

        z_patch_min, y_patch_min, x_patch_min = max(0, z_min - pz), max(0, y_min - py), max(0, x_min - px)
        z_patch_max, y_patch_max, x_patch_max = min(z - pz, z_max), min(y - py, y_max), min(x - px, x_max)

        sz = torch.randint(z_patch_min, z_patch_max + 1, (1,)).item()
        sy = torch.randint(y_patch_min, y_patch_max + 1, (1,)).item()
        sx = torch.randint(x_patch_min, x_patch_max + 1, (1,)).item()

        return image[sz:sz+pz, sy:sy+py, sx:sx+px], label[sz:sz+pz, sy:sy+py, sx:sx+px]


    
class TestDataset(Dataset): 
    """
    Test dataset loads the entire image from a predefined dictionary.
    """
    def __init__(self, test_dict, transform=None):
        self.transform = transform
        
        # Extract images and labels from the dictionary
        self.test_images = [item["image"] for item in test_dict]
        self.test_labels = [item.get("label") for item in test_dict] if "label" in test_dict[0] else None

    def __len__(self):
        return len(self.test_images)
    
    def __getitem__(self, index):
        image = sitk.ReadImage(self.test_images[index])
        image_np = sitk.GetArrayFromImage(image).astype('float32')

        # Check if labels are available
        if self.test_labels is not None:
            label = sitk.ReadImage(self.test_labels[index])
            label_np = sitk.GetArrayFromImage(label).astype('int64')
        else:
            label_np = None
        
        # Apply transformations if provided
        #if self.transform:
        #    image_np = self.transform(image_np)

        # Convert to tensor and add channel dimension
        image_tensor = torch.tensor(image_np, dtype=torch.float32).unsqueeze(0)

        # Return image and label tensors, or only image if label is None
        if label_np is not None:
            label_tensor = torch.tensor(label_np, dtype=torch.int64)
            return image_tensor, label_tensor
        else:
            return image_tensor
'''

# %%
'''
patch_size = (64, 64, 64)
#transform = RandRotated(keys=["image","label"], prob=0.5, range_x=[-0.3, 0.3], mode=["bilinear", "nearest"])
transform =RandAffined(keys=["image","label"], prob=0.9, shear_range=(0.4,0.4), mode=["bilinear", "nearest"],padding_mode="zeros")
#transform = RandZoomd(keys=["image","label"], prob=0.4, min_zoom=1.1, max_zoom=1.5, mode=["area", "nearest"])

train_dataset = TrainDataset(train_data_dict, patch_size, require_target=True, transform=transform, preload_all_images=True, num_patches_per_image=2)
val_dataset = TestDataset(val_data_dict)

batch_size = 7
# The effective batch size will be batch_size * num_patches_per_image
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=2)
'''

# %%
'''#from dataset import TrainDataset, TestDataset
import torch

train_image_path = '/kaggle/input/task2-heart/Task02_Heart/Task02_Heart/imagesTr'
train_label_path = '/kaggle/input/task2-heart/Task02_Heart/Task02_Heart/labelsTr'
val_image_path = '/kaggle/input/task2-heart/Task02_Heart/Task02_Heart/imagesVl'
val_label_path ='/kaggle/input/task2-heart/Task02_Heart/Task02_Heart/labelsVl'

transform = None
patch_size = (64, 64, 64)
train_dataset = TrainDataset(train_image_path, train_label_path, patch_size, require_target=True, transform=transform, preload_all_images=True, num_patches_per_image=2)
val_dataset = TestDataset(val_image_path, val_label_path)

batch_size = 7
# The effective batch size will be batch_size * num_patches_per_image
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=2)

'''

# %% [markdown]
# ## Utils

# %%
import torch.nn as nn
import torch

def dice_coefficient(pred, target, smooth=1.):
    pred = pred > 0.5  # Thresholding to get binary predictions
    intersection = (pred * target).sum()
    return (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

def soft_dice_coefficient(pred, target, smooth=1.):
    intersection = (pred * target).sum()
    return (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

def soft_dice_loss(pred, target, smooth=1.):
    return 1 - soft_dice_coefficient(pred, target, smooth)

def soft_iou(pred, target, smooth=1e-6):
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection
    return (intersection + smooth) / (union + smooth)

def iou(pred, target, smooth=1e-6):
    pred = pred > 0.5  # Thresholding to get binary predictions
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection
    return (intersection + smooth) / (union + smooth)

class CombinedLoss(nn.Module):
    """
    Expects logit inputs
    """

    def __init__(self, smooth=1):
        super(CombinedLoss, self).__init__()
        self.bce_loss = nn.BCEWithLogitsLoss()
        self.smooth = smooth

    def forward(self, outputs, targets):
        ce_loss = self.bce_loss(outputs, targets)
        dice = soft_dice_loss(torch.sigmoid(outputs), targets, self.smooth)
        return ce_loss + dice

# %% [markdown]
# ## Model architecture (3D-UNet)

# %% [markdown]
# **Tips for training 3D-UNet:**
# * For all layers except the last layer, RelU or eLU can be a good choice of activation function. How ever since segmentation is a pixelwise classification problem, softmax would be an ideal choice for the output layer.
# * In semantic segmentation, especially that involves medical images, the usual choice is Dice similarity coefficient. The dice coefficient scores are in the range of 0 to 1 where 1 means that predicted image and groundtruth overlaps perfectly.
# * We can use a higher learning rate to start the training when we use a learning rate scheduler. This can help in faster convergence in a controlled manner.

# %%
import sys

unet_model = '/kaggle/input/unet/pytorch/default/1/'
sys.path.append(unet_model)

from unet import UNet3D, MultiConv3d

# %% [markdown]
# ## Training of model

# %%
from collections import defaultdict
from time import time
#from utils import iou, dice_coefficient
import torch
import torch.nn.functional as F

def train_epoch(model, optimizer, loss_fn, train_loader, scheduler, device):
    model.train()
    train_loss = AccumulatingMetric()
    train_iou = AccumulatingMetric()
    train_dice = AccumulatingMetric()
    for batch in train_loader:
        input, target = batch
        # Concatenate the patches along the batch dimension
        input = input.view(-1, *input.shape[2:])
        target = target.view(-1, *target.shape[2:])

        input, target = input.to(device), target.to(device).float()
        optimizer.zero_grad()
        pred_logits = model(input)
        pred_logits = pred_logits.squeeze(1)
        loss = loss_fn(pred_logits, target)
        loss.backward()
        optimizer.step()
        if scheduler is not None:
            scheduler.step()
        pred = torch.sigmoid(pred_logits)
        train_loss.add(loss.item())
        train_iou.add(iou(pred, target).cpu().item())
        train_dice.add(dice_coefficient(pred, target).cpu().item())

    return train_loss.avg(), train_iou.avg(), train_dice.avg()

def validate(model, loss_fn, val_loader, device, patch_size):
    model.eval()
    validation_loss = AccumulatingMetric()
    validation_iou = AccumulatingMetric()
    validation_dice = AccumulatingMetric()
    
    for batch in val_loader:
        # Here I need to separate the input into patches and then merge them after they have all been analyzed. Should I do this with overlap? Yes I should.
        input, target = batch
        input, target = input.to(device), target.to(device).float()
        with torch.no_grad():
            pred_logits = patched_forward(model, input, patch_size, device)
        pred_logits = pred_logits.squeeze(1)
        pred = torch.sigmoid(pred_logits)
        # Calculate the loss, iou and dice coefficient
        loss = loss_fn(pred_logits, target)

        validation_loss.add(loss.item())
        validation_iou.add(iou(pred, target).cpu().item())
        validation_dice.add(dice_coefficient(pred, target).cpu().item())
        
    return validation_loss.avg(), validation_iou.avg(), validation_dice.avg() 

def patched_forward(model, input, patch_size, device, overlap=0.5):
    # This function will take an input image and split it into patches, then run the model on each patch and merge the results.
    batch_size, channels, z, y, x = input.shape
    pz, py, px = patch_size
    stride_z, stride_y, stride_x = int(pz * (1 - overlap)), int(py * (1 - overlap)), int(px * (1 - overlap))

    # Calculate needed padding
    pad_z = (pz - z % pz) if z % pz != 0 else 0
    pad_y = (py - y % py) if y % py != 0 else 0
    pad_x = (px - x % px) if x % px != 0 else 0
    input_padded = F.pad(input, (0, pad_x, 0, pad_y, 0, pad_z))
    padded_z, padded_y, padded_x = input_padded.shape[2:]

    output = torch.zeros((batch_size, channels, padded_z, padded_y, padded_x)).to(device)
    weight_map = torch.zeros((batch_size, channels, padded_z, padded_y, padded_x)).to(device)

    for z_start in range(0, padded_z - pz + 1, stride_z):
        for y_start in range(0, padded_y - py + 1, stride_y):
            for x_start in range(0, padded_x - px + 1, stride_x):
                z_end, y_end, x_end = z_start + pz, y_start + py, x_start + px
                
                patch = input_padded[:, :, z_start:z_end, y_start:y_end, x_start:x_end]
                patch_output = model(patch)
                # Add the output of the patch to the combined output
                output[:, :, z_start:z_end, y_start:y_end, x_start:x_end] += patch_output

                # Keep track of how many values has been added to each region so that we can average them later
                weight_map[:, :, z_start:z_end, y_start:y_end, x_start:x_end] += 1

    # Avoid division by zero in case some areas are not covered by patches
    weight_map = torch.where(weight_map == 0, torch.ones_like(weight_map), weight_map)

    output /= weight_map

    # Remove padding
    output = output[:, :, :z, :y, :x]
    return output


def train(model, optimizer, loss_fn, train_loader, val_loader, scheduler, device, epochs, patch_size, validation_freq=1):
    print(f"Starting training on device {device}...")
    model.to(device)
    train_metrics = defaultdict(list)
    val_metrics = defaultdict(list)

    best_val_loss = float('inf')  # To store the best validation loss
    best_model_state = None       # To store the best model state

    for epoch in range(epochs):
        start_time = time()
        # Training step
        train_loss, train_iou, train_dice = train_epoch(model, optimizer, loss_fn, train_loader, scheduler, device)
        train_metrics["loss"].append(train_loss)
        train_metrics["iou"].append(train_iou)
        train_metrics["dice"].append(train_dice)
        print(f"Epoch {epoch + 1} of {epochs} took {time() - start_time:.2f}s | Training: loss={train_loss:.4f}, iou={train_iou:.4f}, dice={train_dice:.4f}")
    
        # Validation step
        if epoch % validation_freq == validation_freq - 1 or epoch == epochs - 1:
            val_loss, val_iou, val_dice = validate(model, loss_fn, val_loader, device, patch_size)
            val_metrics["loss"].append(val_loss)
            val_metrics["iou"].append(val_iou)
            val_metrics["dice"].append(val_dice)
            print(f"Validation: loss={val_loss:.4f}, iou={val_iou:.4f}, dice={val_dice:.4f}") 

            # Save the best model based on validation loss
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state = model.state_dict()  # Save the model state
                print(f"New best model found with validation loss {val_loss:.4f}, saving model...")

    model.load_state_dict(best_model_state)
    return model, train_metrics, val_metrics


class AccumulatingMetric:
    """Accumulate samples of a metric and automatically keep track of the number of samples."""

    def __init__(self):
        self.metric = 0.0
        self.counter = 0

    def add(self, value):
        self.metric += value
        self.counter += 1

    def avg(self):
        return self.metric / self.counter

# %%
model = UNet3D(in_channels=1, out_channels=1, features=[32, 64, 128, 256])
loss_fn = CombinedLoss(smooth=1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

epochs = 1000
validation_freq = 20

results_train = train(model, optimizer, loss_fn, train_loader, val_loader, None, 
                device, epochs, patch_size=patch_size, validation_freq=validation_freq)
# Out:
# Starting training on device cuda...
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1 of 1000 took 10.48s | Training: loss=1.5584, iou=0.0619, dice=0.1133
# Epoch 2 of 1000 took 9.80s | Training: loss=1.4923, iou=0.1410, dice=0.2451
# Epoch 3 of 1000 took 9.81s | Training: loss=1.4565, iou=0.1866, dice=0.3084
# Epoch 4 of 1000 took 9.83s | Training: loss=1.4148, iou=0.2786, dice=0.4310
# Epoch 5 of 1000 took 9.86s | Training: loss=1.3898, iou=0.3482, dice=0.5053
# Epoch 6 of 1000 took 9.82s | Training: loss=1.3578, iou=0.4365, dice=0.6005
# Epoch 7 of 1000 took 9.86s | Training: loss=1.3362, iou=0.4746, dice=0.6158
# Epoch 8 of 1000 took 9.88s | Training: loss=1.3045, iou=0.6074, dice=0.7538
# Epoch 9 of 1000 took 10.02s | Training: loss=1.3065, iou=0.5236, dice=0.6758
# Epoch 10 of 1000 took 9.79s | Training: loss=1.2960, iou=0.5951, dice=0.7428
# Epoch 11 of 1000 took 9.86s | Training: loss=1.2921, iou=0.6184, dice=0.7575
# Epoch 12 of 1000 took 9.86s | Training: loss=1.2957, iou=0.5571, dice=0.6963
# Epoch 13 of 1000 took 9.79s | Training: loss=1.2694, iou=0.5832, dice=0.7303
# Epoch 14 of 1000 took 9.83s | Training: loss=1.2805, iou=0.6150, dice=0.7583
# Epoch 15 of 1000 took 9.84s | Training: loss=1.2752, iou=0.5732, dice=0.7211
# Epoch 16 of 1000 took 9.82s | Training: loss=1.2634, iou=0.6671, dice=0.7972
# Epoch 17 of 1000 took 9.81s | Training: loss=1.2650, iou=0.6343, dice=0.7665
# Epoch 18 of 1000 took 9.79s | Training: loss=1.2459, iou=0.6610, dice=0.7902
# Epoch 19 of 1000 took 9.81s | Training: loss=1.2524, iou=0.7181, dice=0.8341
# Epoch 20 of 1000 took 9.82s | Training: loss=1.2578, iou=0.6553, dice=0.7857
# Validation: loss=1.3480, iou=0.7680, dice=0.8641
# New best model found with validation loss 1.3480, saving model...
# Epoch 21 of 1000 took 9.81s | Training: loss=1.2737, iou=0.6313, dice=0.7563
# Epoch 22 of 1000 took 9.79s | Training: loss=1.2343, iou=0.7491, dice=0.8531
# Epoch 23 of 1000 took 9.78s | Training: loss=1.2397, iou=0.7040, dice=0.8246
# Epoch 24 of 1000 took 9.86s | Training: loss=1.2297, iou=0.7260, dice=0.8377
# Epoch 25 of 1000 took 9.81s | Training: loss=1.2154, iou=0.6781, dice=0.7809
# Epoch 26 of 1000 took 9.81s | Training: loss=1.2231, iou=0.7341, dice=0.8420
# Epoch 27 of 1000 took 9.79s | Training: loss=1.2439, iou=0.6183, dice=0.7507
# Epoch 28 of 1000 took 9.82s | Training: loss=1.2362, iou=0.7518, dice=0.8554
# Epoch 29 of 1000 took 9.81s | Training: loss=1.2312, iou=0.6447, dice=0.7793
# Epoch 30 of 1000 took 9.82s | Training: loss=1.2143, iou=0.7070, dice=0.8228
# Epoch 31 of 1000 took 9.83s | Training: loss=1.2200, iou=0.6675, dice=0.7914
# Epoch 32 of 1000 took 9.79s | Training: loss=1.1921, iou=0.7019, dice=0.8210
# Epoch 33 of 1000 took 9.87s | Training: loss=1.1779, iou=0.7305, dice=0.8427
# Epoch 34 of 1000 took 9.80s | Training: loss=1.1842, iou=0.7473, dice=0.8521
# Epoch 35 of 1000 took 9.84s | Training: loss=1.1822, iou=0.7489, dice=0.8553
# Epoch 36 of 1000 took 9.87s | Training: loss=1.1643, iou=0.7461, dice=0.8507
# Epoch 37 of 1000 took 9.86s | Training: loss=1.1770, iou=0.7256, dice=0.8349
# Epoch 38 of 1000 took 9.87s | Training: loss=1.1566, iou=0.7843, dice=0.8783
# Epoch 39 of 1000 took 9.83s | Training: loss=1.1746, iou=0.7219, dice=0.8364
# Epoch 40 of 1000 took 9.84s | Training: loss=1.1796, iou=0.7706, dice=0.8696
# Validation: loss=1.2762, iou=0.7085, dice=0.8285
# New best model found with validation loss 1.2762, saving model...
# Epoch 41 of 1000 took 9.82s | Training: loss=1.1955, iou=0.7092, dice=0.8272
# Epoch 42 of 1000 took 9.80s | Training: loss=1.1616, iou=0.7349, dice=0.8456
# Epoch 43 of 1000 took 9.78s | Training: loss=1.1446, iou=0.7114, dice=0.8188
# Epoch 44 of 1000 took 9.81s | Training: loss=1.1404, iou=0.7820, dice=0.8768
# Epoch 45 of 1000 took 9.83s | Training: loss=1.1676, iou=0.6948, dice=0.8161
# Epoch 46 of 1000 took 9.88s | Training: loss=1.1615, iou=0.6909, dice=0.8094
# Epoch 47 of 1000 took 9.80s | Training: loss=1.1648, iou=0.6320, dice=0.7561
# Epoch 48 of 1000 took 9.87s | Training: loss=1.1575, iou=0.7137, dice=0.8251
# Epoch 49 of 1000 took 9.78s | Training: loss=1.1200, iou=0.7415, dice=0.8482
# Epoch 50 of 1000 took 9.83s | Training: loss=1.1168, iou=0.7221, dice=0.8337
# Epoch 51 of 1000 took 9.84s | Training: loss=1.1265, iou=0.6957, dice=0.8068
# Epoch 52 of 1000 took 9.91s | Training: loss=1.1130, iou=0.7116, dice=0.7969
# Epoch 53 of 1000 took 9.82s | Training: loss=1.1333, iou=0.7118, dice=0.8291
# Epoch 54 of 1000 took 9.79s | Training: loss=1.1125, iou=0.7667, dice=0.8644
# Epoch 55 of 1000 took 9.86s | Training: loss=1.0806, iou=0.7788, dice=0.8735
# Epoch 56 of 1000 took 9.83s | Training: loss=1.0917, iou=0.7512, dice=0.8552
# Epoch 57 of 1000 took 9.86s | Training: loss=1.1212, iou=0.7609, dice=0.8585
# Epoch 58 of 1000 took 9.88s | Training: loss=1.0719, iou=0.7711, dice=0.8699
# Epoch 59 of 1000 took 9.81s | Training: loss=1.0598, iou=0.7951, dice=0.8853
# Epoch 60 of 1000 took 9.81s | Training: loss=1.1067, iou=0.7121, dice=0.8193
# Validation: loss=1.2135, iou=0.8058, dice=0.8922
# New best model found with validation loss 1.2135, saving model...
# Epoch 61 of 1000 took 9.85s | Training: loss=1.0543, iou=0.7966, dice=0.8857
# Epoch 62 of 1000 took 9.84s | Training: loss=1.0642, iou=0.8101, dice=0.8942
# Epoch 63 of 1000 took 9.81s | Training: loss=1.0571, iou=0.8087, dice=0.8927
# Epoch 64 of 1000 took 9.81s | Training: loss=1.1166, iou=0.7515, dice=0.8526
# Epoch 65 of 1000 took 9.88s | Training: loss=1.0733, iou=0.7870, dice=0.8798
# Epoch 66 of 1000 took 9.89s | Training: loss=1.0475, iou=0.8056, dice=0.8914
# Epoch 67 of 1000 took 9.86s | Training: loss=1.0959, iou=0.7328, dice=0.8186
# Epoch 68 of 1000 took 9.82s | Training: loss=1.1173, iou=0.5766, dice=0.7136
# Epoch 69 of 1000 took 9.83s | Training: loss=1.1034, iou=0.6091, dice=0.7400
# Epoch 70 of 1000 took 9.81s | Training: loss=1.0690, iou=0.6802, dice=0.7878
# Epoch 71 of 1000 took 9.82s | Training: loss=1.0464, iou=0.7472, dice=0.8487
# Epoch 72 of 1000 took 9.86s | Training: loss=1.0953, iou=0.6925, dice=0.8113
# Epoch 73 of 1000 took 9.79s | Training: loss=1.0161, iou=0.7303, dice=0.8427
# Epoch 74 of 1000 took 9.81s | Training: loss=1.0352, iou=0.7271, dice=0.8250
# Epoch 75 of 1000 took 9.82s | Training: loss=1.0208, iou=0.8108, dice=0.8954
# Epoch 76 of 1000 took 9.87s | Training: loss=1.0217, iou=0.7806, dice=0.8750
# Epoch 77 of 1000 took 9.85s | Training: loss=1.0179, iou=0.7750, dice=0.8676
# Epoch 78 of 1000 took 9.87s | Training: loss=1.0308, iou=0.7929, dice=0.8830
# Epoch 79 of 1000 took 9.84s | Training: loss=1.0308, iou=0.7370, dice=0.8350
# Epoch 80 of 1000 took 9.78s | Training: loss=0.9719, iou=0.8167, dice=0.8984
# Validation: loss=1.1727, iou=0.7312, dice=0.8439
# New best model found with validation loss 1.1727, saving model...
# Epoch 81 of 1000 took 9.81s | Training: loss=0.9778, iou=0.8122, dice=0.8959
# Epoch 82 of 1000 took 9.83s | Training: loss=1.0044, iou=0.8092, dice=0.8936
# Epoch 83 of 1000 took 9.79s | Training: loss=0.9943, iou=0.7984, dice=0.8837
# Epoch 84 of 1000 took 9.80s | Training: loss=1.0140, iou=0.7778, dice=0.8728
# Epoch 85 of 1000 took 9.80s | Training: loss=1.0016, iou=0.8146, dice=0.8959
# Epoch 86 of 1000 took 9.83s | Training: loss=1.0080, iou=0.7849, dice=0.8770
# Epoch 87 of 1000 took 9.83s | Training: loss=1.0022, iou=0.8079, dice=0.8933
# Epoch 88 of 1000 took 9.80s | Training: loss=0.9949, iou=0.8112, dice=0.8947
# Epoch 89 of 1000 took 9.79s | Training: loss=0.9585, iou=0.8456, dice=0.9157
# Epoch 90 of 1000 took 9.80s | Training: loss=0.9737, iou=0.8048, dice=0.8902
# Epoch 91 of 1000 took 9.81s | Training: loss=0.9796, iou=0.8345, dice=0.9092
# Epoch 92 of 1000 took 9.89s | Training: loss=0.9630, iou=0.8356, dice=0.9100
# Epoch 93 of 1000 took 9.83s | Training: loss=0.9729, iou=0.8337, dice=0.9087
# Epoch 94 of 1000 took 9.79s | Training: loss=0.9759, iou=0.8236, dice=0.9018
# Epoch 95 of 1000 took 9.81s | Training: loss=0.9700, iou=0.8199, dice=0.9000
# Epoch 96 of 1000 took 9.83s | Training: loss=0.9644, iou=0.8489, dice=0.9176
# Epoch 97 of 1000 took 9.82s | Training: loss=0.9587, iou=0.8296, dice=0.9060
# Epoch 98 of 1000 took 9.85s | Training: loss=0.9148, iou=0.8373, dice=0.9110
# Epoch 99 of 1000 took 9.81s | Training: loss=0.9593, iou=0.8065, dice=0.8874
# Epoch 100 of 1000 took 9.83s | Training: loss=0.9433, iou=0.7462, dice=0.8403
# Validation: loss=1.1245, iou=0.7243, dice=0.8386
# New best model found with validation loss 1.1245, saving model...
# Epoch 101 of 1000 took 9.84s | Training: loss=0.9573, iou=0.7985, dice=0.8860
# Epoch 102 of 1000 took 9.81s | Training: loss=0.9989, iou=0.7426, dice=0.8497
# Epoch 103 of 1000 took 9.93s | Training: loss=0.9199, iou=0.8055, dice=0.8898
# Epoch 104 of 1000 took 9.95s | Training: loss=0.9130, iou=0.8255, dice=0.9038
# Epoch 105 of 1000 took 9.83s | Training: loss=0.9155, iou=0.8370, dice=0.9104
# Epoch 106 of 1000 took 9.83s | Training: loss=0.9505, iou=0.7746, dice=0.8686
# Epoch 107 of 1000 took 9.81s | Training: loss=0.9320, iou=0.8165, dice=0.8978
# Epoch 108 of 1000 took 9.84s | Training: loss=0.8693, iou=0.8325, dice=0.9082
# Epoch 109 of 1000 took 9.83s | Training: loss=0.8834, iou=0.8369, dice=0.9105
# Epoch 110 of 1000 took 9.83s | Training: loss=0.9513, iou=0.7953, dice=0.8846
# Epoch 111 of 1000 took 9.81s | Training: loss=0.9112, iou=0.8075, dice=0.8918
# Epoch 112 of 1000 took 9.82s | Training: loss=0.9072, iou=0.8359, dice=0.9102
# Epoch 113 of 1000 took 9.93s | Training: loss=0.9308, iou=0.8105, dice=0.8927
# Epoch 114 of 1000 took 9.85s | Training: loss=0.8631, iou=0.8220, dice=0.9018
# Epoch 115 of 1000 took 9.86s | Training: loss=0.8948, iou=0.8394, dice=0.9122
# Epoch 116 of 1000 took 9.83s | Training: loss=0.8706, iou=0.8311, dice=0.9070
# Epoch 117 of 1000 took 9.84s | Training: loss=0.9252, iou=0.8079, dice=0.8884
# Epoch 118 of 1000 took 9.88s | Training: loss=0.9173, iou=0.7895, dice=0.8807
# Epoch 119 of 1000 took 9.85s | Training: loss=0.8830, iou=0.7820, dice=0.8745
# Epoch 120 of 1000 took 9.99s | Training: loss=0.9022, iou=0.8171, dice=0.8975
# Validation: loss=1.0642, iou=0.7770, dice=0.8741
# New best model found with validation loss 1.0642, saving model...
# Epoch 121 of 1000 took 9.82s | Training: loss=0.8739, iou=0.8156, dice=0.8967
# Epoch 122 of 1000 took 9.82s | Training: loss=0.8724, iou=0.8272, dice=0.9047
# Epoch 123 of 1000 took 9.81s | Training: loss=0.8423, iou=0.8508, dice=0.9188
# Epoch 124 of 1000 took 9.83s | Training: loss=0.8220, iou=0.8465, dice=0.9165
# Epoch 125 of 1000 took 9.83s | Training: loss=0.8710, iou=0.8350, dice=0.9091
# Epoch 126 of 1000 took 9.83s | Training: loss=0.8995, iou=0.7835, dice=0.8710
# Epoch 127 of 1000 took 9.89s | Training: loss=0.8115, iou=0.8424, dice=0.9134
# Epoch 128 of 1000 took 9.80s | Training: loss=0.8471, iou=0.8437, dice=0.9145
# Epoch 129 of 1000 took 9.83s | Training: loss=0.8263, iou=0.8471, dice=0.9168
# Epoch 130 of 1000 took 9.82s | Training: loss=0.8995, iou=0.8065, dice=0.8902
# Epoch 131 of 1000 took 9.84s | Training: loss=0.8590, iou=0.8233, dice=0.9012
# Epoch 132 of 1000 took 9.83s | Training: loss=0.8780, iou=0.8008, dice=0.8870
# Epoch 133 of 1000 took 9.86s | Training: loss=0.8475, iou=0.8422, dice=0.9130
# Epoch 134 of 1000 took 9.91s | Training: loss=0.8379, iou=0.8393, dice=0.9120
# Epoch 135 of 1000 took 9.81s | Training: loss=0.8415, iou=0.8395, dice=0.9118
# Epoch 136 of 1000 took 9.85s | Training: loss=0.7942, iou=0.8367, dice=0.9080
# Epoch 137 of 1000 took 9.84s | Training: loss=0.8375, iou=0.8498, dice=0.9185
# Epoch 138 of 1000 took 9.92s | Training: loss=0.8576, iou=0.8422, dice=0.9131
# Epoch 139 of 1000 took 9.87s | Training: loss=0.8149, iou=0.8555, dice=0.9216
# Epoch 140 of 1000 took 9.84s | Training: loss=0.7705, iou=0.8752, dice=0.9333
# Validation: loss=1.0336, iou=0.7580, dice=0.8612
# New best model found with validation loss 1.0336, saving model...
# Epoch 141 of 1000 took 9.82s | Training: loss=0.8118, iou=0.8354, dice=0.9098
# Epoch 142 of 1000 took 9.81s | Training: loss=0.7615, iou=0.8528, dice=0.9199
# Epoch 143 of 1000 took 9.93s | Training: loss=0.7922, iou=0.8638, dice=0.9253
# Epoch 144 of 1000 took 9.81s | Training: loss=0.8474, iou=0.8381, dice=0.9109
# Epoch 145 of 1000 took 9.87s | Training: loss=0.7770, iou=0.8474, dice=0.9168
# Epoch 146 of 1000 took 9.87s | Training: loss=0.8093, iou=0.8415, dice=0.9109
# Epoch 147 of 1000 took 9.80s | Training: loss=0.7630, iou=0.8679, dice=0.9289
# Epoch 148 of 1000 took 9.82s | Training: loss=0.7824, iou=0.8672, dice=0.9283
# Epoch 149 of 1000 took 9.80s | Training: loss=0.7798, iou=0.8453, dice=0.9150
# Epoch 150 of 1000 took 9.81s | Training: loss=0.7828, iou=0.8495, dice=0.9182
# Epoch 151 of 1000 took 9.84s | Training: loss=0.7643, iou=0.8498, dice=0.9184
# Epoch 152 of 1000 took 9.85s | Training: loss=0.7807, iou=0.8561, dice=0.9222
# Epoch 153 of 1000 took 9.83s | Training: loss=0.7642, iou=0.8399, dice=0.9114
# Epoch 154 of 1000 took 9.91s | Training: loss=0.7355, iou=0.8706, dice=0.9305
# Epoch 155 of 1000 took 9.88s | Training: loss=0.7001, iou=0.8725, dice=0.9316
# Epoch 156 of 1000 took 9.92s | Training: loss=0.7556, iou=0.8588, dice=0.9224
# Epoch 157 of 1000 took 9.85s | Training: loss=0.7479, iou=0.8472, dice=0.9169
# Epoch 158 of 1000 took 9.84s | Training: loss=0.7555, iou=0.8392, dice=0.9108
# Epoch 159 of 1000 took 9.82s | Training: loss=0.7449, iou=0.8305, dice=0.9037
# Epoch 160 of 1000 took 9.81s | Training: loss=0.6904, iou=0.8601, dice=0.9240
# Validation: loss=0.9867, iou=0.8062, dice=0.8925
# New best model found with validation loss 0.9867, saving model...
# Epoch 161 of 1000 took 9.81s | Training: loss=0.7252, iou=0.8520, dice=0.9193
# Epoch 162 of 1000 took 9.79s | Training: loss=0.7593, iou=0.8536, dice=0.9204
# Epoch 163 of 1000 took 9.82s | Training: loss=0.7196, iou=0.8225, dice=0.8977
# Epoch 164 of 1000 took 9.82s | Training: loss=0.7107, iou=0.8684, dice=0.9291
# Epoch 165 of 1000 took 9.83s | Training: loss=0.7230, iou=0.8552, dice=0.9213
# Epoch 166 of 1000 took 9.82s | Training: loss=0.7008, iou=0.8740, dice=0.9326
# Epoch 167 of 1000 took 9.83s | Training: loss=0.6839, iou=0.8485, dice=0.9167
# Epoch 168 of 1000 took 9.80s | Training: loss=0.6592, iou=0.8799, dice=0.9357
# Epoch 169 of 1000 took 9.81s | Training: loss=0.7268, iou=0.8572, dice=0.9225
# Epoch 170 of 1000 took 9.91s | Training: loss=0.6867, iou=0.8505, dice=0.9183
# Epoch 171 of 1000 took 9.82s | Training: loss=0.6938, iou=0.8550, dice=0.9214
# Epoch 172 of 1000 took 9.83s | Training: loss=0.7454, iou=0.8411, dice=0.9130
# Epoch 173 of 1000 took 9.82s | Training: loss=0.6822, iou=0.8440, dice=0.9144
# Epoch 174 of 1000 took 9.81s | Training: loss=0.6427, iou=0.8818, dice=0.9368
# Epoch 175 of 1000 took 9.79s | Training: loss=0.6574, iou=0.8421, dice=0.9104
# Epoch 176 of 1000 took 9.90s | Training: loss=0.7076, iou=0.7943, dice=0.8830
# Epoch 177 of 1000 took 9.80s | Training: loss=0.6231, iou=0.8385, dice=0.9113
# Epoch 178 of 1000 took 9.82s | Training: loss=0.6592, iou=0.8316, dice=0.9077
# Epoch 179 of 1000 took 9.87s | Training: loss=0.6689, iou=0.8416, dice=0.9135
# Epoch 180 of 1000 took 9.80s | Training: loss=0.6272, iou=0.8604, dice=0.9246
# Validation: loss=0.9425, iou=0.8134, dice=0.8969
# New best model found with validation loss 0.9425, saving model...
# Epoch 181 of 1000 took 9.82s | Training: loss=0.6595, iou=0.8536, dice=0.9205
# Epoch 182 of 1000 took 9.79s | Training: loss=0.6233, iou=0.8731, dice=0.9313
# Epoch 183 of 1000 took 9.89s | Training: loss=0.6957, iou=0.8594, dice=0.9241
# Epoch 184 of 1000 took 9.85s | Training: loss=0.5975, iou=0.8776, dice=0.9344
# Epoch 185 of 1000 took 9.80s | Training: loss=0.6803, iou=0.8580, dice=0.9232
# Epoch 186 of 1000 took 9.82s | Training: loss=0.6136, iou=0.8704, dice=0.9306
# Epoch 187 of 1000 took 9.80s | Training: loss=0.6295, iou=0.8912, dice=0.9423
# Epoch 188 of 1000 took 9.80s | Training: loss=0.5841, iou=0.8882, dice=0.9406
# Epoch 189 of 1000 took 9.80s | Training: loss=0.6634, iou=0.8578, dice=0.9212
# Epoch 190 of 1000 took 9.91s | Training: loss=0.6636, iou=0.8670, dice=0.9284
# Epoch 191 of 1000 took 9.86s | Training: loss=0.6079, iou=0.8681, dice=0.9288
# Epoch 192 of 1000 took 9.92s | Training: loss=0.6300, iou=0.8690, dice=0.9291
# Epoch 193 of 1000 took 9.88s | Training: loss=0.6528, iou=0.8535, dice=0.9200
# Epoch 194 of 1000 took 9.91s | Training: loss=0.5628, iou=0.8882, dice=0.9405
# Epoch 195 of 1000 took 10.02s | Training: loss=0.5281, iou=0.8790, dice=0.9353
# Epoch 196 of 1000 took 9.84s | Training: loss=0.6074, iou=0.8431, dice=0.9083
# Epoch 197 of 1000 took 9.83s | Training: loss=0.5326, iou=0.8970, dice=0.9456
# Epoch 198 of 1000 took 9.80s | Training: loss=0.5720, iou=0.8838, dice=0.9381
# Epoch 199 of 1000 took 9.83s | Training: loss=0.5719, iou=0.8991, dice=0.9467
# Epoch 200 of 1000 took 9.83s | Training: loss=0.4915, iou=0.9059, dice=0.9505
# Validation: loss=0.8988, iou=0.8535, dice=0.9208
# New best model found with validation loss 0.8988, saving model...
# Epoch 201 of 1000 took 9.83s | Training: loss=0.5204, iou=0.8942, dice=0.9438
# Epoch 202 of 1000 took 9.81s | Training: loss=0.5667, iou=0.8870, dice=0.9396
# Epoch 203 of 1000 took 9.82s | Training: loss=0.5244, iou=0.9025, dice=0.9486
# Epoch 204 of 1000 took 9.81s | Training: loss=0.4656, iou=0.9107, dice=0.9531
# Epoch 205 of 1000 took 9.85s | Training: loss=0.5123, iou=0.9104, dice=0.9530
# Epoch 206 of 1000 took 9.86s | Training: loss=0.5207, iou=0.8977, dice=0.9459
# Epoch 207 of 1000 took 9.80s | Training: loss=0.4794, iou=0.9066, dice=0.9509
# Epoch 208 of 1000 took 9.83s | Training: loss=0.5230, iou=0.8919, dice=0.9427
# Epoch 209 of 1000 took 9.81s | Training: loss=0.4850, iou=0.9086, dice=0.9520
# Epoch 210 of 1000 took 9.79s | Training: loss=0.4743, iou=0.8991, dice=0.9463
# Epoch 211 of 1000 took 9.81s | Training: loss=0.4790, iou=0.9067, dice=0.9509
# Epoch 212 of 1000 took 9.82s | Training: loss=0.4779, iou=0.9097, dice=0.9526
# Epoch 213 of 1000 took 9.84s | Training: loss=0.5435, iou=0.8657, dice=0.9273
# Epoch 214 of 1000 took 9.80s | Training: loss=0.4976, iou=0.8785, dice=0.9349
# Epoch 215 of 1000 took 9.89s | Training: loss=0.4551, iou=0.8775, dice=0.9344
# Epoch 216 of 1000 took 9.80s | Training: loss=0.5001, iou=0.8913, dice=0.9423
# Epoch 217 of 1000 took 9.85s | Training: loss=0.4532, iou=0.9058, dice=0.9505
# Epoch 218 of 1000 took 9.98s | Training: loss=0.5311, iou=0.8845, dice=0.9383
# Epoch 219 of 1000 took 9.82s | Training: loss=0.4505, iou=0.9149, dice=0.9554
# Epoch 220 of 1000 took 9.83s | Training: loss=0.4785, iou=0.8915, dice=0.9424
# Validation: loss=0.8439, iou=0.8655, dice=0.9278
# New best model found with validation loss 0.8439, saving model...
# Epoch 221 of 1000 took 9.80s | Training: loss=0.5390, iou=0.8815, dice=0.9361
# Epoch 222 of 1000 took 9.82s | Training: loss=0.4708, iou=0.9150, dice=0.9555
# Epoch 223 of 1000 took 9.82s | Training: loss=0.4730, iou=0.9048, dice=0.9498
# Epoch 224 of 1000 took 9.84s | Training: loss=0.4654, iou=0.9046, dice=0.9496
# Epoch 225 of 1000 took 9.86s | Training: loss=0.4204, iou=0.9083, dice=0.9517
# Epoch 226 of 1000 took 9.87s | Training: loss=0.4069, iou=0.9135, dice=0.9546
# Epoch 227 of 1000 took 9.82s | Training: loss=0.4009, iou=0.9107, dice=0.9531
# Epoch 228 of 1000 took 9.82s | Training: loss=0.3835, iou=0.9131, dice=0.9544
# Epoch 229 of 1000 took 9.83s | Training: loss=0.4265, iou=0.9135, dice=0.9547
# Epoch 230 of 1000 took 9.85s | Training: loss=0.4072, iou=0.9088, dice=0.9520
# Epoch 231 of 1000 took 9.80s | Training: loss=0.4842, iou=0.8165, dice=0.8683
# Epoch 232 of 1000 took 9.89s | Training: loss=0.5909, iou=0.8345, dice=0.9065
# Epoch 233 of 1000 took 9.90s | Training: loss=0.4637, iou=0.8923, dice=0.9428
# Epoch 234 of 1000 took 9.84s | Training: loss=0.4135, iou=0.9113, dice=0.9534
# Epoch 235 of 1000 took 9.82s | Training: loss=0.4350, iou=0.8920, dice=0.9423
# Epoch 236 of 1000 took 9.83s | Training: loss=0.4533, iou=0.8799, dice=0.9356
# Epoch 237 of 1000 took 9.81s | Training: loss=0.4505, iou=0.8817, dice=0.9362
# Epoch 238 of 1000 took 9.84s | Training: loss=0.3831, iou=0.9083, dice=0.9517
# Epoch 239 of 1000 took 9.85s | Training: loss=0.4025, iou=0.9002, dice=0.9473
# Epoch 240 of 1000 took 9.81s | Training: loss=0.4086, iou=0.9073, dice=0.9511
# Validation: loss=0.7685, iou=0.8618, dice=0.9256
# New best model found with validation loss 0.7685, saving model...
# Epoch 241 of 1000 took 9.84s | Training: loss=0.3834, iou=0.9182, dice=0.9573
# Epoch 242 of 1000 took 9.82s | Training: loss=0.3788, iou=0.9113, dice=0.9534
# Epoch 243 of 1000 took 9.84s | Training: loss=0.4644, iou=0.8918, dice=0.9423
# Epoch 244 of 1000 took 9.81s | Training: loss=0.3796, iou=0.9183, dice=0.9574
# Epoch 245 of 1000 took 9.80s | Training: loss=0.4712, iou=0.8827, dice=0.9364
# Epoch 246 of 1000 took 9.84s | Training: loss=0.3673, iou=0.9041, dice=0.9495
# Epoch 247 of 1000 took 9.83s | Training: loss=0.3563, iou=0.8920, dice=0.9422
# Epoch 248 of 1000 took 9.85s | Training: loss=0.3464, iou=0.9086, dice=0.9516
# Epoch 249 of 1000 took 9.84s | Training: loss=0.3457, iou=0.9107, dice=0.9532
# Epoch 250 of 1000 took 9.82s | Training: loss=0.4142, iou=0.9113, dice=0.9535
# Epoch 251 of 1000 took 9.88s | Training: loss=0.4401, iou=0.8736, dice=0.9314
# Epoch 252 of 1000 took 9.83s | Training: loss=0.3543, iou=0.9120, dice=0.9539
# Epoch 253 of 1000 took 9.87s | Training: loss=0.3361, iou=0.9101, dice=0.9529
# Epoch 254 of 1000 took 9.87s | Training: loss=0.3606, iou=0.9084, dice=0.9519
# Epoch 255 of 1000 took 9.82s | Training: loss=0.3179, iou=0.9181, dice=0.9572
# Epoch 256 of 1000 took 9.88s | Training: loss=0.3850, iou=0.9156, dice=0.9558
# Epoch 257 of 1000 took 9.88s | Training: loss=0.4544, iou=0.8775, dice=0.9337
# Epoch 258 of 1000 took 9.86s | Training: loss=0.3300, iou=0.9154, dice=0.9557
# Epoch 259 of 1000 took 9.84s | Training: loss=0.3723, iou=0.9078, dice=0.9516
# Epoch 260 of 1000 took 9.83s | Training: loss=0.3153, iou=0.9082, dice=0.9518
# Validation: loss=0.7443, iou=0.8683, dice=0.9294
# New best model found with validation loss 0.7443, saving model...
# Epoch 261 of 1000 took 9.82s | Training: loss=0.3107, iou=0.9176, dice=0.9569
# Epoch 262 of 1000 took 9.83s | Training: loss=0.3018, iou=0.9262, dice=0.9616
# Epoch 263 of 1000 took 9.86s | Training: loss=0.3057, iou=0.9259, dice=0.9615
# Epoch 264 of 1000 took 9.82s | Training: loss=0.3226, iou=0.9216, dice=0.9592
# Epoch 265 of 1000 took 9.88s | Training: loss=0.3250, iou=0.9080, dice=0.9515
# Epoch 266 of 1000 took 9.82s | Training: loss=0.4145, iou=0.8720, dice=0.9288
# Epoch 267 of 1000 took 9.94s | Training: loss=0.3321, iou=0.8837, dice=0.9343
# Epoch 268 of 1000 took 9.82s | Training: loss=0.3368, iou=0.9079, dice=0.9515
# Epoch 269 of 1000 took 9.89s | Training: loss=0.2875, iou=0.9160, dice=0.9561
# Epoch 270 of 1000 took 9.83s | Training: loss=0.2851, iou=0.9124, dice=0.9538
# Epoch 271 of 1000 took 9.84s | Training: loss=0.3162, iou=0.9221, dice=0.9592
# Epoch 272 of 1000 took 9.84s | Training: loss=0.3418, iou=0.9157, dice=0.9559
# Epoch 273 of 1000 took 9.90s | Training: loss=0.2999, iou=0.9199, dice=0.9582
# Epoch 274 of 1000 took 9.85s | Training: loss=0.3042, iou=0.9219, dice=0.9593
# Epoch 275 of 1000 took 9.86s | Training: loss=0.2604, iou=0.9222, dice=0.9595
# Epoch 276 of 1000 took 9.81s | Training: loss=0.2711, iou=0.9279, dice=0.9625
# Epoch 277 of 1000 took 9.84s | Training: loss=0.2559, iou=0.9300, dice=0.9637
# Epoch 278 of 1000 took 9.81s | Training: loss=0.3331, iou=0.9228, dice=0.9598
# Epoch 279 of 1000 took 9.86s | Training: loss=0.2597, iou=0.9240, dice=0.9605
# Epoch 280 of 1000 took 9.80s | Training: loss=0.3172, iou=0.9126, dice=0.9541
# Validation: loss=0.6200, iou=0.8641, dice=0.9270
# New best model found with validation loss 0.6200, saving model...
# Epoch 281 of 1000 took 9.83s | Training: loss=0.2660, iou=0.9235, dice=0.9602
# Epoch 282 of 1000 took 9.82s | Training: loss=0.3072, iou=0.9113, dice=0.9533
# Epoch 283 of 1000 took 9.83s | Training: loss=0.4069, iou=0.8417, dice=0.9065
# Epoch 284 of 1000 took 9.80s | Training: loss=0.3154, iou=0.9082, dice=0.9513
# Epoch 285 of 1000 took 9.81s | Training: loss=0.2334, iou=0.9247, dice=0.9608
# Epoch 286 of 1000 took 9.85s | Training: loss=0.3226, iou=0.9114, dice=0.9536
# Epoch 287 of 1000 took 9.79s | Training: loss=0.2470, iou=0.9260, dice=0.9615
# Epoch 288 of 1000 took 9.88s | Training: loss=0.2303, iou=0.9255, dice=0.9613
# Epoch 289 of 1000 took 9.82s | Training: loss=0.2285, iou=0.9334, dice=0.9655
# Epoch 290 of 1000 took 9.79s | Training: loss=0.2397, iou=0.9318, dice=0.9646
# Epoch 291 of 1000 took 9.80s | Training: loss=0.3038, iou=0.9183, dice=0.9574
# Epoch 292 of 1000 took 9.83s | Training: loss=0.2258, iou=0.9288, dice=0.9631
# Epoch 293 of 1000 took 9.85s | Training: loss=0.2597, iou=0.9261, dice=0.9615
# Epoch 294 of 1000 took 9.83s | Training: loss=0.2534, iou=0.9244, dice=0.9606
# Epoch 295 of 1000 took 9.81s | Training: loss=0.2559, iou=0.9223, dice=0.9595
# Epoch 296 of 1000 took 9.90s | Training: loss=0.2361, iou=0.9209, dice=0.9587
# Epoch 297 of 1000 took 9.82s | Training: loss=0.2067, iou=0.9307, dice=0.9640
# Epoch 298 of 1000 took 9.82s | Training: loss=0.2040, iou=0.9304, dice=0.9639
# Epoch 299 of 1000 took 9.82s | Training: loss=0.2115, iou=0.9321, dice=0.9648
# Epoch 300 of 1000 took 9.82s | Training: loss=0.2728, iou=0.9287, dice=0.9629
# Validation: loss=0.5984, iou=0.8631, dice=0.9264
# New best model found with validation loss 0.5984, saving model...
# Epoch 301 of 1000 took 9.84s | Training: loss=0.2101, iou=0.9331, dice=0.9652
# Epoch 302 of 1000 took 9.80s | Training: loss=0.2170, iou=0.9321, dice=0.9648
# Epoch 303 of 1000 took 9.94s | Training: loss=0.2324, iou=0.9277, dice=0.9624
# Epoch 304 of 1000 took 9.84s | Training: loss=0.2414, iou=0.9303, dice=0.9638
# Epoch 305 of 1000 took 9.80s | Training: loss=0.1933, iou=0.9433, dice=0.9708
# Epoch 306 of 1000 took 9.81s | Training: loss=0.1887, iou=0.9405, dice=0.9693
# Epoch 307 of 1000 took 9.82s | Training: loss=0.2058, iou=0.9305, dice=0.9639
# Epoch 308 of 1000 took 9.88s | Training: loss=0.2888, iou=0.9190, dice=0.9575
# Epoch 309 of 1000 took 9.84s | Training: loss=0.2140, iou=0.9189, dice=0.9575
# Epoch 310 of 1000 took 9.82s | Training: loss=0.2449, iou=0.9145, dice=0.9553
# Epoch 311 of 1000 took 9.92s | Training: loss=0.2029, iou=0.9174, dice=0.9568
# Epoch 312 of 1000 took 9.84s | Training: loss=0.2765, iou=0.8642, dice=0.9229
# Epoch 313 of 1000 took 9.82s | Training: loss=0.2530, iou=0.8718, dice=0.9298
# Epoch 314 of 1000 took 9.81s | Training: loss=0.2077, iou=0.9113, dice=0.9535
# Epoch 315 of 1000 took 9.86s | Training: loss=0.2376, iou=0.8879, dice=0.9392
# Epoch 316 of 1000 took 9.90s | Training: loss=0.2466, iou=0.8978, dice=0.9459
# Epoch 317 of 1000 took 9.83s | Training: loss=0.2108, iou=0.9040, dice=0.9493
# Epoch 318 of 1000 took 9.80s | Training: loss=0.2178, iou=0.8965, dice=0.9454
# Epoch 319 of 1000 took 9.83s | Training: loss=0.2225, iou=0.9054, dice=0.9501
# Epoch 320 of 1000 took 9.83s | Training: loss=0.1744, iou=0.9171, dice=0.9567
# Validation: loss=0.5110, iou=0.8687, dice=0.9297
# New best model found with validation loss 0.5110, saving model...
# Epoch 321 of 1000 took 9.81s | Training: loss=0.1556, iou=0.9276, dice=0.9624
# Epoch 322 of 1000 took 9.85s | Training: loss=0.2551, iou=0.8923, dice=0.9429
# Epoch 323 of 1000 took 9.79s | Training: loss=0.2028, iou=0.9004, dice=0.9475
# Epoch 324 of 1000 took 9.82s | Training: loss=0.2279, iou=0.8872, dice=0.9401
# Epoch 325 of 1000 took 9.84s | Training: loss=0.1967, iou=0.8993, dice=0.9469
# Epoch 326 of 1000 took 9.80s | Training: loss=0.2148, iou=0.9059, dice=0.9504
# Epoch 327 of 1000 took 9.82s | Training: loss=0.2042, iou=0.9195, dice=0.9580
# Epoch 328 of 1000 took 9.81s | Training: loss=0.2055, iou=0.9183, dice=0.9573
# Epoch 329 of 1000 took 9.83s | Training: loss=0.1784, iou=0.9208, dice=0.9586
# Epoch 330 of 1000 took 9.81s | Training: loss=0.2106, iou=0.9291, dice=0.9632
# Epoch 331 of 1000 took 9.81s | Training: loss=0.1638, iou=0.9320, dice=0.9647
# Epoch 332 of 1000 took 9.81s | Training: loss=0.1436, iou=0.9353, dice=0.9665
# Epoch 333 of 1000 took 9.79s | Training: loss=0.1662, iou=0.9345, dice=0.9661
# Epoch 334 of 1000 took 9.81s | Training: loss=0.1851, iou=0.9303, dice=0.9638
# Epoch 335 of 1000 took 9.82s | Training: loss=0.1484, iou=0.9387, dice=0.9684
# Epoch 336 of 1000 took 9.81s | Training: loss=0.1729, iou=0.9390, dice=0.9685
# Epoch 337 of 1000 took 9.83s | Training: loss=0.1489, iou=0.9364, dice=0.9672
# Epoch 338 of 1000 took 9.81s | Training: loss=0.1705, iou=0.9368, dice=0.9673
# Epoch 339 of 1000 took 9.82s | Training: loss=0.1789, iou=0.9263, dice=0.9617
# Epoch 340 of 1000 took 9.83s | Training: loss=0.1477, iou=0.9395, dice=0.9688
# Validation: loss=0.4796, iou=0.8768, dice=0.9343
# New best model found with validation loss 0.4796, saving model...
# Epoch 341 of 1000 took 9.81s | Training: loss=0.1451, iou=0.9347, dice=0.9662
# Epoch 342 of 1000 took 9.82s | Training: loss=0.1596, iou=0.9328, dice=0.9651
# Epoch 343 of 1000 took 9.80s | Training: loss=0.2400, iou=0.8830, dice=0.9335
# Epoch 344 of 1000 took 9.83s | Training: loss=0.1756, iou=0.9276, dice=0.9624
# Epoch 345 of 1000 took 9.88s | Training: loss=0.1533, iou=0.9346, dice=0.9661
# Epoch 346 of 1000 took 9.87s | Training: loss=0.1701, iou=0.9329, dice=0.9653
# Epoch 347 of 1000 took 9.82s | Training: loss=0.1346, iou=0.9400, dice=0.9690
# Epoch 348 of 1000 took 9.83s | Training: loss=0.1427, iou=0.9403, dice=0.9692
# Epoch 349 of 1000 took 9.83s | Training: loss=0.1995, iou=0.9030, dice=0.9441
# Epoch 350 of 1000 took 9.80s | Training: loss=0.1576, iou=0.9194, dice=0.9575
# Epoch 351 of 1000 took 9.84s | Training: loss=0.1633, iou=0.9289, dice=0.9630
# Epoch 352 of 1000 took 9.82s | Training: loss=0.1589, iou=0.9303, dice=0.9639
# Epoch 353 of 1000 took 9.79s | Training: loss=0.1468, iou=0.9380, dice=0.9680
# Epoch 354 of 1000 took 9.84s | Training: loss=0.1502, iou=0.9313, dice=0.9644
# Epoch 355 of 1000 took 9.84s | Training: loss=0.1484, iou=0.9290, dice=0.9631
# Epoch 356 of 1000 took 9.81s | Training: loss=0.1822, iou=0.9261, dice=0.9613
# Epoch 357 of 1000 took 9.83s | Training: loss=0.2260, iou=0.9067, dice=0.9504
# Epoch 358 of 1000 took 9.81s | Training: loss=0.1717, iou=0.9130, dice=0.9544
# Epoch 359 of 1000 took 9.82s | Training: loss=0.1405, iou=0.9196, dice=0.9577
# Epoch 360 of 1000 took 9.82s | Training: loss=0.1523, iou=0.9173, dice=0.9568
# Validation: loss=0.4006, iou=0.8510, dice=0.9194
# New best model found with validation loss 0.4006, saving model...
# Epoch 361 of 1000 took 9.81s | Training: loss=0.2681, iou=0.7785, dice=0.8313
# Epoch 362 of 1000 took 9.83s | Training: loss=0.2083, iou=0.8286, dice=0.9054
# Epoch 363 of 1000 took 9.81s | Training: loss=0.1843, iou=0.8493, dice=0.9178
# Epoch 364 of 1000 took 9.85s | Training: loss=0.3010, iou=0.7587, dice=0.8588
# Epoch 365 of 1000 took 9.82s | Training: loss=0.2291, iou=0.8030, dice=0.8885
# Epoch 366 of 1000 took 9.78s | Training: loss=0.2451, iou=0.7852, dice=0.8604
# Epoch 367 of 1000 took 9.82s | Training: loss=0.1630, iou=0.8902, dice=0.9418
# Epoch 368 of 1000 took 9.82s | Training: loss=0.1745, iou=0.8691, dice=0.9292
# Epoch 369 of 1000 took 9.79s | Training: loss=0.1605, iou=0.8940, dice=0.9439
# Epoch 370 of 1000 took 9.78s | Training: loss=0.1633, iou=0.8887, dice=0.9405
# Epoch 371 of 1000 took 9.79s | Training: loss=0.1360, iou=0.8939, dice=0.9438
# Epoch 372 of 1000 took 9.82s | Training: loss=0.2146, iou=0.8417, dice=0.9077
# Epoch 373 of 1000 took 9.82s | Training: loss=0.1681, iou=0.8957, dice=0.9444
# Epoch 374 of 1000 took 9.81s | Training: loss=0.1628, iou=0.9006, dice=0.9470
# Epoch 375 of 1000 took 9.84s | Training: loss=0.1390, iou=0.9086, dice=0.9521
# Epoch 376 of 1000 took 9.84s | Training: loss=0.1246, iou=0.9264, dice=0.9617
# Epoch 377 of 1000 took 9.89s | Training: loss=0.1284, iou=0.9220, dice=0.9594
# Epoch 378 of 1000 took 9.81s | Training: loss=0.1235, iou=0.9284, dice=0.9628
# Epoch 379 of 1000 took 9.84s | Training: loss=0.1141, iou=0.9354, dice=0.9666
# Epoch 380 of 1000 took 9.81s | Training: loss=0.1313, iou=0.9286, dice=0.9629
# Validation: loss=0.3909, iou=0.8771, dice=0.9344
# New best model found with validation loss 0.3909, saving model...
# Epoch 381 of 1000 took 9.89s | Training: loss=0.1232, iou=0.9289, dice=0.9631
# Epoch 382 of 1000 took 9.84s | Training: loss=0.1555, iou=0.9250, dice=0.9608
# Epoch 383 of 1000 took 9.83s | Training: loss=0.1499, iou=0.9223, dice=0.9595
# Epoch 384 of 1000 took 9.81s | Training: loss=0.1238, iou=0.9221, dice=0.9590
# Epoch 385 of 1000 took 9.79s | Training: loss=0.1803, iou=0.9106, dice=0.9529
# Epoch 386 of 1000 took 9.84s | Training: loss=0.1438, iou=0.9202, dice=0.9584
# Epoch 387 of 1000 took 9.85s | Training: loss=0.1289, iou=0.9290, dice=0.9632
# Epoch 388 of 1000 took 9.86s | Training: loss=0.1295, iou=0.9280, dice=0.9626
# Epoch 389 of 1000 took 9.79s | Training: loss=0.1212, iou=0.9324, dice=0.9650
# Epoch 390 of 1000 took 9.83s | Training: loss=0.1025, iou=0.9431, dice=0.9707
# Epoch 391 of 1000 took 9.82s | Training: loss=0.1331, iou=0.9237, dice=0.9601
# Epoch 392 of 1000 took 9.82s | Training: loss=0.1355, iou=0.9331, dice=0.9654
# Epoch 393 of 1000 took 9.81s | Training: loss=0.1310, iou=0.9252, dice=0.9609
# Epoch 394 of 1000 took 9.81s | Training: loss=0.1140, iou=0.9370, dice=0.9675
# Epoch 395 of 1000 took 9.89s | Training: loss=0.1450, iou=0.9286, dice=0.9629
# Epoch 396 of 1000 took 9.85s | Training: loss=0.1180, iou=0.9339, dice=0.9657
# Epoch 397 of 1000 took 9.80s | Training: loss=0.1233, iou=0.9321, dice=0.9648
# Epoch 398 of 1000 took 9.88s | Training: loss=0.1260, iou=0.9394, dice=0.9687
# Epoch 399 of 1000 took 9.81s | Training: loss=0.1108, iou=0.9405, dice=0.9693
# Epoch 400 of 1000 took 9.83s | Training: loss=0.1149, iou=0.9414, dice=0.9698
# Validation: loss=0.3384, iou=0.8724, dice=0.9318
# New best model found with validation loss 0.3384, saving model...
# Epoch 401 of 1000 took 9.79s | Training: loss=0.1009, iou=0.9450, dice=0.9717
# Epoch 402 of 1000 took 9.79s | Training: loss=0.1320, iou=0.9353, dice=0.9665
# Epoch 403 of 1000 took 9.83s | Training: loss=0.1083, iou=0.9453, dice=0.9718
# Epoch 404 of 1000 took 9.88s | Training: loss=0.1020, iou=0.9427, dice=0.9705
# Epoch 405 of 1000 took 9.88s | Training: loss=0.0985, iou=0.9465, dice=0.9725
# Epoch 406 of 1000 took 9.85s | Training: loss=0.1035, iou=0.9433, dice=0.9708
# Epoch 407 of 1000 took 9.81s | Training: loss=0.1004, iou=0.9411, dice=0.9696
# Epoch 408 of 1000 took 9.81s | Training: loss=0.1750, iou=0.9165, dice=0.9542
# Epoch 409 of 1000 took 9.85s | Training: loss=0.1713, iou=0.9193, dice=0.9576
# Epoch 410 of 1000 took 9.82s | Training: loss=0.1056, iou=0.9420, dice=0.9701
# Epoch 411 of 1000 took 9.83s | Training: loss=0.0943, iou=0.9456, dice=0.9720
# Epoch 412 of 1000 took 9.85s | Training: loss=0.1049, iou=0.9382, dice=0.9680
# Epoch 413 of 1000 took 9.86s | Training: loss=0.0945, iou=0.9448, dice=0.9716
# Epoch 414 of 1000 took 10.11s | Training: loss=0.1161, iou=0.9358, dice=0.9668
# Epoch 415 of 1000 took 9.84s | Training: loss=0.0994, iou=0.9413, dice=0.9697
# Epoch 416 of 1000 took 9.85s | Training: loss=0.0853, iou=0.9444, dice=0.9714
# Epoch 417 of 1000 took 9.87s | Training: loss=0.0980, iou=0.9412, dice=0.9697
# Epoch 418 of 1000 took 9.79s | Training: loss=0.1027, iou=0.9430, dice=0.9706
# Epoch 419 of 1000 took 9.81s | Training: loss=0.1170, iou=0.9402, dice=0.9692
# Epoch 420 of 1000 took 9.86s | Training: loss=0.0923, iou=0.9379, dice=0.9679
# Validation: loss=0.3136, iou=0.8570, dice=0.9228
# New best model found with validation loss 0.3136, saving model...
# Epoch 421 of 1000 took 9.95s | Training: loss=0.0943, iou=0.9389, dice=0.9684
# Epoch 422 of 1000 took 9.87s | Training: loss=0.0904, iou=0.9434, dice=0.9709
# Epoch 423 of 1000 took 9.87s | Training: loss=0.0824, iou=0.9499, dice=0.9743
# Epoch 424 of 1000 took 9.83s | Training: loss=0.0929, iou=0.9448, dice=0.9716
# Epoch 425 of 1000 took 9.84s | Training: loss=0.0923, iou=0.9430, dice=0.9706
# Epoch 426 of 1000 took 9.85s | Training: loss=0.1045, iou=0.9375, dice=0.9677
# Epoch 427 of 1000 took 9.81s | Training: loss=0.0838, iou=0.9427, dice=0.9705
# Epoch 428 of 1000 took 9.83s | Training: loss=0.1061, iou=0.9375, dice=0.9676
# Epoch 429 of 1000 took 9.82s | Training: loss=0.0756, iou=0.9484, dice=0.9735
# Epoch 430 of 1000 took 9.83s | Training: loss=0.1420, iou=0.9241, dice=0.9592
# Epoch 431 of 1000 took 9.81s | Training: loss=0.0981, iou=0.9402, dice=0.9691
# Epoch 432 of 1000 took 9.83s | Training: loss=0.1212, iou=0.9236, dice=0.9595
# Epoch 433 of 1000 took 9.83s | Training: loss=0.0917, iou=0.9394, dice=0.9687
# Epoch 434 of 1000 took 9.79s | Training: loss=0.0896, iou=0.9416, dice=0.9699
# Epoch 435 of 1000 took 9.82s | Training: loss=0.0714, iou=0.9504, dice=0.9746
# Epoch 436 of 1000 took 9.84s | Training: loss=0.0899, iou=0.9446, dice=0.9715
# Epoch 437 of 1000 took 9.78s | Training: loss=0.0735, iou=0.9512, dice=0.9750
# Epoch 438 of 1000 took 9.85s | Training: loss=0.0806, iou=0.9492, dice=0.9739
# Epoch 439 of 1000 took 9.86s | Training: loss=0.0966, iou=0.9497, dice=0.9742
# Epoch 440 of 1000 took 9.98s | Training: loss=0.0843, iou=0.9488, dice=0.9737
# Validation: loss=0.2675, iou=0.8730, dice=0.9321
# New best model found with validation loss 0.2675, saving model...
# Epoch 441 of 1000 took 9.83s | Training: loss=0.0706, iou=0.9524, dice=0.9756
# Epoch 442 of 1000 took 9.91s | Training: loss=0.0721, iou=0.9500, dice=0.9744
# Epoch 443 of 1000 took 9.81s | Training: loss=0.1198, iou=0.9356, dice=0.9664
# Epoch 444 of 1000 took 9.81s | Training: loss=0.0882, iou=0.9424, dice=0.9703
# Epoch 445 of 1000 took 9.83s | Training: loss=0.0850, iou=0.9453, dice=0.9719
# Epoch 446 of 1000 took 9.83s | Training: loss=0.1076, iou=0.9434, dice=0.9708
# Epoch 447 of 1000 took 9.83s | Training: loss=0.0841, iou=0.9451, dice=0.9718
# Epoch 448 of 1000 took 9.80s | Training: loss=0.0800, iou=0.9474, dice=0.9730
# Epoch 449 of 1000 took 9.83s | Training: loss=0.0938, iou=0.9467, dice=0.9726
# Epoch 450 of 1000 took 10.00s | Training: loss=0.0838, iou=0.9509, dice=0.9748
# Epoch 451 of 1000 took 9.83s | Training: loss=0.0736, iou=0.9481, dice=0.9733
# Epoch 452 of 1000 took 9.84s | Training: loss=0.0782, iou=0.9446, dice=0.9715
# Epoch 453 of 1000 took 9.86s | Training: loss=0.0742, iou=0.9462, dice=0.9723
# Epoch 454 of 1000 took 9.83s | Training: loss=0.0707, iou=0.9508, dice=0.9747
# Epoch 455 of 1000 took 9.81s | Training: loss=0.0824, iou=0.9443, dice=0.9713
# Epoch 456 of 1000 took 9.82s | Training: loss=0.1006, iou=0.9413, dice=0.9697
# Epoch 457 of 1000 took 9.83s | Training: loss=0.0852, iou=0.9457, dice=0.9721
# Epoch 458 of 1000 took 9.79s | Training: loss=0.0703, iou=0.9526, dice=0.9757
# Epoch 459 of 1000 took 9.80s | Training: loss=0.0729, iou=0.9484, dice=0.9735
# Epoch 460 of 1000 took 9.79s | Training: loss=0.0796, iou=0.9472, dice=0.9729
# Validation: loss=0.2448, iou=0.8720, dice=0.9315
# New best model found with validation loss 0.2448, saving model...
# Epoch 461 of 1000 took 9.88s | Training: loss=0.0904, iou=0.9359, dice=0.9667
# Epoch 462 of 1000 took 9.79s | Training: loss=0.0919, iou=0.9447, dice=0.9715
# Epoch 463 of 1000 took 9.80s | Training: loss=0.0891, iou=0.9481, dice=0.9733
# Epoch 464 of 1000 took 9.80s | Training: loss=0.0856, iou=0.9473, dice=0.9729
# Epoch 465 of 1000 took 9.82s | Training: loss=0.0836, iou=0.9433, dice=0.9708
# Epoch 466 of 1000 took 9.84s | Training: loss=0.0689, iou=0.9532, dice=0.9760
# Epoch 467 of 1000 took 9.80s | Training: loss=0.0717, iou=0.9541, dice=0.9765
# Epoch 468 of 1000 took 9.80s | Training: loss=0.0861, iou=0.9440, dice=0.9711
# Epoch 469 of 1000 took 9.90s | Training: loss=0.0788, iou=0.9459, dice=0.9721
# Epoch 470 of 1000 took 9.84s | Training: loss=0.0916, iou=0.9440, dice=0.9711
# Epoch 471 of 1000 took 9.82s | Training: loss=0.0914, iou=0.9405, dice=0.9693
# Epoch 472 of 1000 took 9.83s | Training: loss=0.0948, iou=0.9421, dice=0.9701
# Epoch 473 of 1000 took 9.81s | Training: loss=0.0762, iou=0.9464, dice=0.9724
# Epoch 474 of 1000 took 9.89s | Training: loss=0.0739, iou=0.9477, dice=0.9731
# Epoch 475 of 1000 took 9.95s | Training: loss=0.0719, iou=0.9521, dice=0.9754
# Epoch 476 of 1000 took 10.05s | Training: loss=0.0696, iou=0.9516, dice=0.9752
# Epoch 477 of 1000 took 9.84s | Training: loss=0.0849, iou=0.9455, dice=0.9719
# Epoch 478 of 1000 took 9.83s | Training: loss=0.0721, iou=0.9513, dice=0.9750
# Epoch 479 of 1000 took 9.90s | Training: loss=0.0938, iou=0.9399, dice=0.9689
# Epoch 480 of 1000 took 9.82s | Training: loss=0.0639, iou=0.9486, dice=0.9736
# Validation: loss=0.2080, iou=0.8767, dice=0.9342
# New best model found with validation loss 0.2080, saving model...
# Epoch 481 of 1000 took 9.80s | Training: loss=0.1021, iou=0.9402, dice=0.9689
# Epoch 482 of 1000 took 9.80s | Training: loss=0.0669, iou=0.9470, dice=0.9728
# Epoch 483 of 1000 took 9.81s | Training: loss=0.0886, iou=0.9443, dice=0.9713
# Epoch 484 of 1000 took 9.82s | Training: loss=0.0642, iou=0.9525, dice=0.9756
# Epoch 485 of 1000 took 9.83s | Training: loss=0.0683, iou=0.9526, dice=0.9757
# Epoch 486 of 1000 took 9.81s | Training: loss=0.0855, iou=0.9454, dice=0.9719
# Epoch 487 of 1000 took 9.81s | Training: loss=0.0670, iou=0.9500, dice=0.9743
# Epoch 488 of 1000 took 9.79s | Training: loss=0.0565, iou=0.9543, dice=0.9766
# Epoch 489 of 1000 took 9.81s | Training: loss=0.0770, iou=0.9466, dice=0.9725
# Epoch 490 of 1000 took 9.82s | Training: loss=0.0591, iou=0.9559, dice=0.9774
# Epoch 491 of 1000 took 9.82s | Training: loss=0.0691, iou=0.9516, dice=0.9751
# Epoch 492 of 1000 took 9.78s | Training: loss=0.0633, iou=0.9533, dice=0.9761
# Epoch 493 of 1000 took 9.83s | Training: loss=0.0788, iou=0.9240, dice=0.9599
# Epoch 494 of 1000 took 9.81s | Training: loss=0.1581, iou=0.8215, dice=0.8994
# Epoch 495 of 1000 took 9.80s | Training: loss=0.1337, iou=0.8505, dice=0.9188
# Epoch 496 of 1000 took 9.78s | Training: loss=0.1786, iou=0.8017, dice=0.8855
# Epoch 497 of 1000 took 9.81s | Training: loss=0.1219, iou=0.8677, dice=0.9281
# Epoch 498 of 1000 took 9.81s | Training: loss=0.1480, iou=0.8478, dice=0.9163
# Epoch 499 of 1000 took 9.85s | Training: loss=0.1041, iou=0.8847, dice=0.9387
# Epoch 500 of 1000 took 9.80s | Training: loss=0.1467, iou=0.8385, dice=0.9045
# Validation: loss=0.2524, iou=0.8675, dice=0.9290
# Epoch 501 of 1000 took 9.81s | Training: loss=0.0929, iou=0.9000, dice=0.9472
# Epoch 502 of 1000 took 9.82s | Training: loss=0.0930, iou=0.9097, dice=0.9525
# Epoch 503 of 1000 took 9.81s | Training: loss=0.0771, iou=0.9297, dice=0.9635
# Epoch 504 of 1000 took 9.81s | Training: loss=0.0700, iou=0.9350, dice=0.9664
# Epoch 505 of 1000 took 9.81s | Training: loss=0.0767, iou=0.9294, dice=0.9633
# Epoch 506 of 1000 took 9.83s | Training: loss=0.0671, iou=0.9410, dice=0.9696
# Epoch 507 of 1000 took 9.84s | Training: loss=0.0704, iou=0.9377, dice=0.9678
# Epoch 508 of 1000 took 9.82s | Training: loss=0.0622, iou=0.9403, dice=0.9692
# Epoch 509 of 1000 took 9.81s | Training: loss=0.0730, iou=0.9344, dice=0.9660
# Epoch 510 of 1000 took 9.80s | Training: loss=0.0613, iou=0.9422, dice=0.9702
# Epoch 511 of 1000 took 9.90s | Training: loss=0.0879, iou=0.9350, dice=0.9662
# Epoch 512 of 1000 took 9.96s | Training: loss=0.0559, iou=0.9490, dice=0.9738
# Epoch 513 of 1000 took 9.83s | Training: loss=0.0794, iou=0.9290, dice=0.9631
# Epoch 514 of 1000 took 9.81s | Training: loss=0.0725, iou=0.9390, dice=0.9685
# Epoch 515 of 1000 took 9.81s | Training: loss=0.0656, iou=0.9385, dice=0.9683
# Epoch 516 of 1000 took 9.81s | Training: loss=0.0659, iou=0.9432, dice=0.9707
# Epoch 517 of 1000 took 9.82s | Training: loss=0.0882, iou=0.9344, dice=0.9660
# Epoch 518 of 1000 took 9.86s | Training: loss=0.0656, iou=0.9425, dice=0.9704
# Epoch 519 of 1000 took 9.82s | Training: loss=0.0611, iou=0.9463, dice=0.9724
# Epoch 520 of 1000 took 9.81s | Training: loss=0.0916, iou=0.9325, dice=0.9646
# Validation: loss=0.1945, iou=0.8770, dice=0.9344
# New best model found with validation loss 0.1945, saving model...
# Epoch 521 of 1000 took 9.80s | Training: loss=0.0644, iou=0.9431, dice=0.9707
# Epoch 522 of 1000 took 9.86s | Training: loss=0.0795, iou=0.9409, dice=0.9694
# Epoch 523 of 1000 took 9.88s | Training: loss=0.0613, iou=0.9449, dice=0.9717
# Epoch 524 of 1000 took 9.83s | Training: loss=0.0744, iou=0.9405, dice=0.9692
# Epoch 525 of 1000 took 9.79s | Training: loss=0.0613, iou=0.9464, dice=0.9724
# Epoch 526 of 1000 took 9.80s | Training: loss=0.0710, iou=0.9414, dice=0.9697
# Epoch 527 of 1000 took 9.88s | Training: loss=0.0728, iou=0.9440, dice=0.9711
# Epoch 528 of 1000 took 9.81s | Training: loss=0.0612, iou=0.9472, dice=0.9729
# Epoch 529 of 1000 took 9.81s | Training: loss=0.0548, iou=0.9516, dice=0.9752
# Epoch 530 of 1000 took 9.81s | Training: loss=0.0750, iou=0.9422, dice=0.9701
# Epoch 531 of 1000 took 9.81s | Training: loss=0.0606, iou=0.9480, dice=0.9733
# Epoch 532 of 1000 took 9.79s | Training: loss=0.0537, iou=0.9541, dice=0.9765
# Epoch 533 of 1000 took 9.82s | Training: loss=0.0720, iou=0.9451, dice=0.9717
# Epoch 534 of 1000 took 9.79s | Training: loss=0.0678, iou=0.9490, dice=0.9738
# Epoch 535 of 1000 took 9.82s | Training: loss=0.0641, iou=0.9462, dice=0.9723
# Epoch 536 of 1000 took 9.85s | Training: loss=0.0550, iou=0.9495, dice=0.9741
# Epoch 537 of 1000 took 9.84s | Training: loss=0.0614, iou=0.9471, dice=0.9728
# Epoch 538 of 1000 took 10.13s | Training: loss=0.0870, iou=0.9322, dice=0.9647
# Epoch 539 of 1000 took 9.81s | Training: loss=0.0515, iou=0.9535, dice=0.9762
# Epoch 540 of 1000 took 9.82s | Training: loss=0.0530, iou=0.9501, dice=0.9744
# Validation: loss=0.1786, iou=0.8764, dice=0.9341
# New best model found with validation loss 0.1786, saving model...
# Epoch 541 of 1000 took 9.82s | Training: loss=0.0711, iou=0.9407, dice=0.9691
# Epoch 542 of 1000 took 9.84s | Training: loss=0.0622, iou=0.9485, dice=0.9735
# Epoch 543 of 1000 took 9.84s | Training: loss=0.0512, iou=0.9543, dice=0.9766
# Epoch 544 of 1000 took 9.81s | Training: loss=0.0523, iou=0.9530, dice=0.9759
# Epoch 545 of 1000 took 9.81s | Training: loss=0.1560, iou=0.8621, dice=0.8999
# Epoch 546 of 1000 took 9.82s | Training: loss=0.1034, iou=0.9112, dice=0.9528
# Epoch 547 of 1000 took 9.84s | Training: loss=0.0682, iou=0.9301, dice=0.9637
# Epoch 548 of 1000 took 9.88s | Training: loss=0.0647, iou=0.9275, dice=0.9623
# Epoch 549 of 1000 took 9.79s | Training: loss=0.0841, iou=0.9247, dice=0.9606
# Epoch 550 of 1000 took 9.82s | Training: loss=0.0636, iou=0.9406, dice=0.9693
# Epoch 551 of 1000 took 9.81s | Training: loss=0.0606, iou=0.9437, dice=0.9710
# Epoch 552 of 1000 took 9.81s | Training: loss=0.0541, iou=0.9459, dice=0.9721
# Epoch 553 of 1000 took 9.80s | Training: loss=0.0626, iou=0.9359, dice=0.9668
# Epoch 554 of 1000 took 9.80s | Training: loss=0.0565, iou=0.9399, dice=0.9690
# Epoch 555 of 1000 took 9.80s | Training: loss=0.0548, iou=0.9477, dice=0.9731
# Epoch 556 of 1000 took 9.83s | Training: loss=0.0721, iou=0.9380, dice=0.9679
# Epoch 557 of 1000 took 9.80s | Training: loss=0.0576, iou=0.9470, dice=0.9727
# Epoch 558 of 1000 took 9.81s | Training: loss=0.0551, iou=0.9501, dice=0.9744
# Epoch 559 of 1000 took 9.79s | Training: loss=0.0502, iou=0.9519, dice=0.9754
# Epoch 560 of 1000 took 9.80s | Training: loss=0.0541, iou=0.9507, dice=0.9747
# Validation: loss=0.1665, iou=0.8673, dice=0.9288
# New best model found with validation loss 0.1665, saving model...
# Epoch 561 of 1000 took 9.88s | Training: loss=0.0488, iou=0.9552, dice=0.9771
# Epoch 562 of 1000 took 9.79s | Training: loss=0.0585, iou=0.9497, dice=0.9742
# Epoch 563 of 1000 took 9.80s | Training: loss=0.0491, iou=0.9547, dice=0.9768
# Epoch 564 of 1000 took 9.80s | Training: loss=0.0518, iou=0.9542, dice=0.9766
# Epoch 565 of 1000 took 9.79s | Training: loss=0.0429, iou=0.9577, dice=0.9784
# Epoch 566 of 1000 took 9.84s | Training: loss=0.0602, iou=0.9484, dice=0.9734
# Epoch 567 of 1000 took 9.80s | Training: loss=0.0548, iou=0.9526, dice=0.9757
# Epoch 568 of 1000 took 9.80s | Training: loss=0.0483, iou=0.9540, dice=0.9765
# Epoch 569 of 1000 took 9.79s | Training: loss=0.0470, iou=0.9543, dice=0.9766
# ...
# Epoch 809 of 1000 took 9.79s | Training: loss=0.0368, iou=0.9500, dice=0.9744
# Epoch 810 of 1000 took 9.85s | Training: loss=0.0312, iou=0.9581, dice=0.9786
# Epoch 811 of 1000 took 9.81s | Training: loss=0.0342, iou=0.9539, dice=0.9764
# Epoch 812 of 1000 took 9.86s | Training: loss=0.0323, iou=0.9575, dice=0.9783
# Epoch 813 of 1000 took 9.81s | Training: loss=0.0393, iou=0.9497, dice=0.9741
# Epoch 814 of 1000 took 9.82s | Training: loss=0.0374, iou=0.9486, dice=0.9736
# Epoch 815 of 1000 took 9.89s | Training: loss=0.0421, iou=0.9437, dice=0.9710
# Epoch 816 of 1000 took 9.83s | Training: loss=0.0329, iou=0.9555, dice=0.9772
# Epoch 817 of 1000 took 9.80s | Training: loss=0.0402, iou=0.9487, dice=0.9734
# Epoch 818 of 1000 took 9.88s | Training: loss=0.0324, iou=0.9558, dice=0.9774
# Epoch 819 of 1000 took 9.85s | Training: loss=0.0365, iou=0.9522, dice=0.9755
# Epoch 820 of 1000 took 9.82s | Training: loss=0.0328, iou=0.9567, dice=0.9778
# Validation: loss=0.0999, iou=0.8705, dice=0.9307
# New best model found with validation loss 0.0999, saving model...
# Epoch 821 of 1000 took 9.80s | Training: loss=0.0334, iou=0.9560, dice=0.9774
# Epoch 822 of 1000 took 9.80s | Training: loss=0.0313, iou=0.9595, dice=0.9793
# Epoch 823 of 1000 took 9.79s | Training: loss=0.0288, iou=0.9615, dice=0.9804
# Epoch 824 of 1000 took 9.79s | Training: loss=0.0404, iou=0.9486, dice=0.9736
# Epoch 825 of 1000 took 9.87s | Training: loss=0.0336, iou=0.9555, dice=0.9772
# Epoch 826 of 1000 took 9.81s | Training: loss=0.0457, iou=0.9477, dice=0.9728
# Epoch 827 of 1000 took 9.79s | Training: loss=0.0281, iou=0.9624, dice=0.9808
# Epoch 828 of 1000 took 9.81s | Training: loss=0.0293, iou=0.9616, dice=0.9804
# Epoch 829 of 1000 took 9.89s | Training: loss=0.0274, iou=0.9632, dice=0.9812
# Epoch 830 of 1000 took 9.85s | Training: loss=0.0298, iou=0.9613, dice=0.9802
# Epoch 831 of 1000 took 9.83s | Training: loss=0.0255, iou=0.9663, dice=0.9828
# Epoch 832 of 1000 took 9.83s | Training: loss=0.0312, iou=0.9589, dice=0.9790
# Epoch 833 of 1000 took 9.85s | Training: loss=0.0272, iou=0.9634, dice=0.9814
# Epoch 834 of 1000 took 9.82s | Training: loss=0.0282, iou=0.9627, dice=0.9810
# Epoch 835 of 1000 took 9.85s | Training: loss=0.0291, iou=0.9613, dice=0.9803
# Epoch 836 of 1000 took 9.82s | Training: loss=0.0268, iou=0.9645, dice=0.9819
# Epoch 837 of 1000 took 9.86s | Training: loss=0.0309, iou=0.9586, dice=0.9789
# Epoch 838 of 1000 took 9.85s | Training: loss=0.0312, iou=0.9594, dice=0.9792
# Epoch 839 of 1000 took 9.82s | Training: loss=0.0290, iou=0.9618, dice=0.9805
# Epoch 840 of 1000 took 9.81s | Training: loss=0.0336, iou=0.9554, dice=0.9771
# Validation: loss=0.0948, iou=0.8737, dice=0.9325
# New best model found with validation loss 0.0948, saving model...
# Epoch 841 of 1000 took 9.82s | Training: loss=0.0282, iou=0.9624, dice=0.9809
# Epoch 842 of 1000 took 9.88s | Training: loss=0.0359, iou=0.9546, dice=0.9766
# Epoch 843 of 1000 took 9.82s | Training: loss=0.0281, iou=0.9625, dice=0.9809
# Epoch 844 of 1000 took 9.78s | Training: loss=0.0294, iou=0.9608, dice=0.9800
# Epoch 845 of 1000 took 9.85s | Training: loss=0.0266, iou=0.9643, dice=0.9818
# Epoch 846 of 1000 took 9.87s | Training: loss=0.0359, iou=0.9560, dice=0.9774
# Epoch 847 of 1000 took 9.80s | Training: loss=0.0391, iou=0.9487, dice=0.9736
# Epoch 848 of 1000 took 9.83s | Training: loss=0.0289, iou=0.9610, dice=0.9801
# Epoch 849 of 1000 took 9.85s | Training: loss=0.0265, iou=0.9643, dice=0.9818
# Epoch 850 of 1000 took 9.82s | Training: loss=0.0322, iou=0.9573, dice=0.9781
# Epoch 851 of 1000 took 9.80s | Training: loss=0.0294, iou=0.9602, dice=0.9797
# Epoch 852 of 1000 took 9.83s | Training: loss=0.0253, iou=0.9659, dice=0.9826
# Epoch 853 of 1000 took 9.82s | Training: loss=0.0267, iou=0.9637, dice=0.9815
# Epoch 854 of 1000 took 9.82s | Training: loss=0.0614, iou=0.9346, dice=0.9643
# Epoch 855 of 1000 took 9.89s | Training: loss=0.0599, iou=0.9176, dice=0.9569
# Epoch 856 of 1000 took 9.83s | Training: loss=0.0462, iou=0.9349, dice=0.9663
# Epoch 857 of 1000 took 9.81s | Training: loss=0.0409, iou=0.9448, dice=0.9716
# Epoch 858 of 1000 took 9.84s | Training: loss=0.0446, iou=0.9374, dice=0.9676
# Epoch 859 of 1000 took 9.81s | Training: loss=0.0365, iou=0.9507, dice=0.9747
# Epoch 860 of 1000 took 9.86s | Training: loss=0.0339, iou=0.9529, dice=0.9759
# Validation: loss=0.0922, iou=0.8710, dice=0.9310
# New best model found with validation loss 0.0922, saving model...
# Epoch 861 of 1000 took 9.88s | Training: loss=0.0302, iou=0.9585, dice=0.9788
# Epoch 862 of 1000 took 9.81s | Training: loss=0.0288, iou=0.9602, dice=0.9797
# Epoch 863 of 1000 took 9.84s | Training: loss=0.0289, iou=0.9615, dice=0.9803
# Epoch 864 of 1000 took 9.82s | Training: loss=0.0291, iou=0.9605, dice=0.9798
# Epoch 865 of 1000 took 9.87s | Training: loss=0.0250, iou=0.9660, dice=0.9827
# Epoch 866 of 1000 took 9.79s | Training: loss=0.0328, iou=0.9556, dice=0.9772
# Epoch 867 of 1000 took 9.81s | Training: loss=0.0258, iou=0.9649, dice=0.9821
# Epoch 868 of 1000 took 9.88s | Training: loss=0.0260, iou=0.9650, dice=0.9822
# Epoch 869 of 1000 took 9.83s | Training: loss=0.0325, iou=0.9554, dice=0.9770
# Epoch 870 of 1000 took 9.80s | Training: loss=0.0253, iou=0.9655, dice=0.9824
# Epoch 871 of 1000 took 9.83s | Training: loss=0.0334, iou=0.9536, dice=0.9760
# Epoch 872 of 1000 took 9.83s | Training: loss=0.0257, iou=0.9649, dice=0.9821
# Epoch 873 of 1000 took 9.81s | Training: loss=0.0264, iou=0.9638, dice=0.9815
# Epoch 874 of 1000 took 9.80s | Training: loss=0.0328, iou=0.9569, dice=0.9779
# Epoch 875 of 1000 took 9.80s | Training: loss=0.0274, iou=0.9630, dice=0.9811
# Epoch 876 of 1000 took 9.81s | Training: loss=0.0264, iou=0.9640, dice=0.9817
# Epoch 877 of 1000 took 9.81s | Training: loss=0.0271, iou=0.9626, dice=0.9809
# Epoch 878 of 1000 took 9.92s | Training: loss=0.0258, iou=0.9645, dice=0.9819
# Epoch 879 of 1000 took 9.81s | Training: loss=0.0228, iou=0.9692, dice=0.9844
# Epoch 880 of 1000 took 9.80s | Training: loss=0.0288, iou=0.9611, dice=0.9802
# Validation: loss=0.0896, iou=0.8757, dice=0.9337
# New best model found with validation loss 0.0896, saving model...
# Epoch 881 of 1000 took 9.79s | Training: loss=0.0257, iou=0.9647, dice=0.9820
# Epoch 882 of 1000 took 9.86s | Training: loss=0.0287, iou=0.9615, dice=0.9802
# Epoch 883 of 1000 took 9.81s | Training: loss=0.0352, iou=0.9514, dice=0.9750
# Epoch 884 of 1000 took 9.83s | Training: loss=0.0280, iou=0.9605, dice=0.9798
# Epoch 885 of 1000 took 9.88s | Training: loss=0.0265, iou=0.9631, dice=0.9812
# Epoch 886 of 1000 took 9.81s | Training: loss=0.0242, iou=0.9667, dice=0.9831
# Epoch 887 of 1000 took 9.84s | Training: loss=0.0319, iou=0.9602, dice=0.9797
# Epoch 888 of 1000 took 9.81s | Training: loss=0.0243, iou=0.9671, dice=0.9833
# Epoch 889 of 1000 took 9.79s | Training: loss=0.0255, iou=0.9657, dice=0.9825
# Epoch 890 of 1000 took 9.80s | Training: loss=0.0256, iou=0.9648, dice=0.9820
# Epoch 891 of 1000 took 9.82s | Training: loss=0.0223, iou=0.9696, dice=0.9846
# Epoch 892 of 1000 took 9.78s | Training: loss=0.0218, iou=0.9712, dice=0.9854
# Epoch 893 of 1000 took 9.86s | Training: loss=0.0244, iou=0.9666, dice=0.9830
# Epoch 894 of 1000 took 9.81s | Training: loss=0.0252, iou=0.9652, dice=0.9823
# Epoch 895 of 1000 took 9.80s | Training: loss=0.0217, iou=0.9703, dice=0.9849
# Epoch 896 of 1000 took 9.79s | Training: loss=0.0283, iou=0.9609, dice=0.9800
# Epoch 897 of 1000 took 9.82s | Training: loss=0.0250, iou=0.9651, dice=0.9823
# Epoch 898 of 1000 took 9.84s | Training: loss=0.0267, iou=0.9636, dice=0.9815
# Epoch 899 of 1000 took 9.82s | Training: loss=0.0258, iou=0.9638, dice=0.9816
# Epoch 900 of 1000 took 9.84s | Training: loss=0.0251, iou=0.9652, dice=0.9823
# Validation: loss=0.0866, iou=0.8771, dice=0.9344
# New best model found with validation loss 0.0866, saving model...
# Epoch 901 of 1000 took 9.83s | Training: loss=0.0248, iou=0.9660, dice=0.9827
# Epoch 902 of 1000 took 9.83s | Training: loss=0.0253, iou=0.9666, dice=0.9830
# Epoch 903 of 1000 took 9.79s | Training: loss=0.0227, iou=0.9686, dice=0.9840
# Epoch 904 of 1000 took 9.82s | Training: loss=0.0255, iou=0.9649, dice=0.9821
# Epoch 905 of 1000 took 9.82s | Training: loss=0.0268, iou=0.9632, dice=0.9812
# Epoch 906 of 1000 took 9.82s | Training: loss=0.0270, iou=0.9632, dice=0.9812
# Epoch 907 of 1000 took 9.82s | Training: loss=0.0282, iou=0.9620, dice=0.9806
# Epoch 908 of 1000 took 9.85s | Training: loss=0.0274, iou=0.9619, dice=0.9806
# Epoch 909 of 1000 took 9.82s | Training: loss=0.0236, iou=0.9681, dice=0.9838
# Epoch 910 of 1000 took 9.81s | Training: loss=0.0241, iou=0.9662, dice=0.9828
# Epoch 911 of 1000 took 9.82s | Training: loss=0.0243, iou=0.9664, dice=0.9829
# Epoch 912 of 1000 took 9.80s | Training: loss=0.0226, iou=0.9684, dice=0.9839
# Epoch 913 of 1000 took 9.81s | Training: loss=0.0229, iou=0.9686, dice=0.9841
# Epoch 914 of 1000 took 9.96s | Training: loss=0.0275, iou=0.9628, dice=0.9810
# Epoch 915 of 1000 took 9.88s | Training: loss=0.0286, iou=0.9643, dice=0.9818
# Epoch 916 of 1000 took 9.82s | Training: loss=0.0237, iou=0.9669, dice=0.9831
# Epoch 917 of 1000 took 9.83s | Training: loss=0.0226, iou=0.9685, dice=0.9840
# Epoch 918 of 1000 took 9.88s | Training: loss=0.0229, iou=0.9680, dice=0.9838
# Epoch 919 of 1000 took 9.88s | Training: loss=0.0254, iou=0.9657, dice=0.9826
# Epoch 920 of 1000 took 9.83s | Training: loss=0.0240, iou=0.9667, dice=0.9831
# Validation: loss=0.0848, iou=0.8755, dice=0.9336
# New best model found with validation loss 0.0848, saving model...
# Epoch 921 of 1000 took 9.77s | Training: loss=0.0286, iou=0.9613, dice=0.9802
# Epoch 922 of 1000 took 9.81s | Training: loss=0.0430, iou=0.9423, dice=0.9699
# Epoch 923 of 1000 took 9.83s | Training: loss=0.0345, iou=0.9491, dice=0.9738
# Epoch 924 of 1000 took 9.81s | Training: loss=0.0309, iou=0.9557, dice=0.9773
# Epoch 925 of 1000 took 9.81s | Training: loss=0.0294, iou=0.9578, dice=0.9784
# Epoch 926 of 1000 took 9.85s | Training: loss=0.0250, iou=0.9642, dice=0.9818
# Epoch 927 of 1000 took 9.82s | Training: loss=0.0280, iou=0.9621, dice=0.9806
# Epoch 928 of 1000 took 9.84s | Training: loss=0.0249, iou=0.9650, dice=0.9821
# Epoch 929 of 1000 took 9.85s | Training: loss=0.0233, iou=0.9673, dice=0.9834
# Epoch 930 of 1000 took 9.79s | Training: loss=0.0259, iou=0.9640, dice=0.9816
# Epoch 931 of 1000 took 9.81s | Training: loss=0.0279, iou=0.9613, dice=0.9802
# Epoch 932 of 1000 took 9.83s | Training: loss=0.0252, iou=0.9649, dice=0.9821
# Epoch 933 of 1000 took 9.82s | Training: loss=0.0246, iou=0.9659, dice=0.9826
# Epoch 934 of 1000 took 9.89s | Training: loss=0.0271, iou=0.9636, dice=0.9814
# Epoch 935 of 1000 took 9.84s | Training: loss=0.0235, iou=0.9666, dice=0.9830
# Epoch 936 of 1000 took 9.83s | Training: loss=0.0253, iou=0.9641, dice=0.9817
# Epoch 937 of 1000 took 9.82s | Training: loss=0.0259, iou=0.9642, dice=0.9818
# Epoch 938 of 1000 took 9.83s | Training: loss=0.0229, iou=0.9676, dice=0.9835
# Epoch 939 of 1000 took 9.92s | Training: loss=0.0241, iou=0.9660, dice=0.9827
# Epoch 940 of 1000 took 9.79s | Training: loss=0.0232, iou=0.9674, dice=0.9834
# Validation: loss=0.0834, iou=0.8749, dice=0.9332
# New best model found with validation loss 0.0834, saving model...
# Epoch 941 of 1000 took 9.83s | Training: loss=0.0204, iou=0.9716, dice=0.9856
# Epoch 942 of 1000 took 9.78s | Training: loss=0.0212, iou=0.9706, dice=0.9851
# Epoch 943 of 1000 took 9.79s | Training: loss=0.0202, iou=0.9720, dice=0.9858
# Epoch 944 of 1000 took 9.84s | Training: loss=0.0241, iou=0.9676, dice=0.9835
# Epoch 945 of 1000 took 9.90s | Training: loss=0.0213, iou=0.9702, dice=0.9849
# Epoch 946 of 1000 took 9.79s | Training: loss=0.0229, iou=0.9677, dice=0.9836
# Epoch 947 of 1000 took 9.81s | Training: loss=0.0230, iou=0.9676, dice=0.9835
# Epoch 948 of 1000 took 9.80s | Training: loss=0.0322, iou=0.9561, dice=0.9773
# Epoch 949 of 1000 took 9.81s | Training: loss=0.0236, iou=0.9664, dice=0.9829
# Epoch 950 of 1000 took 9.81s | Training: loss=0.0216, iou=0.9693, dice=0.9844
# Epoch 951 of 1000 took 9.80s | Training: loss=0.0216, iou=0.9694, dice=0.9845
# Epoch 952 of 1000 took 9.80s | Training: loss=0.0206, iou=0.9713, dice=0.9854
# Epoch 953 of 1000 took 9.81s | Training: loss=0.0226, iou=0.9683, dice=0.9839
# Epoch 954 of 1000 took 9.86s | Training: loss=0.0456, iou=0.9414, dice=0.9684
# Epoch 955 of 1000 took 9.88s | Training: loss=0.0313, iou=0.9566, dice=0.9777
# Epoch 956 of 1000 took 9.86s | Training: loss=0.0251, iou=0.9641, dice=0.9817
# Epoch 957 of 1000 took 9.91s | Training: loss=0.0233, iou=0.9671, dice=0.9833
# Epoch 958 of 1000 took 9.86s | Training: loss=0.0354, iou=0.9574, dice=0.9781
# Epoch 959 of 1000 took 9.87s | Training: loss=0.0282, iou=0.9596, dice=0.9793
# Epoch 960 of 1000 took 9.84s | Training: loss=0.0240, iou=0.9663, dice=0.9829
# Validation: loss=0.0909, iou=0.8764, dice=0.9341
# Epoch 961 of 1000 took 9.83s | Training: loss=0.0249, iou=0.9652, dice=0.9823
# Epoch 962 of 1000 took 9.79s | Training: loss=0.0226, iou=0.9679, dice=0.9837
# Epoch 963 of 1000 took 9.79s | Training: loss=0.0253, iou=0.9631, dice=0.9812
# Epoch 964 of 1000 took 9.80s | Training: loss=0.0271, iou=0.9604, dice=0.9798
# Epoch 965 of 1000 took 9.80s | Training: loss=0.0437, iou=0.9380, dice=0.9667
# Epoch 966 of 1000 took 9.80s | Training: loss=0.0349, iou=0.9476, dice=0.9730
# Epoch 967 of 1000 took 9.80s | Training: loss=0.0274, iou=0.9598, dice=0.9795
# Epoch 968 of 1000 took 9.81s | Training: loss=0.0288, iou=0.9580, dice=0.9785
# Epoch 969 of 1000 took 9.80s | Training: loss=0.0260, iou=0.9620, dice=0.9806
# Epoch 970 of 1000 took 9.81s | Training: loss=0.0250, iou=0.9644, dice=0.9819
# Epoch 971 of 1000 took 9.83s | Training: loss=0.0234, iou=0.9664, dice=0.9829
# Epoch 972 of 1000 took 9.79s | Training: loss=0.0256, iou=0.9627, dice=0.9810
# Epoch 973 of 1000 took 9.82s | Training: loss=0.0372, iou=0.9504, dice=0.9742
# Epoch 974 of 1000 took 9.89s | Training: loss=0.0241, iou=0.9648, dice=0.9820
# Epoch 975 of 1000 took 9.92s | Training: loss=0.0287, iou=0.9603, dice=0.9797
# Epoch 976 of 1000 took 9.99s | Training: loss=0.0258, iou=0.9626, dice=0.9809
# Epoch 977 of 1000 took 9.82s | Training: loss=0.0226, iou=0.9680, dice=0.9837
# Epoch 978 of 1000 took 9.83s | Training: loss=0.0252, iou=0.9633, dice=0.9813
# Epoch 979 of 1000 took 9.79s | Training: loss=0.0211, iou=0.9699, dice=0.9847
# Epoch 980 of 1000 took 9.79s | Training: loss=0.0234, iou=0.9658, dice=0.9826
# Validation: loss=0.0817, iou=0.8768, dice=0.9343
# New best model found with validation loss 0.0817, saving model...
# Epoch 981 of 1000 took 9.84s | Training: loss=0.0256, iou=0.9638, dice=0.9816
# Epoch 982 of 1000 took 9.81s | Training: loss=0.0225, iou=0.9675, dice=0.9835
# Epoch 983 of 1000 took 9.88s | Training: loss=0.0232, iou=0.9666, dice=0.9830
# Epoch 984 of 1000 took 9.79s | Training: loss=0.0232, iou=0.9663, dice=0.9829
# Epoch 985 of 1000 took 9.84s | Training: loss=0.0212, iou=0.9696, dice=0.9846
# Epoch 986 of 1000 took 9.79s | Training: loss=0.0197, iou=0.9719, dice=0.9857
# Epoch 987 of 1000 took 9.82s | Training: loss=0.0201, iou=0.9712, dice=0.9854
# Epoch 988 of 1000 took 9.80s | Training: loss=0.0251, iou=0.9643, dice=0.9818
# Epoch 989 of 1000 took 9.85s | Training: loss=0.0204, iou=0.9708, dice=0.9852
# Epoch 990 of 1000 took 9.81s | Training: loss=0.0222, iou=0.9683, dice=0.9839
# Epoch 991 of 1000 took 9.94s | Training: loss=0.0232, iou=0.9664, dice=0.9829
# Epoch 992 of 1000 took 9.85s | Training: loss=0.0202, iou=0.9710, dice=0.9853
# Epoch 993 of 1000 took 9.85s | Training: loss=0.0220, iou=0.9680, dice=0.9837
# Epoch 994 of 1000 took 9.80s | Training: loss=0.0212, iou=0.9697, dice=0.9846
# Epoch 995 of 1000 took 9.87s | Training: loss=0.0246, iou=0.9638, dice=0.9815
# Epoch 996 of 1000 took 9.79s | Training: loss=0.0265, iou=0.9608, dice=0.9800
# Epoch 997 of 1000 took 9.79s | Training: loss=0.0234, iou=0.9658, dice=0.9826
# Epoch 998 of 1000 took 9.81s | Training: loss=0.0202, iou=0.9709, dice=0.9852
# Epoch 999 of 1000 took 9.78s | Training: loss=0.0254, iou=0.9628, dice=0.9810
# Epoch 1000 of 1000 took 9.81s | Training: loss=0.0270, iou=0.9613, dice=0.9802
# Validation: loss=0.0839, iou=0.8723, dice=0.9317

# %%
trained_model, results_train, results_val = results_train

# %%
import pandas as pd
import seaborn as sns

# Create DataFrames for easier plotting with Seaborn
df_train_loss = pd.DataFrame({'Epoch': range(len(results_train['loss'])), 'Value': results_train['loss'], 'Metric': 'Loss', 'Type': 'Train'})
df_val_loss = pd.DataFrame({'Epoch': [validation_freq * (1 + x) for x in range(len(results_val['loss']))], 'Value': results_val['loss'], 'Metric': 'Loss', 'Type': 'Validation'})

df_train_dice = pd.DataFrame({'Epoch': range(len(results_train['dice'])), 'Value': results_train['dice'], 'Metric': 'Dice', 'Type': 'Train'})
df_val_dice = pd.DataFrame({'Epoch': [validation_freq * (1 + x) for x in range(len(results_val['dice']))], 'Value': results_val['dice'], 'Metric': 'Dice', 'Type': 'Validation'})

df_train_iou = pd.DataFrame({'Epoch': range(len(results_train['iou'])), 'Value': results_train['iou'], 'Metric': 'IoU', 'Type': 'Train'})
df_val_iou = pd.DataFrame({'Epoch': [validation_freq * (1 + x) for x in range(len(results_val['iou']))], 'Value': results_val['iou'], 'Metric': 'IoU', 'Type': 'Validation'})

# Combine the DataFrames
df = pd.concat([df_train_loss, df_val_loss, df_train_dice, df_val_dice, df_train_iou, df_val_iou])

# Plot using Seaborn
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

sns.lineplot(data=df[df['Metric'] == 'Loss'], x='Epoch', y='Value', hue='Type', ax=axs[0])
axs[0].set_title('Training and Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')

sns.lineplot(data=df[df['Metric'] == 'Dice'], x='Epoch', y='Value', hue='Type', ax=axs[1])
axs[1].set_title('Training and Validation Dice')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Dice')

sns.lineplot(data=df[df['Metric'] == 'IoU'], x='Epoch', y='Value', hue='Type', ax=axs[2])
axs[2].set_title('Training and Validation IoU')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('IoU')

plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
torch.save(trained_model.state_dict(), 'cuboid_unet1000epochs.pth')
import joblib

joblib.dump(trained_model, 'cuboid_unet1000epochs.pkl')
# Out:
# ['cuboid_unet1000epochs.pkl']

# %% [markdown]
# ## Evaluation of model

# %%
image, label = val_dataset[0]
image = image.unsqueeze(0)
image = image.to(device)
with torch.no_grad():
    pred_logits = patched_forward(trained_model, image, patch_size, 'cuda')
pred = torch.sigmoid(pred_logits)
pred = pred.squeeze(0, 1)
image = image.squeeze(0, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select the 50th slice along the first axis
slice_index = 60

image_slice = image[slice_index].cpu().numpy()
pred_slice = pred[slice_index].cpu().numpy()
label_slice = label[slice_index].cpu().numpy()

# Create the figure and the axes with 3 subplots side by side
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot the original image slice
axs[0].imshow(image_slice, cmap='gray')
axs[0].set_title('Image Slice')
axs[0].axis('off')

# Plot the prediction slice
axs[1].imshow(pred_slice, vmin=0, vmax=1, cmap='Reds')
axs[1].set_title('Prediction Slice')
axs[1].axis('off')

# Plot the label slice
axs[2].imshow(label_slice, cmap='Greens')
axs[2].set_title('Label Slice')
axs[2].axis('off')

# Display the figure
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select the 50th slice along the first axis
slice_index = 60
image_slice = image[slice_index].cpu().numpy()
pred_slice = pred[slice_index].cpu().numpy()
label_slice = label[slice_index].cpu().numpy()

pred_slice = (pred_slice > 0.5).astype(np.float32)

# Normalize image slice for visualization (if needed)
image_slice = (image_slice - image_slice.min()) / (image_slice.max() - image_slice.min())

# Create an RGB image from the grayscale slice
image_rgb = np.stack([image_slice]*3, axis=-1)

# Create solid colors for the prediction and label overlays
red_overlay = np.zeros_like(image_rgb)
red_overlay[..., 0] = 1  # Red color for prediction

green_overlay = np.zeros_like(image_rgb)
green_overlay[..., 1] = 1  # Green color for label

# Create the prediction and label masks (expanding dims for compatibility)
pred_mask = np.expand_dims(pred_slice, axis=-1)
label_mask = np.expand_dims(label_slice, axis=-1)

# Set the opacity for the overlays (50% opacity)
opacity = 0.5

# Blend the solid color with the original image using the mask
# First, apply the red overlay for predictions
overlay_image = image_rgb * (1 - pred_mask * opacity) + red_overlay * pred_mask * opacity

# Then, apply the green overlay for labels
overlay_image = overlay_image * (1 - label_mask * opacity) + green_overlay * label_mask * opacity

# Plot the resulting image with the 50% opacity overlays
plt.figure(figsize=(10, 10))
plt.imshow(overlay_image)
plt.title('Image with 50% Opacity Prediction and Label Overlays')
plt.axis('off')
plt.show()
