# %% [markdown]
# ## Imports

# %%
import nibabel as nib

# %%
import os
import io
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import SimpleITK as sitk
import imageio
from PIL import Image
from IPython.display import display, Image as IPImage

# %% [markdown]
# ## Dataset + preprocessing / augmentation

# %% [markdown]
# Rotating, Gaussian blur, normalization per patient (over full volume), crop image to remove deadspace
# Flipping doesn not have a great effect on tumor segmentation
#
# **Tips for training 3d-UNet:**
# * Before training make sure that the data you want to train is normalized and resized for the model.
# * Main purpose of normalization is to make computation efficient by reducing values between 0 to 1 as well as removing noise in data.
# * Images used for medical image segmentation are high-resolution three-dimensional (3D) images. To reduce the memory usage on GPU’s, we can use a patch-based method, which divides a large image into small patches and trains the models with these small patches.
#
# **TODO:**
# * Bestäm ett rimligt område för crop baserat på visualisering av bilder

# %%
import sys
import glob

# %%
'''import zipfile
zip_path = 'Task02_Heart.zip'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('data')
'''

# %%
# Load images in directories
data_dir = "data/Task02_Heart"

train_images = sorted(glob.glob(os.path.join(data_dir, "imagesTr", "*.nii.gz")))
train_labels = sorted(glob.glob(os.path.join(data_dir, "labelsTr", "*.nii.gz")))
train_data_dict = [{"image": image_name, "label": label_name} for image_name, label_name in zip(train_images, train_labels)]

val_images = sorted(glob.glob(os.path.join(data_dir, "imagesVl", "*.nii.gz")))
val_labels = sorted(glob.glob(os.path.join(data_dir, "labelsVl", "*.nii.gz")))
val_data_dict = [{"image": image_name, "label": label_name} for image_name, label_name in zip(val_images, val_labels)]

# Display first image and label in train dict
train_data_dict[15]
# Out:
# {'image': 'data/Task02_Heart/imagesTr/la_023.nii.gz',
#  'label': 'data/Task02_Heart/labelsTr/la_023.nii.gz'}

# %% [markdown]
# ### Transforms

# %%
# !pip install monai

# %%
# TODO, take slice index as input
from monai.transforms import Rotated, RandRotated, RandZoomd, RandAffined, RandGaussianNoised, RandGaussianSmoothd

def visualize_transform(data_dict, img_idx=0, transform=None):
    image, label = data_dict[img_idx]["image"], data_dict[img_idx]["label"]

    image_array = sitk.GetArrayFromImage(sitk.ReadImage(image))
    label_array = sitk.GetArrayFromImage(sitk.ReadImage(label))

    data = {"image": image_array, "label": label_array}

    # Apply transform if provided
    if transform:
        transformed = transform(data)
        image_array, label_array = transformed["image"], transformed["label"]

    mid_slice = image_array.shape[0] // 2
    slice_img = image_array[mid_slice, :, :]
    slice_label = label_array[mid_slice, :, :]
    flipped_slice_img = np.flip(slice_img, axis=(0, 1))
    flipped_slice_label = np.flip(slice_label, axis=(0, 1))

    fig, axes = plt.subplots(1, 2, figsize=(6, 3))
    axes[0].imshow(flipped_slice_img, cmap='gray')
    axes[0].set_title(f'Transformed image (slice: {mid_slice})')
    axes[0].axis('off')

    axes[1].imshow(flipped_slice_label, cmap='gray')
    axes[1].set_title(f'Transformed label (slice: {mid_slice})')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()

# TODO - FIX multiple transforms
#transform = Rotated(keys=["image","label"], angle=0.2, mode=["bilinear", "nearest"])
transform = RandRotated(keys=["image","label"], prob=0.4, range_x=[-0.3, 0.3], mode=["bilinear", "nearest"])
#transform = RandZoomd(keys=["image","label"], prob=0.4, min_zoom=1.1, max_zoom=1.5, mode=["area", "nearest"])
#transform =RandAffined(keys=["image","label"], prob=0.5, shear_range=(0.4,0.4), mode=["bilinear", "nearest"],padding_mode="zeros")
#transform = RandGaussianNoised(keys=["image"], prob=0.9, mean=0, std=0.1)
#transform = RandGaussianSmoothd(keys="image",prob=1.0, sigma_x=(0,3))
visualize_transform(train_data_dict, img_idx=0, transform=transform)

# %% [markdown]
# ### Dataset and loader

# %%
import torch
from glob import glob
from torch.utils.data import Dataset
import SimpleITK as sitk
import numpy as np

class TrainDataset(Dataset):
    """
    require_target = True => all returned patches contain atleast some of the target
    preoad_all_images = True => all images are loaded into memory at the start
    """

    def __init__(self, data_dir, labels_dir, patch_size, require_target=False,transform=None, preload_all_images=True, num_patches_per_image=1):
        self.patch_size = patch_size
        self.transform = transform
        self.require_target = require_target

        self.data_paths = sorted(glob(data_dir + '/*.nii.gz'))
        self.label_paths = sorted(glob(labels_dir + '/*.nii.gz'))

        self.preload_all_images = preload_all_images
        if preload_all_images:
            self.data = {path_: sitk.GetArrayFromImage(sitk.ReadImage(path_)).astype('float32') for path_ in self.data_paths}
            self.labels = {path_: sitk.GetArrayFromImage(sitk.ReadImage(path_)).astype('int64') for path_ in self.label_paths}

        self.num_patches_per_image = num_patches_per_image

    def __len__(self):
        return len(self.data_paths)

    def __getitem__(self, idx):
        if self.preload_all_images:
            image_np = self.data[self.data_paths[idx]]
            label_np = self.labels[self.label_paths[idx]]
        else:
            image  = sitk.ReadImage(self.data_paths[idx])
            label = sitk.ReadImage(self.label_paths[idx])

            image_np = sitk.GetArrayFromImage(image).astype('float32')
            label_np = sitk.GetArrayFromImage(label).astype('int64')

        patches = []
        labels = []
        for _ in range(self.num_patches_per_image):
            if self.require_target:
                image_patch, label_patch = self.random_crop_3d_target(image_np, label_np, self.patch_size)
            else:
                image_patch, label_patch = self.random_crop_3d(image_np, label_np, self.patch_size)

            if self.transform:
                array_data = {"image_patch": image_patch, "label_patch": label_patch}
                transformed = self.transform(array_data)
                image_patch, label_patch = transformed["image_patch"], transformed["label_patch"]

            image_tensor = torch.as_tensor(image_patch, dtype=torch.float32).unsqueeze(0)
            label_tensor = torch.as_tensor(label_patch, dtype=torch.float32)
            patches.append(image_tensor)
            labels.append(label_tensor)

        return torch.stack(patches, dim=0), torch.stack(labels, dim=0)

    def random_crop_3d(self, image, label, patch_size):
        z, y, x = image.shape
        pz, py, px = patch_size
        sz = torch.randint(0, z - pz, (1,)).item()
        sy = torch.randint(0, y - py, (1,)).item()
        sx = torch.randint(0, x - px, (1,)).item()
        return image[sz:sz+pz, sy:sy+py, sx:sx+px], label[sz:sz+pz, sy:sy+py, sx:sx+px]

    def random_crop_3d_target(self, image, label, patch_size):
        z, y, x = image.shape
        pz, py, px = patch_size

        ones_indices = np.argwhere(label)
        z_min, y_min, x_min = ones_indices.min(axis=0)
        z_max, y_max, x_max = ones_indices.max(axis=0)

        z_patch_min, y_patch_min, x_patch_min = max(0, z_min - pz), max(0, y_min - py), max(0, x_min - px)
        z_patch_max, y_patch_max, x_patch_max = min(z - pz, z_max), min(y - py, y_max), min(x - px, x_max)

        sz = torch.randint(z_patch_min, z_patch_max + 1, (1,)).item()
        sy = torch.randint(y_patch_min, y_patch_max + 1, (1,)).item()
        sx = torch.randint(x_patch_min, x_patch_max + 1, (1,)).item()

        return image[sz:sz+pz, sy:sy+py, sx:sx+px], label[sz:sz+pz, sy:sy+py, sx:sx+px]


class TestDataset(Dataset):
    """
    Test dataset loads the entire image
    """
    def __init__(self, data_dir, labels_dir=None, transform=None):
        self.transform = transform

        self.data_paths = sorted(glob(data_dir + '/*'))
        self.label_paths = sorted(glob(labels_dir + '/*')) if labels_dir is not None else None

    def __len__(self):
        return len(self.data_paths)

    def __getitem__(self, index):
        image = sitk.ReadImage(self.data_paths[index])
        image_np = sitk.GetArrayFromImage(image).astype('float32')

        if self.label_paths is not None:
            label = sitk.ReadImage(self.label_paths[index])
            label_np = sitk.GetArrayFromImage(label).astype('int64')
        else:
            label_np = None

        #if self.transform:
        #    image_np = self.transform(image_np)

        image_tensor = torch.tensor(image_np, dtype=torch.float32).unsqueeze(0)

        if label_np is not None:
            label_tensor = torch.tensor(label_np, dtype=torch.int64)
            return image_tensor, label_tensor
        else:
            return image_tensor

# %%
patch_size = (64, 128, 128)
transform = RandRotated(keys=["image","label"], prob=0.5, range_x=[-0.3, 0.3], mode=["bilinear", "nearest"])
#transform =RandAffined(keys=["image_patch","label_patch"], prob=1.0, shear_range=(0.3,0.3), mode=["bilinear", "nearest"],padding_mode="zeros")
#transform = RandZoomd(keys=["image_patch","label_patch"], prob=0.4, min_zoom=1.1, max_zoom=1.5, mode=["area", "nearest"])
transform = None

train_image_path = "data/Task02_Heart/imagesTr"
train_label_path = "data/Task02_Heart/labelsTr"
val_image_path = "data/Task02_Heart/imagesVl"
val_label_path = "data/Task02_Heart/labelsVl"

train_dataset = TrainDataset(train_image_path, train_label_path, patch_size, require_target=True, transform=transform, preload_all_images=True, num_patches_per_image=2)
val_dataset = TestDataset(val_image_path, val_label_path)
print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of validation samples: {len(val_dataset)}")

batch_size = 2
# The effective batch size will be batch_size * num_patches_per_image
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, num_workers=6, pin_memory=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=4)
# Out:
# Number of training samples: 16
# Number of validation samples: 4

# %% [markdown]
# ## Utils

# %%
import torch.nn as nn
import torch

def dice_coefficient(pred, target, smooth=1.):
    pred = pred > 0.5  # Thresholding to get binary predictions
    intersection = (pred * target).sum()
    return (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

def soft_dice_coefficient(pred, target, smooth=1.):
    intersection = (pred * target).sum()
    return (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

def soft_dice_loss(pred, target, smooth=1.):
    return 1 - soft_dice_coefficient(pred, target, smooth)

def soft_iou(pred, target, smooth=1e-6):
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection
    return (intersection + smooth) / (union + smooth)

def iou(pred, target, smooth=1e-6):
    pred = pred > 0.5  # Thresholding to get binary predictions
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection
    return (intersection + smooth) / (union + smooth)

class CombinedLoss(nn.Module):
    """
    Expects logit inputs
    """

    def __init__(self, smooth=1):
        super(CombinedLoss, self).__init__()
        self.bce_loss = nn.BCEWithLogitsLoss()
        self.smooth = smooth

    def forward(self, outputs, targets):
        ce_loss = self.bce_loss(outputs, targets)
        dice = soft_dice_loss(torch.sigmoid(outputs), targets, self.smooth)
        return ce_loss + dice

# %% [markdown]
# ## Training of model

# %%
import sys
from monai.networks.nets import UNETR

# %%
from collections import defaultdict
from time import time
import torch
import torch.nn.functional as F

def train_epoch(model, optimizer, loss_fn, train_loader, scheduler, device):
    model.train()
    train_loss = AccumulatingMetric()
    train_iou = AccumulatingMetric()
    train_dice = AccumulatingMetric()
    for batch in train_loader:
        input, target = batch
        # Concatenate the patches along the batch dimension
        input = input.view(-1, *input.shape[2:])
        target = target.view(-1, *target.shape[2:])

        input, target = input.to(device), target.to(device).float()
        optimizer.zero_grad()
        pred_logits = model(input)
        pred_logits = pred_logits.squeeze(1)
        loss = loss_fn(pred_logits, target)
        loss.backward()
        optimizer.step()
        if scheduler is not None:
            scheduler.step()
        pred = torch.sigmoid(pred_logits)
        train_loss.add(loss.item())
        train_iou.add(iou(pred, target).cpu().item())
        train_dice.add(dice_coefficient(pred, target).cpu().item())

    return train_loss.avg(), train_iou.avg(), train_dice.avg()

def validate(model, loss_fn, val_loader, device, patch_size):
    model.eval()
    validation_loss = AccumulatingMetric()
    validation_iou = AccumulatingMetric()
    validation_dice = AccumulatingMetric()

    for batch in val_loader:
        # Here I need to separate the input into patches and then merge them after they have all been analyzed. Should I do this with overlap? Yes I should.
        input, target = batch
        input, target = input.to(device), target.to(device).float()
        with torch.no_grad():
            pred_logits = patched_forward(model, input, patch_size, device)
        pred_logits = pred_logits.squeeze(1)
        pred = torch.sigmoid(pred_logits)
        # Calculate the loss, iou and dice coefficient
        loss = loss_fn(pred_logits, target)

        validation_loss.add(loss.item())
        validation_iou.add(iou(pred, target).cpu().item())
        validation_dice.add(dice_coefficient(pred, target).cpu().item())

    return validation_loss.avg(), validation_iou.avg(), validation_dice.avg()

def patched_forward(model, input, patch_size, device, overlap=0.5):
    # This function will take an input image and split it into patches, then run the model on each patch and merge the results.
    batch_size, channels, z, y, x = input.shape
    pz, py, px = patch_size
    stride_z, stride_y, stride_x = int(pz * (1 - overlap)), int(py * (1 - overlap)), int(px * (1 - overlap))

    # Calculate needed padding
    pad_z = (pz - z % pz) if z % pz != 0 else 0
    pad_y = (py - y % py) if y % py != 0 else 0
    pad_x = (px - x % px) if x % px != 0 else 0
    input_padded = F.pad(input, (0, pad_x, 0, pad_y, 0, pad_z))
    padded_z, padded_y, padded_x = input_padded.shape[2:]

    output = torch.zeros((batch_size, channels, padded_z, padded_y, padded_x)).to(device)
    weight_map = torch.zeros((batch_size, channels, padded_z, padded_y, padded_x)).to(device)

    for z_start in range(0, padded_z - pz + 1, stride_z):
        for y_start in range(0, padded_y - py + 1, stride_y):
            for x_start in range(0, padded_x - px + 1, stride_x):
                z_end, y_end, x_end = z_start + pz, y_start + py, x_start + px

                patch = input_padded[:, :, z_start:z_end, y_start:y_end, x_start:x_end]
                patch_output = model(patch)
                # Add the output of the patch to the combined output
                output[:, :, z_start:z_end, y_start:y_end, x_start:x_end] += patch_output

                # Keep track of how many values has been added to each region so that we can average them later
                weight_map[:, :, z_start:z_end, y_start:y_end, x_start:x_end] += 1

    # Avoid division by zero in case some areas are not covered by patches
    weight_map = torch.where(weight_map == 0, torch.ones_like(weight_map), weight_map)

    output /= weight_map

    # Remove padding
    output = output[:, :, :z, :y, :x]
    return output


def train(model, optimizer, loss_fn, train_loader, val_loader, scheduler, device, epochs, patch_size, validation_freq=1):
    print(f"Starting training on device {device}...")
    model.to(device)
    train_metrics = defaultdict(list)
    val_metrics = defaultdict(list)

    best_val_loss = float('inf')  # To store the best validation loss
    best_model_state = None       # To store the best model state

    for epoch in range(epochs):
        start_time = time()
        # Training step
        train_loss, train_iou, train_dice = train_epoch(model, optimizer, loss_fn, train_loader, scheduler, device)
        train_metrics["loss"].append(train_loss)
        train_metrics["iou"].append(train_iou)
        train_metrics["dice"].append(train_dice)
        print(f"Epoch {epoch + 1} of {epochs} took {time() - start_time:.2f}s | Training: loss={train_loss:.4f}, iou={train_iou:.4f}, dice={train_dice:.4f}")

        # Validation step
        if epoch % validation_freq == validation_freq - 1 or epoch == epochs - 1:
            val_loss, val_iou, val_dice = validate(model, loss_fn, val_loader, device, patch_size)
            val_metrics["loss"].append(val_loss)
            val_metrics["iou"].append(val_iou)
            val_metrics["dice"].append(val_dice)
            print(f"Validation: loss={val_loss:.4f}, iou={val_iou:.4f}, dice={val_dice:.4f}")

            # Save the best model based on validation loss
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state = model.state_dict()  # Save the model state
                print(f"New best model found with validation loss {val_loss:.4f}, saving model...")

    model.load_state_dict(best_model_state)
    return model, train_metrics, val_metrics


class AccumulatingMetric:
    """Accumulate samples of a metric and automatically keep track of the number of samples."""

    def __init__(self):
        self.metric = 0.0
        self.counter = 0

    def add(self, value):
        self.metric += value
        self.counter += 1

    def avg(self):
        return self.metric / (self.counter)

# %%
model = UNETR(in_channels=1, out_channels=1, img_size=(64 , 128 , 128))

loss_fn = CombinedLoss(smooth=1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

epochs = 1000
validation_freq = 20

results_train = train(model, optimizer, loss_fn, train_loader, val_loader, None, device, epochs, patch_size=patch_size, validation_freq=validation_freq)
# Out:
# Starting training on device cuda...
# Epoch 1 of 1000 took 10.81s | Training: loss=1.5421, iou=0.0418, dice=0.0789
# Epoch 2 of 1000 took 10.38s | Training: loss=1.4118, iou=0.1066, dice=0.1919
# Epoch 3 of 1000 took 10.49s | Training: loss=1.3934, iou=0.0806, dice=0.1483
# Epoch 4 of 1000 took 10.60s | Training: loss=1.3456, iou=0.1097, dice=0.1951
# Epoch 5 of 1000 took 10.58s | Training: loss=1.3181, iou=0.1338, dice=0.2339
# Epoch 6 of 1000 took 10.79s | Training: loss=1.3130, iou=0.1227, dice=0.2179
# Epoch 7 of 1000 took 10.93s | Training: loss=1.3087, iou=0.1326, dice=0.2314
# Epoch 8 of 1000 took 11.02s | Training: loss=1.2837, iou=0.1598, dice=0.2747
# Epoch 9 of 1000 took 11.11s | Training: loss=1.2769, iou=0.1862, dice=0.3122
# Epoch 10 of 1000 took 11.09s | Training: loss=1.2749, iou=0.1693, dice=0.2851
# Epoch 11 of 1000 took 11.35s | Training: loss=1.2778, iou=0.1730, dice=0.2933
# Epoch 12 of 1000 took 11.33s | Training: loss=1.2595, iou=0.2068, dice=0.3394
# Epoch 13 of 1000 took 11.45s | Training: loss=1.2633, iou=0.1764, dice=0.2972
# Epoch 14 of 1000 took 11.60s | Training: loss=1.2361, iou=0.2490, dice=0.3955
# Epoch 15 of 1000 took 11.54s | Training: loss=1.2399, iou=0.2279, dice=0.3684
# Epoch 16 of 1000 took 11.40s | Training: loss=1.2539, iou=0.2057, dice=0.3342
# Epoch 17 of 1000 took 11.35s | Training: loss=1.2559, iou=0.1899, dice=0.3109
# Epoch 18 of 1000 took 11.31s | Training: loss=1.2407, iou=0.2416, dice=0.3845
# Epoch 19 of 1000 took 11.47s | Training: loss=1.2462, iou=0.2144, dice=0.3423
# Epoch 20 of 1000 took 11.40s | Training: loss=1.2133, iou=0.3244, dice=0.4819
# Validation: loss=1.2923, iou=0.1878, dice=0.3149
# New best model found with validation loss 1.2923, saving model...
# Epoch 21 of 1000 took 11.42s | Training: loss=1.2164, iou=0.2608, dice=0.4105
# Epoch 22 of 1000 took 11.42s | Training: loss=1.2040, iou=0.3224, dice=0.4784
# Epoch 23 of 1000 took 11.48s | Training: loss=1.2073, iou=0.2889, dice=0.4373
# Epoch 24 of 1000 took 11.41s | Training: loss=1.1995, iou=0.3025, dice=0.4572
# Epoch 25 of 1000 took 11.40s | Training: loss=1.1875, iou=0.3348, dice=0.4968
# Epoch 26 of 1000 took 11.53s | Training: loss=1.1947, iou=0.3083, dice=0.4596
# Epoch 27 of 1000 took 11.53s | Training: loss=1.1480, iou=0.3890, dice=0.5559
# Epoch 28 of 1000 took 11.46s | Training: loss=1.1720, iou=0.3237, dice=0.4814
# Epoch 29 of 1000 took 11.55s | Training: loss=1.1768, iou=0.3461, dice=0.5052
# Epoch 30 of 1000 took 11.54s | Training: loss=1.1864, iou=0.3517, dice=0.4991
# Epoch 31 of 1000 took 11.46s | Training: loss=1.1740, iou=0.3520, dice=0.4995
# Epoch 32 of 1000 took 11.54s | Training: loss=1.1549, iou=0.3581, dice=0.5174
# Epoch 33 of 1000 took 11.51s | Training: loss=1.1522, iou=0.3516, dice=0.5113
# Epoch 34 of 1000 took 11.51s | Training: loss=1.1261, iou=0.4255, dice=0.5847
# Epoch 35 of 1000 took 11.44s | Training: loss=1.1507, iou=0.3719, dice=0.5300
# Epoch 36 of 1000 took 11.54s | Training: loss=1.1350, iou=0.3758, dice=0.5240
# Epoch 37 of 1000 took 11.42s | Training: loss=1.1402, iou=0.3725, dice=0.5326
# Epoch 38 of 1000 took 11.46s | Training: loss=1.1362, iou=0.3971, dice=0.5570
# Epoch 39 of 1000 took 11.45s | Training: loss=1.1155, iou=0.4376, dice=0.6002
# Epoch 40 of 1000 took 11.45s | Training: loss=1.1243, iou=0.4489, dice=0.6093
# Validation: loss=1.2342, iou=0.2535, dice=0.4031
# New best model found with validation loss 1.2342, saving model...
# Epoch 41 of 1000 took 11.41s | Training: loss=1.1079, iou=0.4505, dice=0.6151
# Epoch 42 of 1000 took 11.42s | Training: loss=1.1035, iou=0.4450, dice=0.6116
# Epoch 43 of 1000 took 11.38s | Training: loss=1.1244, iou=0.4108, dice=0.5771
# Epoch 44 of 1000 took 11.51s | Training: loss=1.0803, iou=0.4834, dice=0.6424
# Epoch 45 of 1000 took 11.42s | Training: loss=1.0898, iou=0.4460, dice=0.5890
# Epoch 46 of 1000 took 11.41s | Training: loss=1.0741, iou=0.4881, dice=0.6469
# Epoch 47 of 1000 took 11.45s | Training: loss=1.1019, iou=0.4196, dice=0.5671
# Epoch 48 of 1000 took 11.55s | Training: loss=1.0829, iou=0.4364, dice=0.6031
# Epoch 49 of 1000 took 11.54s | Training: loss=1.0986, iou=0.4186, dice=0.5804
# Epoch 50 of 1000 took 11.51s | Training: loss=1.0640, iou=0.4993, dice=0.6596
# Epoch 51 of 1000 took 11.48s | Training: loss=1.1157, iou=0.3720, dice=0.5371
# Epoch 52 of 1000 took 11.40s | Training: loss=1.0841, iou=0.4644, dice=0.6309
# Epoch 53 of 1000 took 11.49s | Training: loss=1.0661, iou=0.4928, dice=0.6558
# Epoch 54 of 1000 took 11.51s | Training: loss=1.0829, iou=0.4733, dice=0.6348
# Epoch 55 of 1000 took 11.49s | Training: loss=1.0596, iou=0.4755, dice=0.6087
# Epoch 56 of 1000 took 11.42s | Training: loss=1.0737, iou=0.4935, dice=0.6556
# Epoch 57 of 1000 took 11.54s | Training: loss=1.0508, iou=0.5614, dice=0.7150
# Epoch 58 of 1000 took 11.54s | Training: loss=1.0394, iou=0.5581, dice=0.7116
# Epoch 59 of 1000 took 11.53s | Training: loss=1.0056, iou=0.5750, dice=0.7219
# Epoch 60 of 1000 took 11.49s | Training: loss=1.0431, iou=0.5794, dice=0.7279
# Validation: loss=1.1846, iou=0.3111, dice=0.4697
# New best model found with validation loss 1.1846, saving model...
# Epoch 61 of 1000 took 11.53s | Training: loss=1.0164, iou=0.5583, dice=0.7127
# Epoch 62 of 1000 took 11.48s | Training: loss=1.0221, iou=0.5760, dice=0.7285
# Epoch 63 of 1000 took 11.52s | Training: loss=1.0429, iou=0.5387, dice=0.6892
# Epoch 64 of 1000 took 11.53s | Training: loss=1.0239, iou=0.4683, dice=0.6339
# Epoch 65 of 1000 took 11.53s | Training: loss=1.0358, iou=0.5131, dice=0.6674
# Epoch 66 of 1000 took 11.50s | Training: loss=1.0331, iou=0.4945, dice=0.6562
# Epoch 67 of 1000 took 11.51s | Training: loss=1.0655, iou=0.5098, dice=0.6617
# Epoch 68 of 1000 took 11.41s | Training: loss=1.0144, iou=0.5533, dice=0.7081
# Epoch 69 of 1000 took 11.52s | Training: loss=1.0620, iou=0.5206, dice=0.6800
# Epoch 70 of 1000 took 11.42s | Training: loss=1.0484, iou=0.5218, dice=0.6789
# Epoch 71 of 1000 took 11.51s | Training: loss=1.0402, iou=0.4563, dice=0.6031
# Epoch 72 of 1000 took 11.43s | Training: loss=0.9853, iou=0.5761, dice=0.7286
# Epoch 73 of 1000 took 11.56s | Training: loss=0.9776, iou=0.5931, dice=0.7362
# Epoch 74 of 1000 took 11.53s | Training: loss=0.9988, iou=0.5579, dice=0.7087
# Epoch 75 of 1000 took 11.53s | Training: loss=1.0092, iou=0.5517, dice=0.7040
# Epoch 76 of 1000 took 11.43s | Training: loss=1.0168, iou=0.5582, dice=0.7143
# Epoch 77 of 1000 took 11.43s | Training: loss=0.9999, iou=0.5768, dice=0.7298
# Epoch 78 of 1000 took 11.52s | Training: loss=0.9796, iou=0.6108, dice=0.7539
# Epoch 79 of 1000 took 11.55s | Training: loss=0.9910, iou=0.6053, dice=0.7522
# Epoch 80 of 1000 took 11.44s | Training: loss=1.0199, iou=0.5974, dice=0.7433
# Validation: loss=1.1392, iou=0.6045, dice=0.7493
# New best model found with validation loss 1.1392, saving model...
# Epoch 81 of 1000 took 11.52s | Training: loss=1.0023, iou=0.5514, dice=0.7061
# Epoch 82 of 1000 took 11.53s | Training: loss=1.0253, iou=0.5373, dice=0.6859
# Epoch 83 of 1000 took 11.53s | Training: loss=0.9383, iou=0.6325, dice=0.7724
# Epoch 84 of 1000 took 11.40s | Training: loss=0.9816, iou=0.5956, dice=0.7362
# Epoch 85 of 1000 took 11.40s | Training: loss=0.9302, iou=0.6529, dice=0.7880
# Epoch 86 of 1000 took 11.42s | Training: loss=1.0209, iou=0.5051, dice=0.6472
# Epoch 87 of 1000 took 11.51s | Training: loss=0.9644, iou=0.5816, dice=0.7315
# Epoch 88 of 1000 took 11.52s | Training: loss=0.9638, iou=0.5973, dice=0.7462
# Epoch 89 of 1000 took 11.44s | Training: loss=0.9623, iou=0.6198, dice=0.7608
# Epoch 90 of 1000 took 11.43s | Training: loss=0.9874, iou=0.5287, dice=0.6592
# Epoch 91 of 1000 took 11.42s | Training: loss=0.9410, iou=0.5835, dice=0.7348
# Epoch 92 of 1000 took 11.50s | Training: loss=0.9752, iou=0.5783, dice=0.7299
# Epoch 93 of 1000 took 11.39s | Training: loss=0.9673, iou=0.6215, dice=0.7637
# Epoch 94 of 1000 took 11.49s | Training: loss=0.9260, iou=0.6292, dice=0.7686
# Epoch 95 of 1000 took 11.49s | Training: loss=0.9505, iou=0.6410, dice=0.7754
# Epoch 96 of 1000 took 11.51s | Training: loss=0.9136, iou=0.6771, dice=0.8053
# Epoch 97 of 1000 took 11.51s | Training: loss=0.9588, iou=0.5223, dice=0.6703
# Epoch 98 of 1000 took 11.50s | Training: loss=0.9770, iou=0.6273, dice=0.7691
# Epoch 99 of 1000 took 11.52s | Training: loss=0.9754, iou=0.5532, dice=0.7093
# Epoch 100 of 1000 took 11.44s | Training: loss=0.9584, iou=0.5635, dice=0.7086
# Validation: loss=1.1135, iou=0.6535, dice=0.7886
# New best model found with validation loss 1.1135, saving model...
# Epoch 101 of 1000 took 11.56s | Training: loss=0.9340, iou=0.5817, dice=0.7286
# Epoch 102 of 1000 took 11.54s | Training: loss=0.9423, iou=0.6360, dice=0.7732
# Epoch 103 of 1000 took 11.39s | Training: loss=0.9130, iou=0.6126, dice=0.7517
# Epoch 104 of 1000 took 11.46s | Training: loss=0.9283, iou=0.6135, dice=0.7461
# Epoch 105 of 1000 took 11.39s | Training: loss=0.9400, iou=0.6495, dice=0.7830
# Epoch 106 of 1000 took 11.50s | Training: loss=0.9023, iou=0.6624, dice=0.7944
# Epoch 107 of 1000 took 11.42s | Training: loss=0.9222, iou=0.6536, dice=0.7869
# Epoch 108 of 1000 took 11.52s | Training: loss=0.9464, iou=0.6149, dice=0.7557
# Epoch 109 of 1000 took 11.54s | Training: loss=0.8887, iou=0.6309, dice=0.7711
# Epoch 110 of 1000 took 11.54s | Training: loss=0.8887, iou=0.6790, dice=0.8055
# Epoch 111 of 1000 took 11.45s | Training: loss=0.9455, iou=0.6342, dice=0.7663
# Epoch 112 of 1000 took 11.55s | Training: loss=0.8716, iou=0.6661, dice=0.7984
# Epoch 113 of 1000 took 11.55s | Training: loss=0.9148, iou=0.6797, dice=0.8079
# Epoch 114 of 1000 took 11.41s | Training: loss=0.8851, iou=0.6671, dice=0.7954
# Epoch 115 of 1000 took 11.52s | Training: loss=0.8904, iou=0.6873, dice=0.8132
# Epoch 116 of 1000 took 11.42s | Training: loss=0.9043, iou=0.6299, dice=0.7678
# Epoch 117 of 1000 took 11.40s | Training: loss=0.8681, iou=0.6626, dice=0.7932
# Epoch 118 of 1000 took 11.52s | Training: loss=0.8909, iou=0.6676, dice=0.7998
# Epoch 119 of 1000 took 11.52s | Training: loss=0.8827, iou=0.6764, dice=0.8062
# Epoch 120 of 1000 took 11.52s | Training: loss=0.8503, iou=0.6957, dice=0.8185
# Validation: loss=1.0846, iou=0.7253, dice=0.8380
# New best model found with validation loss 1.0846, saving model...
# Epoch 121 of 1000 took 11.51s | Training: loss=0.8595, iou=0.6903, dice=0.8145
# Epoch 122 of 1000 took 11.42s | Training: loss=0.8671, iou=0.7027, dice=0.8236
# Epoch 123 of 1000 took 11.52s | Training: loss=0.8658, iou=0.6667, dice=0.7989
# Epoch 124 of 1000 took 11.51s | Training: loss=0.8880, iou=0.6226, dice=0.7653
# Epoch 125 of 1000 took 11.50s | Training: loss=0.9143, iou=0.5905, dice=0.7357
# Epoch 126 of 1000 took 11.50s | Training: loss=0.8451, iou=0.7014, dice=0.8235
# Epoch 127 of 1000 took 11.50s | Training: loss=0.8740, iou=0.6744, dice=0.8022
# Epoch 128 of 1000 took 11.51s | Training: loss=0.8253, iou=0.6945, dice=0.8183
# Epoch 129 of 1000 took 11.42s | Training: loss=0.8818, iou=0.6926, dice=0.8169
# Epoch 130 of 1000 took 11.43s | Training: loss=0.8760, iou=0.6703, dice=0.7982
# Epoch 131 of 1000 took 11.52s | Training: loss=0.8412, iou=0.6732, dice=0.8025
# Epoch 132 of 1000 took 11.41s | Training: loss=0.8883, iou=0.6528, dice=0.7849
# Epoch 133 of 1000 took 11.44s | Training: loss=0.8421, iou=0.6987, dice=0.8214
# Epoch 134 of 1000 took 11.52s | Training: loss=0.8474, iou=0.6822, dice=0.8061
# Epoch 135 of 1000 took 11.52s | Training: loss=0.8319, iou=0.7005, dice=0.8214
# Epoch 136 of 1000 took 11.52s | Training: loss=0.8396, iou=0.6460, dice=0.7823
# Epoch 137 of 1000 took 11.50s | Training: loss=0.8664, iou=0.6272, dice=0.7642
# Epoch 138 of 1000 took 11.50s | Training: loss=0.8468, iou=0.7280, dice=0.8417
# Epoch 139 of 1000 took 11.46s | Training: loss=0.8901, iou=0.6183, dice=0.7501
# Epoch 140 of 1000 took 11.40s | Training: loss=0.8387, iou=0.6577, dice=0.7880
# Validation: loss=1.0590, iou=0.6386, dice=0.7752
# New best model found with validation loss 1.0590, saving model...
# Epoch 141 of 1000 took 11.55s | Training: loss=0.7978, iou=0.7036, dice=0.8217
# Epoch 142 of 1000 took 11.48s | Training: loss=0.8212, iou=0.7237, dice=0.8384
# Epoch 143 of 1000 took 11.39s | Training: loss=0.8224, iou=0.7130, dice=0.8310
# Epoch 144 of 1000 took 11.39s | Training: loss=0.8125, iou=0.6777, dice=0.7987
# Epoch 145 of 1000 took 11.50s | Training: loss=0.8621, iou=0.6883, dice=0.8114
# Epoch 146 of 1000 took 11.38s | Training: loss=0.8063, iou=0.7160, dice=0.8335
# Epoch 147 of 1000 took 11.48s | Training: loss=0.8244, iou=0.7224, dice=0.8378
# Epoch 148 of 1000 took 11.42s | Training: loss=0.8305, iou=0.6494, dice=0.7805
# Epoch 149 of 1000 took 11.53s | Training: loss=0.7982, iou=0.7323, dice=0.8444
# Epoch 150 of 1000 took 11.57s | Training: loss=0.8249, iou=0.7132, dice=0.8296
# Epoch 151 of 1000 took 11.52s | Training: loss=0.8270, iou=0.7069, dice=0.8192
# Epoch 152 of 1000 took 11.54s | Training: loss=0.7667, iou=0.7308, dice=0.8431
# Epoch 153 of 1000 took 11.43s | Training: loss=0.8131, iou=0.7063, dice=0.8271
# Epoch 154 of 1000 took 11.53s | Training: loss=0.8140, iou=0.7274, dice=0.8403
# Epoch 155 of 1000 took 11.52s | Training: loss=0.8556, iou=0.6405, dice=0.7707
# Epoch 156 of 1000 took 11.54s | Training: loss=0.8397, iou=0.7113, dice=0.8306
# Epoch 157 of 1000 took 11.51s | Training: loss=0.7795, iou=0.6727, dice=0.8019
# Epoch 158 of 1000 took 11.42s | Training: loss=0.8517, iou=0.6314, dice=0.7642
# Epoch 159 of 1000 took 11.41s | Training: loss=0.8286, iou=0.6661, dice=0.7938
# Epoch 160 of 1000 took 11.51s | Training: loss=0.7812, iou=0.6900, dice=0.8132
# Validation: loss=1.0380, iou=0.6347, dice=0.7700
# New best model found with validation loss 1.0380, saving model...
# Epoch 161 of 1000 took 11.57s | Training: loss=0.7665, iou=0.7335, dice=0.8452
# Epoch 162 of 1000 took 11.58s | Training: loss=0.7830, iou=0.7097, dice=0.8291
# Epoch 163 of 1000 took 11.55s | Training: loss=0.7548, iou=0.6984, dice=0.8162
# Epoch 164 of 1000 took 11.46s | Training: loss=0.7596, iou=0.6999, dice=0.8198
# Epoch 165 of 1000 took 11.53s | Training: loss=0.7911, iou=0.7008, dice=0.8227
# Epoch 166 of 1000 took 11.53s | Training: loss=0.7783, iou=0.7301, dice=0.8426
# Epoch 167 of 1000 took 11.51s | Training: loss=0.7696, iou=0.7200, dice=0.8284
# Epoch 168 of 1000 took 11.56s | Training: loss=0.7646, iou=0.7324, dice=0.8436
# Epoch 169 of 1000 took 11.48s | Training: loss=0.8756, iou=0.6787, dice=0.8073
# Epoch 170 of 1000 took 11.41s | Training: loss=0.8253, iou=0.6865, dice=0.8127
# Epoch 171 of 1000 took 11.50s | Training: loss=0.7293, iou=0.7394, dice=0.8481
# Epoch 172 of 1000 took 11.54s | Training: loss=0.7743, iou=0.7231, dice=0.8375
# Epoch 173 of 1000 took 11.44s | Training: loss=0.7732, iou=0.7179, dice=0.8349
# Epoch 174 of 1000 took 11.55s | Training: loss=0.8079, iou=0.6584, dice=0.7649
# Epoch 175 of 1000 took 11.57s | Training: loss=0.7350, iou=0.7388, dice=0.8488
# Epoch 176 of 1000 took 11.42s | Training: loss=0.7471, iou=0.7223, dice=0.8374
# Epoch 177 of 1000 took 11.52s | Training: loss=0.8170, iou=0.6690, dice=0.7948
# Epoch 178 of 1000 took 11.48s | Training: loss=0.8063, iou=0.6943, dice=0.8176
# Epoch 179 of 1000 took 11.42s | Training: loss=0.7394, iou=0.7466, dice=0.8536
# Epoch 180 of 1000 took 11.52s | Training: loss=0.7582, iou=0.7428, dice=0.8505
# Validation: loss=1.0175, iou=0.7343, dice=0.8458
# New best model found with validation loss 1.0175, saving model...
# Epoch 181 of 1000 took 11.51s | Training: loss=0.7810, iou=0.6867, dice=0.8063
# Epoch 182 of 1000 took 11.46s | Training: loss=0.7559, iou=0.7722, dice=0.8713
# Epoch 183 of 1000 took 11.53s | Training: loss=0.7569, iou=0.7176, dice=0.8329
# Epoch 184 of 1000 took 11.54s | Training: loss=0.7459, iou=0.7377, dice=0.8487
# Epoch 185 of 1000 took 11.45s | Training: loss=0.6953, iou=0.7656, dice=0.8664
# Epoch 186 of 1000 took 11.50s | Training: loss=0.7088, iou=0.7875, dice=0.8801
# Epoch 187 of 1000 took 11.55s | Training: loss=0.7848, iou=0.7341, dice=0.8449
# Epoch 188 of 1000 took 11.54s | Training: loss=0.7036, iou=0.7737, dice=0.8719
# Epoch 189 of 1000 took 11.57s | Training: loss=0.6794, iou=0.7687, dice=0.8686
# Epoch 190 of 1000 took 11.42s | Training: loss=0.7185, iou=0.7563, dice=0.8602
# Epoch 191 of 1000 took 11.42s | Training: loss=0.7700, iou=0.7069, dice=0.8235
# Epoch 192 of 1000 took 11.56s | Training: loss=0.7435, iou=0.7600, dice=0.8633
# Epoch 193 of 1000 took 11.53s | Training: loss=0.7860, iou=0.7253, dice=0.8295
# Epoch 194 of 1000 took 11.49s | Training: loss=0.7563, iou=0.7528, dice=0.8579
# Epoch 195 of 1000 took 11.41s | Training: loss=0.7866, iou=0.7221, dice=0.8362
# Epoch 196 of 1000 took 11.39s | Training: loss=0.7206, iou=0.7327, dice=0.8433
# Epoch 197 of 1000 took 11.40s | Training: loss=0.7190, iou=0.7586, dice=0.8622
# Epoch 198 of 1000 took 11.52s | Training: loss=0.7347, iou=0.7268, dice=0.8381
# Epoch 199 of 1000 took 11.40s | Training: loss=0.6870, iou=0.7484, dice=0.8559
# Epoch 200 of 1000 took 11.50s | Training: loss=0.7018, iou=0.7432, dice=0.8522
# Validation: loss=0.9965, iou=0.7363, dice=0.8472
# New best model found with validation loss 0.9965, saving model...
# Epoch 201 of 1000 took 11.50s | Training: loss=0.6559, iou=0.7683, dice=0.8673
# Epoch 202 of 1000 took 11.50s | Training: loss=0.7070, iou=0.7642, dice=0.8655
# Epoch 203 of 1000 took 11.53s | Training: loss=0.7272, iou=0.7409, dice=0.8488
# Epoch 204 of 1000 took 11.54s | Training: loss=0.6860, iou=0.7654, dice=0.8663
# Epoch 205 of 1000 took 11.52s | Training: loss=0.7434, iou=0.7600, dice=0.8627
# Epoch 206 of 1000 took 11.54s | Training: loss=0.7185, iou=0.7459, dice=0.8526
# Epoch 207 of 1000 took 11.51s | Training: loss=0.6344, iou=0.7877, dice=0.8809
# Epoch 208 of 1000 took 11.42s | Training: loss=0.6377, iou=0.7811, dice=0.8758
# Epoch 209 of 1000 took 11.40s | Training: loss=0.7302, iou=0.7246, dice=0.8370
# Epoch 210 of 1000 took 11.42s | Training: loss=0.6691, iou=0.7467, dice=0.8479
# Epoch 211 of 1000 took 11.50s | Training: loss=0.7159, iou=0.7232, dice=0.8383
# Epoch 212 of 1000 took 11.52s | Training: loss=0.7109, iou=0.7364, dice=0.8468
# Epoch 213 of 1000 took 11.41s | Training: loss=0.7426, iou=0.7140, dice=0.8304
# Epoch 214 of 1000 took 11.50s | Training: loss=0.7428, iou=0.6479, dice=0.7719
# Epoch 215 of 1000 took 11.44s | Training: loss=0.7070, iou=0.7254, dice=0.8362
# Epoch 216 of 1000 took 11.52s | Training: loss=0.6731, iou=0.7309, dice=0.8421
# Epoch 217 of 1000 took 11.55s | Training: loss=0.6426, iou=0.7955, dice=0.8860
# Epoch 218 of 1000 took 11.40s | Training: loss=0.6672, iou=0.7632, dice=0.8641
# Epoch 219 of 1000 took 11.40s | Training: loss=0.6527, iou=0.7933, dice=0.8845
# Epoch 220 of 1000 took 11.39s | Training: loss=0.6456, iou=0.7906, dice=0.8830
# Validation: loss=0.9789, iou=0.7557, dice=0.8597
# New best model found with validation loss 0.9789, saving model...
# Epoch 221 of 1000 took 11.43s | Training: loss=0.6775, iou=0.7669, dice=0.8679
# Epoch 222 of 1000 took 11.52s | Training: loss=0.6954, iou=0.7179, dice=0.8228
# Epoch 223 of 1000 took 11.40s | Training: loss=0.6342, iou=0.7823, dice=0.8771
# Epoch 224 of 1000 took 11.51s | Training: loss=0.6881, iou=0.7098, dice=0.8207
# Epoch 225 of 1000 took 11.40s | Training: loss=0.7023, iou=0.7534, dice=0.8590
# Epoch 226 of 1000 took 11.42s | Training: loss=0.6614, iou=0.7392, dice=0.8472
# Epoch 227 of 1000 took 11.51s | Training: loss=0.6307, iou=0.7622, dice=0.8641
# Epoch 228 of 1000 took 11.53s | Training: loss=0.6474, iou=0.7639, dice=0.8654
# Epoch 229 of 1000 took 11.57s | Training: loss=0.6529, iou=0.7598, dice=0.8629
# Epoch 230 of 1000 took 11.58s | Training: loss=0.6585, iou=0.7277, dice=0.8386
# Epoch 231 of 1000 took 11.54s | Training: loss=0.6235, iou=0.7493, dice=0.8548
# Epoch 232 of 1000 took 11.41s | Training: loss=0.6266, iou=0.7500, dice=0.8558
# Epoch 233 of 1000 took 11.51s | Training: loss=0.6828, iou=0.7396, dice=0.8473
# Epoch 234 of 1000 took 11.50s | Training: loss=0.6485, iou=0.7464, dice=0.8521
# Epoch 235 of 1000 took 11.37s | Training: loss=0.6516, iou=0.7603, dice=0.8631
# Epoch 236 of 1000 took 11.50s | Training: loss=0.6677, iou=0.7834, dice=0.8780
# Epoch 237 of 1000 took 11.43s | Training: loss=0.6049, iou=0.7785, dice=0.8741
# Epoch 238 of 1000 took 11.50s | Training: loss=0.6008, iou=0.7713, dice=0.8704
# Epoch 239 of 1000 took 11.51s | Training: loss=0.5934, iou=0.7943, dice=0.8848
# Epoch 240 of 1000 took 11.50s | Training: loss=0.6155, iou=0.7834, dice=0.8783
# Validation: loss=0.9570, iou=0.7691, dice=0.8687
# New best model found with validation loss 0.9570, saving model...
# Epoch 241 of 1000 took 11.40s | Training: loss=0.5907, iou=0.8016, dice=0.8895
# Epoch 242 of 1000 took 11.50s | Training: loss=0.6160, iou=0.7852, dice=0.8782
# Epoch 243 of 1000 took 11.50s | Training: loss=0.5771, iou=0.8107, dice=0.8947
# Epoch 244 of 1000 took 11.38s | Training: loss=0.6366, iou=0.7669, dice=0.8675
# Epoch 245 of 1000 took 11.47s | Training: loss=0.6492, iou=0.7554, dice=0.8582
# Epoch 246 of 1000 took 11.51s | Training: loss=0.6602, iou=0.7484, dice=0.8542
# Epoch 247 of 1000 took 11.51s | Training: loss=0.5634, iou=0.7906, dice=0.8827
# Epoch 248 of 1000 took 11.50s | Training: loss=0.6934, iou=0.7165, dice=0.8329
# Epoch 249 of 1000 took 11.40s | Training: loss=0.6676, iou=0.7296, dice=0.8416
# Epoch 250 of 1000 took 11.42s | Training: loss=0.6128, iou=0.7717, dice=0.8691
# Epoch 251 of 1000 took 11.54s | Training: loss=0.6363, iou=0.7468, dice=0.8540
# Epoch 252 of 1000 took 11.55s | Training: loss=0.6330, iou=0.7463, dice=0.8525
# Epoch 253 of 1000 took 11.53s | Training: loss=0.6518, iou=0.7718, dice=0.8703
# Epoch 254 of 1000 took 11.51s | Training: loss=0.5859, iou=0.7805, dice=0.8756
# Epoch 255 of 1000 took 11.42s | Training: loss=0.5638, iou=0.7867, dice=0.8800
# Epoch 256 of 1000 took 11.52s | Training: loss=0.5801, iou=0.8119, dice=0.8959
# Epoch 257 of 1000 took 11.48s | Training: loss=0.5985, iou=0.7734, dice=0.8718
# Epoch 258 of 1000 took 11.50s | Training: loss=0.5555, iou=0.7946, dice=0.8852
# Epoch 259 of 1000 took 11.39s | Training: loss=0.5633, iou=0.7961, dice=0.8862
# Epoch 260 of 1000 took 11.40s | Training: loss=0.6227, iou=0.7975, dice=0.8869
# Validation: loss=0.9370, iou=0.7167, dice=0.8306
# New best model found with validation loss 0.9370, saving model...
# Epoch 261 of 1000 took 11.49s | Training: loss=0.5446, iou=0.7947, dice=0.8843
# Epoch 262 of 1000 took 11.51s | Training: loss=0.6040, iou=0.7881, dice=0.8811
# Epoch 263 of 1000 took 11.39s | Training: loss=0.6122, iou=0.7667, dice=0.8670
# Epoch 264 of 1000 took 11.44s | Training: loss=0.5450, iou=0.8135, dice=0.8970
# Epoch 265 of 1000 took 11.51s | Training: loss=0.6008, iou=0.8084, dice=0.8936
# Epoch 266 of 1000 took 11.49s | Training: loss=0.6091, iou=0.7739, dice=0.8716
# Epoch 267 of 1000 took 11.53s | Training: loss=0.6182, iou=0.7409, dice=0.8418
# Epoch 268 of 1000 took 11.43s | Training: loss=0.6406, iou=0.7635, dice=0.8641
# Epoch 269 of 1000 took 11.51s | Training: loss=0.5895, iou=0.7864, dice=0.8787
# Epoch 270 of 1000 took 11.51s | Training: loss=0.5308, iou=0.8093, dice=0.8940
# Epoch 271 of 1000 took 11.55s | Training: loss=0.5705, iou=0.7899, dice=0.8822
# Epoch 272 of 1000 took 11.41s | Training: loss=0.5695, iou=0.7833, dice=0.8777
# Epoch 273 of 1000 took 11.51s | Training: loss=0.5496, iou=0.7912, dice=0.8825
# Epoch 274 of 1000 took 11.48s | Training: loss=0.5509, iou=0.7879, dice=0.8805
# Epoch 275 of 1000 took 11.50s | Training: loss=0.5491, iou=0.8106, dice=0.8945
# Epoch 276 of 1000 took 11.52s | Training: loss=0.5310, iou=0.8114, dice=0.8951
# Epoch 277 of 1000 took 11.52s | Training: loss=0.5739, iou=0.7865, dice=0.8784
# Epoch 278 of 1000 took 11.53s | Training: loss=0.6103, iou=0.7277, dice=0.8265
# Epoch 279 of 1000 took 11.55s | Training: loss=0.6615, iou=0.7294, dice=0.8397
# Epoch 280 of 1000 took 11.43s | Training: loss=0.5020, iou=0.8204, dice=0.9008
# Validation: loss=0.9229, iou=0.7259, dice=0.8383
# New best model found with validation loss 0.9229, saving model...
# Epoch 281 of 1000 took 11.40s | Training: loss=0.5282, iou=0.7998, dice=0.8883
# Epoch 282 of 1000 took 11.47s | Training: loss=0.5679, iou=0.8219, dice=0.9020
# Epoch 283 of 1000 took 11.50s | Training: loss=0.5178, iou=0.8021, dice=0.8900
# Epoch 284 of 1000 took 11.51s | Training: loss=0.5609, iou=0.8019, dice=0.8889
# Epoch 285 of 1000 took 11.53s | Training: loss=0.5092, iou=0.8105, dice=0.8950
# Epoch 286 of 1000 took 11.55s | Training: loss=0.5406, iou=0.8016, dice=0.8883
# Epoch 287 of 1000 took 11.47s | Training: loss=0.5164, iou=0.8079, dice=0.8935
# Epoch 288 of 1000 took 11.43s | Training: loss=0.5963, iou=0.8045, dice=0.8915
# Epoch 289 of 1000 took 11.43s | Training: loss=0.4808, iou=0.8062, dice=0.8911
# Epoch 290 of 1000 took 11.52s | Training: loss=0.5924, iou=0.6967, dice=0.7972
# Epoch 291 of 1000 took 11.54s | Training: loss=0.5825, iou=0.7445, dice=0.8487
# Epoch 292 of 1000 took 11.52s | Training: loss=0.5794, iou=0.7651, dice=0.8653
# Epoch 293 of 1000 took 11.52s | Training: loss=0.5375, iou=0.7764, dice=0.8733
# Epoch 294 of 1000 took 11.53s | Training: loss=0.5121, iou=0.8022, dice=0.8900
# Epoch 295 of 1000 took 11.49s | Training: loss=0.4824, iou=0.8206, dice=0.9011
# Epoch 296 of 1000 took 11.51s | Training: loss=0.5671, iou=0.7854, dice=0.8794
# Epoch 297 of 1000 took 11.51s | Training: loss=0.5420, iou=0.7688, dice=0.8671
# Epoch 298 of 1000 took 11.42s | Training: loss=0.5123, iou=0.8169, dice=0.8987
# Epoch 299 of 1000 took 11.51s | Training: loss=0.4545, iou=0.8231, dice=0.9025
# Epoch 300 of 1000 took 11.42s | Training: loss=0.4744, iou=0.8267, dice=0.9050
# Validation: loss=0.9026, iou=0.7865, dice=0.8799
# New best model found with validation loss 0.9026, saving model...
# Epoch 301 of 1000 took 11.44s | Training: loss=0.4920, iou=0.8236, dice=0.9025
# Epoch 302 of 1000 took 11.58s | Training: loss=0.4804, iou=0.8323, dice=0.9081
# Epoch 303 of 1000 took 11.43s | Training: loss=0.5228, iou=0.8229, dice=0.9025
# Epoch 304 of 1000 took 11.43s | Training: loss=0.4971, iou=0.8259, dice=0.9044
# Epoch 305 of 1000 took 11.56s | Training: loss=0.5097, iou=0.8082, dice=0.8932
# Epoch 306 of 1000 took 11.55s | Training: loss=0.4683, iou=0.8221, dice=0.9016
# Epoch 307 of 1000 took 11.42s | Training: loss=0.5548, iou=0.7995, dice=0.8881
# Epoch 308 of 1000 took 11.51s | Training: loss=0.5169, iou=0.8266, dice=0.9048
# Epoch 309 of 1000 took 11.53s | Training: loss=0.4851, iou=0.8017, dice=0.8883
# Epoch 310 of 1000 took 11.54s | Training: loss=0.5356, iou=0.8059, dice=0.8921
# Epoch 311 of 1000 took 11.54s | Training: loss=0.4726, iou=0.8189, dice=0.8998
# Epoch 312 of 1000 took 11.44s | Training: loss=0.5446, iou=0.7673, dice=0.8621
# Epoch 313 of 1000 took 11.53s | Training: loss=0.5195, iou=0.8023, dice=0.8883
# Epoch 314 of 1000 took 11.42s | Training: loss=0.5012, iou=0.7934, dice=0.8840
# Epoch 315 of 1000 took 11.51s | Training: loss=0.4771, iou=0.8055, dice=0.8903
# Epoch 316 of 1000 took 11.40s | Training: loss=0.4528, iou=0.8102, dice=0.8943
# Epoch 317 of 1000 took 11.50s | Training: loss=0.4791, iou=0.8302, dice=0.9069
# Epoch 318 of 1000 took 11.50s | Training: loss=0.5540, iou=0.7916, dice=0.8819
# Epoch 319 of 1000 took 11.40s | Training: loss=0.5102, iou=0.7958, dice=0.8848
# Epoch 320 of 1000 took 11.51s | Training: loss=0.5185, iou=0.8091, dice=0.8940
# Validation: loss=0.8749, iou=0.7766, dice=0.8729
# New best model found with validation loss 0.8749, saving model...
# Epoch 321 of 1000 took 11.51s | Training: loss=0.4938, iou=0.8137, dice=0.8970
# Epoch 322 of 1000 took 11.47s | Training: loss=0.5045, iou=0.7918, dice=0.8827
# Epoch 323 of 1000 took 11.38s | Training: loss=0.4540, iou=0.8185, dice=0.8999
# Epoch 324 of 1000 took 11.35s | Training: loss=0.5636, iou=0.7016, dice=0.8147
# Epoch 325 of 1000 took 11.39s | Training: loss=0.4998, iou=0.7211, dice=0.8360
# Epoch 326 of 1000 took 11.40s | Training: loss=0.5729, iou=0.6884, dice=0.8136
# Epoch 327 of 1000 took 11.39s | Training: loss=0.4885, iou=0.7457, dice=0.8538
# Epoch 328 of 1000 took 11.52s | Training: loss=0.5162, iou=0.7698, dice=0.8678
# Epoch 329 of 1000 took 11.41s | Training: loss=0.4811, iou=0.7703, dice=0.8688
# Epoch 330 of 1000 took 11.49s | Training: loss=0.4827, iou=0.7634, dice=0.8561
# Epoch 331 of 1000 took 11.42s | Training: loss=0.4659, iou=0.7910, dice=0.8820
# Epoch 332 of 1000 took 11.50s | Training: loss=0.4422, iou=0.8339, dice=0.9092
# Epoch 333 of 1000 took 11.48s | Training: loss=0.4859, iou=0.7852, dice=0.8788
# Epoch 334 of 1000 took 11.39s | Training: loss=0.4711, iou=0.8054, dice=0.8917
# Epoch 335 of 1000 took 11.51s | Training: loss=0.4472, iou=0.8273, dice=0.9054
# Epoch 336 of 1000 took 11.40s | Training: loss=0.4651, iou=0.8127, dice=0.8962
# Epoch 337 of 1000 took 11.40s | Training: loss=0.5214, iou=0.7667, dice=0.8647
# Epoch 338 of 1000 took 11.41s | Training: loss=0.4552, iou=0.7909, dice=0.8828
# Epoch 339 of 1000 took 11.41s | Training: loss=0.3863, iou=0.8415, dice=0.9138
# Epoch 340 of 1000 took 11.42s | Training: loss=0.4805, iou=0.8084, dice=0.8932
# Validation: loss=0.8505, iou=0.8134, dice=0.8967
# New best model found with validation loss 0.8505, saving model...
# Epoch 341 of 1000 took 11.54s | Training: loss=0.3917, iou=0.8408, dice=0.9133
# Epoch 342 of 1000 took 11.53s | Training: loss=0.4064, iou=0.8384, dice=0.9115
# Epoch 343 of 1000 took 11.53s | Training: loss=0.3949, iou=0.8422, dice=0.9142
# Epoch 344 of 1000 took 11.51s | Training: loss=0.4184, iou=0.8355, dice=0.9099
# Epoch 345 of 1000 took 11.43s | Training: loss=0.3452, iou=0.8603, dice=0.9248
# Epoch 346 of 1000 took 11.50s | Training: loss=0.4033, iou=0.8264, dice=0.9042
# Epoch 347 of 1000 took 11.50s | Training: loss=0.4041, iou=0.8455, dice=0.9162
# Epoch 348 of 1000 took 11.53s | Training: loss=0.4097, iou=0.8255, dice=0.9041
# Epoch 349 of 1000 took 11.43s | Training: loss=0.4384, iou=0.8237, dice=0.9025
# Epoch 350 of 1000 took 11.41s | Training: loss=0.4080, iou=0.8351, dice=0.9097
# Epoch 351 of 1000 took 11.52s | Training: loss=0.4022, iou=0.8326, dice=0.9084
# Epoch 352 of 1000 took 11.53s | Training: loss=0.3949, iou=0.8347, dice=0.9097
# Epoch 353 of 1000 took 11.50s | Training: loss=0.3818, iou=0.8511, dice=0.9194
# Epoch 354 of 1000 took 11.39s | Training: loss=0.4919, iou=0.8116, dice=0.8948
# Epoch 355 of 1000 took 11.53s | Training: loss=0.3924, iou=0.8509, dice=0.9191
# Epoch 356 of 1000 took 11.40s | Training: loss=0.4323, iou=0.8239, dice=0.9030
# Epoch 357 of 1000 took 11.49s | Training: loss=0.4590, iou=0.8061, dice=0.8922
# Epoch 358 of 1000 took 11.39s | Training: loss=0.4263, iou=0.8147, dice=0.8974
# Epoch 359 of 1000 took 11.52s | Training: loss=0.3617, iou=0.8516, dice=0.9197
# Epoch 360 of 1000 took 11.52s | Training: loss=0.3595, iou=0.8483, dice=0.9177
# Validation: loss=0.8300, iou=0.7646, dice=0.8654
# New best model found with validation loss 0.8300, saving model...
# Epoch 361 of 1000 took 11.40s | Training: loss=0.3938, iou=0.7992, dice=0.8867
# Epoch 362 of 1000 took 11.37s | Training: loss=0.3961, iou=0.8213, dice=0.9011
# Epoch 363 of 1000 took 11.38s | Training: loss=0.3956, iou=0.8246, dice=0.9032
# Epoch 364 of 1000 took 11.38s | Training: loss=0.4134, iou=0.8285, dice=0.9057
# Epoch 365 of 1000 took 11.49s | Training: loss=0.3800, iou=0.8468, dice=0.9168
# Epoch 366 of 1000 took 11.50s | Training: loss=0.3455, iou=0.8516, dice=0.9193
# Epoch 367 of 1000 took 11.42s | Training: loss=0.3694, iou=0.8567, dice=0.9227
# Epoch 368 of 1000 took 11.50s | Training: loss=0.3915, iou=0.8534, dice=0.9207
# Epoch 369 of 1000 took 11.49s | Training: loss=0.4004, iou=0.8390, dice=0.9119
# Epoch 370 of 1000 took 11.51s | Training: loss=0.4046, iou=0.8281, dice=0.9056
# Epoch 371 of 1000 took 11.39s | Training: loss=0.3940, iou=0.8319, dice=0.9076
# Epoch 372 of 1000 took 11.53s | Training: loss=0.3183, iou=0.8681, dice=0.9292
# Epoch 373 of 1000 took 11.50s | Training: loss=0.3475, iou=0.8533, dice=0.9206
# Epoch 374 of 1000 took 11.40s | Training: loss=0.3526, iou=0.8536, dice=0.9209
# Epoch 375 of 1000 took 11.40s | Training: loss=0.3693, iou=0.8375, dice=0.9112
# Epoch 376 of 1000 took 11.51s | Training: loss=0.3832, iou=0.8411, dice=0.9134
# Epoch 377 of 1000 took 11.41s | Training: loss=0.3769, iou=0.8414, dice=0.9135
# Epoch 378 of 1000 took 11.49s | Training: loss=0.3792, iou=0.8297, dice=0.9066
# Epoch 379 of 1000 took 11.43s | Training: loss=0.3871, iou=0.8344, dice=0.9095
# Epoch 380 of 1000 took 11.47s | Training: loss=0.4025, iou=0.8287, dice=0.9058
# Validation: loss=0.8065, iou=0.7816, dice=0.8758
# New best model found with validation loss 0.8065, saving model...
# Epoch 381 of 1000 took 11.47s | Training: loss=0.3182, iou=0.8477, dice=0.9174
# Epoch 382 of 1000 took 11.50s | Training: loss=0.3782, iou=0.8428, dice=0.9142
# Epoch 383 of 1000 took 11.51s | Training: loss=0.3906, iou=0.8196, dice=0.9004
# Epoch 384 of 1000 took 11.48s | Training: loss=0.4123, iou=0.8242, dice=0.9014
# Epoch 385 of 1000 took 11.49s | Training: loss=0.3645, iou=0.8502, dice=0.9189
# Epoch 386 of 1000 took 11.51s | Training: loss=0.3400, iou=0.8455, dice=0.9161
# Epoch 387 of 1000 took 11.56s | Training: loss=0.3560, iou=0.8370, dice=0.9107
# Epoch 388 of 1000 took 11.42s | Training: loss=0.3722, iou=0.8300, dice=0.9067
# Epoch 389 of 1000 took 11.49s | Training: loss=0.4340, iou=0.7888, dice=0.8805
# Epoch 390 of 1000 took 11.38s | Training: loss=0.3823, iou=0.8207, dice=0.9011
# Epoch 391 of 1000 took 11.47s | Training: loss=0.3570, iou=0.8020, dice=0.8896
# Epoch 392 of 1000 took 11.38s | Training: loss=0.3757, iou=0.8351, dice=0.9099
# Epoch 393 of 1000 took 11.49s | Training: loss=0.4050, iou=0.8048, dice=0.8911
# Epoch 394 of 1000 took 11.49s | Training: loss=0.4005, iou=0.8077, dice=0.8931
# Epoch 395 of 1000 took 11.43s | Training: loss=0.2948, iou=0.8490, dice=0.9182
# Epoch 396 of 1000 took 11.52s | Training: loss=0.3206, iou=0.8455, dice=0.9160
# Epoch 397 of 1000 took 11.52s | Training: loss=0.4313, iou=0.8001, dice=0.8884
# Epoch 398 of 1000 took 11.53s | Training: loss=0.3169, iou=0.8490, dice=0.9180
# Epoch 399 of 1000 took 11.50s | Training: loss=0.3567, iou=0.8481, dice=0.9175
# Epoch 400 of 1000 took 11.52s | Training: loss=0.3643, iou=0.8291, dice=0.9062
# Validation: loss=0.7886, iou=0.8290, dice=0.9063
# New best model found with validation loss 0.7886, saving model...
# Epoch 401 of 1000 took 11.49s | Training: loss=0.3922, iou=0.8215, dice=0.9014
# Epoch 402 of 1000 took 11.51s | Training: loss=0.3456, iou=0.8121, dice=0.8958
# Epoch 403 of 1000 took 11.50s | Training: loss=0.3418, iou=0.8307, dice=0.9072
# Epoch 404 of 1000 took 11.51s | Training: loss=0.3427, iou=0.8426, dice=0.9143
# Epoch 405 of 1000 took 11.48s | Training: loss=0.3432, iou=0.8292, dice=0.9064
# Epoch 406 of 1000 took 11.49s | Training: loss=0.3127, iou=0.8565, dice=0.9225
# Epoch 407 of 1000 took 11.50s | Training: loss=0.3280, iou=0.8435, dice=0.9149
# Epoch 408 of 1000 took 11.47s | Training: loss=0.3655, iou=0.8325, dice=0.9082
# Epoch 409 of 1000 took 11.41s | Training: loss=0.3436, iou=0.8516, dice=0.9196
# Epoch 410 of 1000 took 11.52s | Training: loss=0.3744, iou=0.8413, dice=0.9132
# Epoch 411 of 1000 took 11.50s | Training: loss=0.3063, iou=0.8402, dice=0.9127
# Epoch 412 of 1000 took 11.51s | Training: loss=0.3161, iou=0.8472, dice=0.9170
# Epoch 413 of 1000 took 11.42s | Training: loss=0.2820, iou=0.8538, dice=0.9210
# Epoch 414 of 1000 took 11.50s | Training: loss=0.3482, iou=0.8339, dice=0.9089
# Epoch 415 of 1000 took 11.41s | Training: loss=0.3736, iou=0.8231, dice=0.9023
# Epoch 416 of 1000 took 11.54s | Training: loss=0.3040, iou=0.8203, dice=0.9006
# Epoch 417 of 1000 took 11.51s | Training: loss=0.3395, iou=0.8019, dice=0.8890
# Epoch 418 of 1000 took 11.50s | Training: loss=0.3621, iou=0.8096, dice=0.8939
# Epoch 419 of 1000 took 11.44s | Training: loss=0.3509, iou=0.8066, dice=0.8912
# Epoch 420 of 1000 took 11.43s | Training: loss=0.3269, iou=0.8291, dice=0.9062
# Validation: loss=0.7641, iou=0.8245, dice=0.9036
# New best model found with validation loss 0.7641, saving model...
# Epoch 421 of 1000 took 11.53s | Training: loss=0.3190, iou=0.8310, dice=0.9074
# Epoch 422 of 1000 took 11.49s | Training: loss=0.3778, iou=0.7943, dice=0.8827
# Epoch 423 of 1000 took 11.54s | Training: loss=0.3599, iou=0.8180, dice=0.8993
# Epoch 424 of 1000 took 11.52s | Training: loss=0.3355, iou=0.8297, dice=0.9068
# Epoch 425 of 1000 took 11.50s | Training: loss=0.2898, iou=0.8470, dice=0.9170
# Epoch 426 of 1000 took 11.50s | Training: loss=0.2944, iou=0.8431, dice=0.9147
# Epoch 427 of 1000 took 11.40s | Training: loss=0.2940, iou=0.8520, dice=0.9199
# Epoch 428 of 1000 took 11.51s | Training: loss=0.2864, iou=0.8536, dice=0.9208
# Epoch 429 of 1000 took 11.40s | Training: loss=0.3430, iou=0.8416, dice=0.9138
# Epoch 430 of 1000 took 11.55s | Training: loss=0.3222, iou=0.8262, dice=0.9046
# Epoch 431 of 1000 took 11.52s | Training: loss=0.3326, iou=0.8133, dice=0.8963
# Epoch 432 of 1000 took 11.48s | Training: loss=0.3256, iou=0.7940, dice=0.8848
# Epoch 433 of 1000 took 11.52s | Training: loss=0.2694, iou=0.8491, dice=0.9183
# Epoch 434 of 1000 took 11.52s | Training: loss=0.3267, iou=0.8194, dice=0.8997
# Epoch 435 of 1000 took 11.53s | Training: loss=0.3235, iou=0.8314, dice=0.9072
# Epoch 436 of 1000 took 11.51s | Training: loss=0.2684, iou=0.8573, dice=0.9228
# Epoch 437 of 1000 took 11.39s | Training: loss=0.2706, iou=0.8533, dice=0.9204
# Epoch 438 of 1000 took 11.47s | Training: loss=0.2622, iou=0.8583, dice=0.9234
# Epoch 439 of 1000 took 11.54s | Training: loss=0.2554, iou=0.8614, dice=0.9253
# Epoch 440 of 1000 took 11.44s | Training: loss=0.2726, iou=0.8522, dice=0.9201
# Validation: loss=0.7379, iou=0.8223, dice=0.9019
# New best model found with validation loss 0.7379, saving model...
# Epoch 441 of 1000 took 11.56s | Training: loss=0.2659, iou=0.8558, dice=0.9222
# Epoch 442 of 1000 took 11.52s | Training: loss=0.2753, iou=0.8614, dice=0.9253
# Epoch 443 of 1000 took 11.51s | Training: loss=0.3131, iou=0.8609, dice=0.9250
# Epoch 444 of 1000 took 11.40s | Training: loss=0.2835, iou=0.8601, dice=0.9246
# Epoch 445 of 1000 took 11.48s | Training: loss=0.2957, iou=0.8492, dice=0.9181
# Epoch 446 of 1000 took 11.41s | Training: loss=0.2414, iou=0.8548, dice=0.9214
# Epoch 447 of 1000 took 11.51s | Training: loss=0.2876, iou=0.8353, dice=0.9101
# Epoch 448 of 1000 took 11.54s | Training: loss=0.3008, iou=0.8589, dice=0.9240
# Epoch 449 of 1000 took 11.55s | Training: loss=0.2563, iou=0.8636, dice=0.9267
# Epoch 450 of 1000 took 11.56s | Training: loss=0.2712, iou=0.8548, dice=0.9216
# Epoch 451 of 1000 took 11.45s | Training: loss=0.3020, iou=0.8416, dice=0.9137
# Epoch 452 of 1000 took 11.54s | Training: loss=0.2663, iou=0.8576, dice=0.9231
# Epoch 453 of 1000 took 11.49s | Training: loss=0.2818, iou=0.8630, dice=0.9263
# Epoch 454 of 1000 took 11.51s | Training: loss=0.2345, iou=0.8641, dice=0.9270
# Epoch 455 of 1000 took 11.51s | Training: loss=0.2947, iou=0.8493, dice=0.9178
# Epoch 456 of 1000 took 11.48s | Training: loss=0.2864, iou=0.8512, dice=0.9195
# Epoch 457 of 1000 took 11.40s | Training: loss=0.2894, iou=0.8349, dice=0.9086
# Epoch 458 of 1000 took 11.50s | Training: loss=0.2694, iou=0.8586, dice=0.9238
# Epoch 459 of 1000 took 11.41s | Training: loss=0.2916, iou=0.8649, dice=0.9275
# Epoch 460 of 1000 took 11.51s | Training: loss=0.2931, iou=0.8448, dice=0.9155
# Validation: loss=0.7191, iou=0.8278, dice=0.9053
# New best model found with validation loss 0.7191, saving model...
# Epoch 461 of 1000 took 11.53s | Training: loss=0.3444, iou=0.8289, dice=0.9055
# Epoch 462 of 1000 took 11.48s | Training: loss=0.2690, iou=0.8509, dice=0.9190
# Epoch 463 of 1000 took 11.49s | Training: loss=0.2966, iou=0.8402, dice=0.9126
# Epoch 464 of 1000 took 11.49s | Training: loss=0.3053, iou=0.8422, dice=0.9141
# Epoch 465 of 1000 took 11.40s | Training: loss=0.2636, iou=0.8334, dice=0.9086
# Epoch 466 of 1000 took 11.48s | Training: loss=0.2870, iou=0.8333, dice=0.9087
# Epoch 467 of 1000 took 11.50s | Training: loss=0.2825, iou=0.8515, dice=0.9197
# Epoch 468 of 1000 took 11.54s | Training: loss=0.2716, iou=0.8417, dice=0.9137
# Epoch 469 of 1000 took 11.45s | Training: loss=0.2746, iou=0.8554, dice=0.9214
# Epoch 470 of 1000 took 11.53s | Training: loss=0.2758, iou=0.8477, dice=0.9172
# Epoch 471 of 1000 took 11.52s | Training: loss=0.3207, iou=0.8504, dice=0.9188
# Epoch 472 of 1000 took 11.50s | Training: loss=0.2706, iou=0.8433, dice=0.9142
# Epoch 473 of 1000 took 11.39s | Training: loss=0.2485, iou=0.8484, dice=0.9178
# Epoch 474 of 1000 took 11.52s | Training: loss=0.2798, iou=0.8440, dice=0.9153
# Epoch 475 of 1000 took 11.48s | Training: loss=0.2430, iou=0.8510, dice=0.9191
# Epoch 476 of 1000 took 11.50s | Training: loss=0.2728, iou=0.8480, dice=0.9175
# Epoch 477 of 1000 took 11.51s | Training: loss=0.2735, iou=0.8597, dice=0.9244
# Epoch 478 of 1000 took 11.41s | Training: loss=0.3450, iou=0.8261, dice=0.9040
# Epoch 479 of 1000 took 11.50s | Training: loss=0.2506, iou=0.8540, dice=0.9206
# Epoch 480 of 1000 took 11.51s | Training: loss=0.2788, iou=0.8314, dice=0.9033
# Validation: loss=0.7028, iou=0.8419, dice=0.9141
# New best model found with validation loss 0.7028, saving model...
# Epoch 481 of 1000 took 11.43s | Training: loss=0.2563, iou=0.8497, dice=0.9186
# Epoch 482 of 1000 took 11.48s | Training: loss=0.2992, iou=0.8352, dice=0.9100
# Epoch 483 of 1000 took 11.45s | Training: loss=0.2526, iou=0.8601, dice=0.9247
# Epoch 484 of 1000 took 11.36s | Training: loss=0.2862, iou=0.8423, dice=0.9134
# Epoch 485 of 1000 took 11.49s | Training: loss=0.2147, iou=0.8691, dice=0.9299
# Epoch 486 of 1000 took 11.48s | Training: loss=0.2184, iou=0.8664, dice=0.9283
# Epoch 487 of 1000 took 11.43s | Training: loss=0.2144, iou=0.8705, dice=0.9306
# Epoch 488 of 1000 took 11.51s | Training: loss=0.2704, iou=0.8509, dice=0.9193
# Epoch 489 of 1000 took 11.49s | Training: loss=0.2510, iou=0.8519, dice=0.9198
# Epoch 490 of 1000 took 11.56s | Training: loss=0.2746, iou=0.8505, dice=0.9180
# Epoch 491 of 1000 took 11.42s | Training: loss=0.2505, iou=0.8618, dice=0.9256
# Epoch 492 of 1000 took 11.40s | Training: loss=0.2667, iou=0.8602, dice=0.9247
# Epoch 493 of 1000 took 11.50s | Training: loss=0.2460, iou=0.8513, dice=0.9194
# Epoch 494 of 1000 took 11.39s | Training: loss=0.2672, iou=0.8560, dice=0.9223
# Epoch 495 of 1000 took 11.51s | Training: loss=0.2360, iou=0.8535, dice=0.9207
# Epoch 496 of 1000 took 11.51s | Training: loss=0.2231, iou=0.8620, dice=0.9258
# Epoch 497 of 1000 took 11.47s | Training: loss=0.2654, iou=0.8537, dice=0.9209
# Epoch 498 of 1000 took 11.52s | Training: loss=0.3589, iou=0.7367, dice=0.7996
# Epoch 499 of 1000 took 11.55s | Training: loss=0.2259, iou=0.8587, dice=0.9238
# Epoch 500 of 1000 took 11.52s | Training: loss=0.2632, iou=0.8408, dice=0.9123
# Validation: loss=0.6810, iou=0.8498, dice=0.9187
# New best model found with validation loss 0.6810, saving model...
# Epoch 501 of 1000 took 11.47s | Training: loss=0.2350, iou=0.8527, dice=0.9203
# Epoch 502 of 1000 took 11.51s | Training: loss=0.2569, iou=0.8363, dice=0.9098
# Epoch 503 of 1000 took 11.50s | Training: loss=0.2202, iou=0.8477, dice=0.9172
# Epoch 504 of 1000 took 11.43s | Training: loss=0.2421, iou=0.8526, dice=0.9201
# Epoch 505 of 1000 took 11.42s | Training: loss=0.2492, iou=0.8615, dice=0.9255
# Epoch 506 of 1000 took 11.51s | Training: loss=0.2284, iou=0.8580, dice=0.9235
# Epoch 507 of 1000 took 11.51s | Training: loss=0.2244, iou=0.8567, dice=0.9228
# Epoch 508 of 1000 took 11.44s | Training: loss=0.2115, iou=0.8651, dice=0.9275
# Epoch 509 of 1000 took 11.38s | Training: loss=0.2325, iou=0.8570, dice=0.9227
# Epoch 510 of 1000 took 11.51s | Training: loss=0.2589, iou=0.8614, dice=0.9253
# Epoch 511 of 1000 took 11.42s | Training: loss=0.2173, iou=0.8608, dice=0.9250
# Epoch 512 of 1000 took 11.50s | Training: loss=0.2193, iou=0.8783, dice=0.9351
# Epoch 513 of 1000 took 11.54s | Training: loss=0.2455, iou=0.8606, dice=0.9249
# Epoch 514 of 1000 took 11.53s | Training: loss=0.2654, iou=0.8402, dice=0.9124
# Epoch 515 of 1000 took 11.45s | Training: loss=0.2211, iou=0.8628, dice=0.9262
# Epoch 516 of 1000 took 11.56s | Training: loss=0.1879, iou=0.8768, dice=0.9342
# Epoch 517 of 1000 took 11.54s | Training: loss=0.2522, iou=0.8506, dice=0.9181
# Epoch 518 of 1000 took 11.52s | Training: loss=0.2020, iou=0.8631, dice=0.9264
# Epoch 519 of 1000 took 11.56s | Training: loss=0.2342, iou=0.8438, dice=0.9144
# Epoch 520 of 1000 took 11.45s | Training: loss=0.2292, iou=0.8547, dice=0.9215
# Validation: loss=0.6649, iou=0.7917, dice=0.8816
# New best model found with validation loss 0.6649, saving model...
# Epoch 521 of 1000 took 11.55s | Training: loss=0.2321, iou=0.8450, dice=0.9158
# Epoch 522 of 1000 took 11.52s | Training: loss=0.2129, iou=0.8412, dice=0.9135
# Epoch 523 of 1000 took 11.52s | Training: loss=0.2591, iou=0.8398, dice=0.9106
# Epoch 524 of 1000 took 11.41s | Training: loss=0.2214, iou=0.8581, dice=0.9233
# Epoch 525 of 1000 took 11.49s | Training: loss=0.2286, iou=0.8499, dice=0.9185
# Epoch 526 of 1000 took 11.52s | Training: loss=0.2203, iou=0.8707, dice=0.9308
# Epoch 527 of 1000 took 11.54s | Training: loss=0.2143, iou=0.8603, dice=0.9247
# Epoch 528 of 1000 took 11.53s | Training: loss=0.2697, iou=0.8401, dice=0.9122
# Epoch 529 of 1000 took 11.57s | Training: loss=0.2414, iou=0.8288, dice=0.9052
# Epoch 530 of 1000 took 11.55s | Training: loss=0.2440, iou=0.8403, dice=0.9129
# Epoch 531 of 1000 took 11.43s | Training: loss=0.2095, iou=0.8424, dice=0.9142
# Epoch 532 of 1000 took 11.42s | Training: loss=0.2238, iou=0.8467, dice=0.9168
# Epoch 533 of 1000 took 11.52s | Training: loss=0.1994, iou=0.8579, dice=0.9234
# Epoch 534 of 1000 took 11.54s | Training: loss=0.2741, iou=0.8353, dice=0.9101
# Epoch 535 of 1000 took 11.52s | Training: loss=0.2502, iou=0.8435, dice=0.9147
# Epoch 536 of 1000 took 11.39s | Training: loss=0.2701, iou=0.8446, dice=0.9156
# Epoch 537 of 1000 took 11.39s | Training: loss=0.2231, iou=0.8398, dice=0.9125
# Epoch 538 of 1000 took 11.49s | Training: loss=0.2965, iou=0.7897, dice=0.8817
# Epoch 539 of 1000 took 11.51s | Training: loss=0.2576, iou=0.8402, dice=0.9123
# Epoch 540 of 1000 took 11.54s | Training: loss=0.1984, iou=0.8550, dice=0.9217
# Validation: loss=0.6388, iou=0.8503, dice=0.9190
# New best model found with validation loss 0.6388, saving model...
# Epoch 541 of 1000 took 11.54s | Training: loss=0.1862, iou=0.8715, dice=0.9313
# Epoch 542 of 1000 took 11.55s | Training: loss=0.2334, iou=0.8431, dice=0.9140
# Epoch 543 of 1000 took 11.55s | Training: loss=0.2275, iou=0.8529, dice=0.9205
# Epoch 544 of 1000 took 11.49s | Training: loss=0.2387, iou=0.8510, dice=0.9192
# Epoch 545 of 1000 took 11.47s | Training: loss=0.2279, iou=0.8578, dice=0.9231
# Epoch 546 of 1000 took 11.40s | Training: loss=0.2010, iou=0.8630, dice=0.9263
# Epoch 547 of 1000 took 11.51s | Training: loss=0.2540, iou=0.8547, dice=0.9210
# Epoch 548 of 1000 took 11.38s | Training: loss=0.2292, iou=0.8517, dice=0.9192
# Epoch 549 of 1000 took 11.41s | Training: loss=0.2679, iou=0.8288, dice=0.9046
# Epoch 550 of 1000 took 11.51s | Training: loss=0.1975, iou=0.8561, dice=0.9223
# Epoch 551 of 1000 took 11.50s | Training: loss=0.1802, iou=0.8633, dice=0.9265
# Epoch 552 of 1000 took 11.52s | Training: loss=0.1724, iou=0.8752, dice=0.9333
# Epoch 553 of 1000 took 11.41s | Training: loss=0.1995, iou=0.8611, dice=0.9251
# Epoch 554 of 1000 took 11.51s | Training: loss=0.2089, iou=0.8620, dice=0.9256
# Epoch 555 of 1000 took 11.41s | Training: loss=0.2100, iou=0.8522, dice=0.9199
# Epoch 556 of 1000 took 11.52s | Training: loss=0.2993, iou=0.8196, dice=0.8981
# Epoch 557 of 1000 took 11.52s | Training: loss=0.2967, iou=0.8015, dice=0.8814
# Epoch 558 of 1000 took 11.52s | Training: loss=0.2014, iou=0.8591, dice=0.9239
# Epoch 559 of 1000 took 11.46s | Training: loss=0.2317, iou=0.8410, dice=0.9133
# Epoch 560 of 1000 took 11.53s | Training: loss=0.1869, iou=0.8600, dice=0.9245
# Validation: loss=0.6251, iou=0.8285, dice=0.9057
# New best model found with validation loss 0.6251, saving model...
# Epoch 561 of 1000 took 11.43s | Training: loss=0.2187, iou=0.8499, dice=0.9185
# Epoch 562 of 1000 took 11.52s | Training: loss=0.2299, iou=0.8574, dice=0.9231
# Epoch 563 of 1000 took 11.51s | Training: loss=0.2075, iou=0.8576, dice=0.9231
# Epoch 564 of 1000 took 11.49s | Training: loss=0.1970, iou=0.8615, dice=0.9254
# Epoch 565 of 1000 took 11.41s | Training: loss=0.1845, iou=0.8722, dice=0.9317
# Epoch 566 of 1000 took 11.52s | Training: loss=0.2717, iou=0.8246, dice=0.9033
# Epoch 567 of 1000 took 11.50s | Training: loss=0.2094, iou=0.8455, dice=0.9159
# ...
# Epoch 813 of 1000 took 11.51s | Training: loss=0.1347, iou=0.8711, dice=0.9306
# Epoch 814 of 1000 took 11.52s | Training: loss=0.1108, iou=0.8847, dice=0.9387
# Epoch 815 of 1000 took 11.48s | Training: loss=0.1574, iou=0.8598, dice=0.9239
# Epoch 816 of 1000 took 11.51s | Training: loss=0.1000, iou=0.8942, dice=0.9441
# Epoch 817 of 1000 took 11.50s | Training: loss=0.1201, iou=0.8772, dice=0.9345
# Epoch 818 of 1000 took 11.51s | Training: loss=0.1242, iou=0.8837, dice=0.9381
# Epoch 819 of 1000 took 11.52s | Training: loss=0.1236, iou=0.8794, dice=0.9357
# Epoch 820 of 1000 took 11.43s | Training: loss=0.1150, iou=0.8895, dice=0.9415
# Validation: loss=0.4165, iou=0.8525, dice=0.9202
# New best model found with validation loss 0.4165, saving model...
# Epoch 821 of 1000 took 11.41s | Training: loss=0.1006, iou=0.8894, dice=0.9414
# Epoch 822 of 1000 took 11.46s | Training: loss=0.1395, iou=0.8739, dice=0.9321
# Epoch 823 of 1000 took 11.45s | Training: loss=0.1190, iou=0.8758, dice=0.9337
# Epoch 824 of 1000 took 11.37s | Training: loss=0.1176, iou=0.8873, dice=0.9400
# Epoch 825 of 1000 took 11.41s | Training: loss=0.1134, iou=0.8852, dice=0.9389
# Epoch 826 of 1000 took 11.54s | Training: loss=0.1264, iou=0.8838, dice=0.9380
# Epoch 827 of 1000 took 11.48s | Training: loss=0.1079, iou=0.8919, dice=0.9428
# Epoch 828 of 1000 took 11.55s | Training: loss=0.1271, iou=0.8724, dice=0.9318
# Epoch 829 of 1000 took 11.53s | Training: loss=0.0981, iou=0.8946, dice=0.9443
# Epoch 830 of 1000 took 11.50s | Training: loss=0.0984, iou=0.8939, dice=0.9439
# Epoch 831 of 1000 took 11.39s | Training: loss=0.1090, iou=0.8847, dice=0.9386
# Epoch 832 of 1000 took 11.42s | Training: loss=0.1016, iou=0.8899, dice=0.9416
# Epoch 833 of 1000 took 11.52s | Training: loss=0.1393, iou=0.8672, dice=0.9282
# Epoch 834 of 1000 took 11.53s | Training: loss=0.1259, iou=0.8603, dice=0.9239
# Epoch 835 of 1000 took 11.51s | Training: loss=0.1340, iou=0.8618, dice=0.9254
# Epoch 836 of 1000 took 11.50s | Training: loss=0.1021, iou=0.8860, dice=0.9394
# Epoch 837 of 1000 took 11.51s | Training: loss=0.1184, iou=0.8799, dice=0.9360
# Epoch 838 of 1000 took 11.40s | Training: loss=0.1106, iou=0.8849, dice=0.9387
# Epoch 839 of 1000 took 11.52s | Training: loss=0.1006, iou=0.8892, dice=0.9413
# Epoch 840 of 1000 took 11.51s | Training: loss=0.1068, iou=0.8880, dice=0.9406
# Validation: loss=0.4093, iou=0.8533, dice=0.9208
# New best model found with validation loss 0.4093, saving model...
# Epoch 841 of 1000 took 11.43s | Training: loss=0.0957, iou=0.8954, dice=0.9447
# Epoch 842 of 1000 took 11.53s | Training: loss=0.1081, iou=0.8869, dice=0.9398
# Epoch 843 of 1000 took 11.52s | Training: loss=0.1008, iou=0.8989, dice=0.9467
# Epoch 844 of 1000 took 11.40s | Training: loss=0.1135, iou=0.8851, dice=0.9387
# Epoch 845 of 1000 took 11.53s | Training: loss=0.1571, iou=0.8535, dice=0.9201
# Epoch 846 of 1000 took 11.47s | Training: loss=0.1674, iou=0.8506, dice=0.9184
# Epoch 847 of 1000 took 11.45s | Training: loss=0.1076, iou=0.8811, dice=0.9368
# Epoch 848 of 1000 took 11.44s | Training: loss=0.1165, iou=0.8824, dice=0.9373
# Epoch 849 of 1000 took 11.54s | Training: loss=0.1121, iou=0.8786, dice=0.9352
# Epoch 850 of 1000 took 11.51s | Training: loss=0.1272, iou=0.8828, dice=0.9376
# Epoch 851 of 1000 took 11.41s | Training: loss=0.1199, iou=0.8786, dice=0.9353
# Epoch 852 of 1000 took 11.49s | Training: loss=0.1138, iou=0.8779, dice=0.9349
# Epoch 853 of 1000 took 11.50s | Training: loss=0.1239, iou=0.8705, dice=0.9307
# Epoch 854 of 1000 took 11.53s | Training: loss=0.0997, iou=0.8929, dice=0.9433
# Epoch 855 of 1000 took 11.41s | Training: loss=0.0957, iou=0.8964, dice=0.9453
# Epoch 856 of 1000 took 11.52s | Training: loss=0.0997, iou=0.8910, dice=0.9422
# Epoch 857 of 1000 took 11.42s | Training: loss=0.1252, iou=0.8734, dice=0.9317
# Epoch 858 of 1000 took 11.56s | Training: loss=0.1000, iou=0.8881, dice=0.9406
# Epoch 859 of 1000 took 11.52s | Training: loss=0.1075, iou=0.8900, dice=0.9417
# Epoch 860 of 1000 took 11.52s | Training: loss=0.1385, iou=0.8713, dice=0.9304
# Validation: loss=0.3966, iou=0.8508, dice=0.9193
# New best model found with validation loss 0.3966, saving model...
# Epoch 861 of 1000 took 11.42s | Training: loss=0.1480, iou=0.8591, dice=0.9235
# Epoch 862 of 1000 took 11.40s | Training: loss=0.1144, iou=0.8689, dice=0.9297
# Epoch 863 of 1000 took 11.52s | Training: loss=0.1139, iou=0.8852, dice=0.9389
# Epoch 864 of 1000 took 11.53s | Training: loss=0.1172, iou=0.8816, dice=0.9368
# Epoch 865 of 1000 took 11.51s | Training: loss=0.1095, iou=0.8858, dice=0.9391
# Epoch 866 of 1000 took 11.51s | Training: loss=0.0979, iou=0.8926, dice=0.9431
# Epoch 867 of 1000 took 11.55s | Training: loss=0.1035, iou=0.8883, dice=0.9407
# Epoch 868 of 1000 took 11.55s | Training: loss=0.1197, iou=0.8902, dice=0.9419
# Epoch 869 of 1000 took 11.54s | Training: loss=0.1188, iou=0.8706, dice=0.9305
# Epoch 870 of 1000 took 11.57s | Training: loss=0.1349, iou=0.8424, dice=0.9141
# Epoch 871 of 1000 took 11.57s | Training: loss=0.1453, iou=0.8319, dice=0.9075
# Epoch 872 of 1000 took 11.44s | Training: loss=0.1268, iou=0.8585, dice=0.9236
# Epoch 873 of 1000 took 11.55s | Training: loss=0.1247, iou=0.8550, dice=0.9214
# Epoch 874 of 1000 took 11.41s | Training: loss=0.1208, iou=0.8645, dice=0.9270
# Epoch 875 of 1000 took 11.50s | Training: loss=0.1340, iou=0.8551, dice=0.9217
# Epoch 876 of 1000 took 11.49s | Training: loss=0.1265, iou=0.8695, dice=0.9298
# Epoch 877 of 1000 took 11.52s | Training: loss=0.1162, iou=0.8836, dice=0.9381
# Epoch 878 of 1000 took 11.52s | Training: loss=0.1080, iou=0.8837, dice=0.9381
# Epoch 879 of 1000 took 11.39s | Training: loss=0.1071, iou=0.8879, dice=0.9405
# Epoch 880 of 1000 took 11.41s | Training: loss=0.1043, iou=0.8885, dice=0.9408
# Validation: loss=0.3780, iou=0.8458, dice=0.9162
# New best model found with validation loss 0.3780, saving model...
# Epoch 881 of 1000 took 11.54s | Training: loss=0.0973, iou=0.8950, dice=0.9445
# Epoch 882 of 1000 took 11.50s | Training: loss=0.1052, iou=0.8881, dice=0.9407
# Epoch 883 of 1000 took 11.40s | Training: loss=0.1174, iou=0.8784, dice=0.9349
# Epoch 884 of 1000 took 11.49s | Training: loss=0.1004, iou=0.8888, dice=0.9411
# Epoch 885 of 1000 took 11.44s | Training: loss=0.1040, iou=0.8820, dice=0.9371
# Epoch 886 of 1000 took 11.50s | Training: loss=0.1282, iou=0.8804, dice=0.9362
# Epoch 887 of 1000 took 11.44s | Training: loss=0.1032, iou=0.8884, dice=0.9409
# Epoch 888 of 1000 took 11.52s | Training: loss=0.1025, iou=0.8907, dice=0.9420
# Epoch 889 of 1000 took 11.53s | Training: loss=0.0996, iou=0.8935, dice=0.9437
# Epoch 890 of 1000 took 11.55s | Training: loss=0.1014, iou=0.8885, dice=0.9408
# Epoch 891 of 1000 took 11.48s | Training: loss=0.0978, iou=0.8906, dice=0.9420
# Epoch 892 of 1000 took 11.45s | Training: loss=0.1013, iou=0.8845, dice=0.9386
# Epoch 893 of 1000 took 11.54s | Training: loss=0.1234, iou=0.8752, dice=0.9331
# Epoch 894 of 1000 took 11.41s | Training: loss=0.1295, iou=0.8559, dice=0.9211
# Epoch 895 of 1000 took 11.41s | Training: loss=0.1084, iou=0.8836, dice=0.9379
# Epoch 896 of 1000 took 11.56s | Training: loss=0.1296, iou=0.8628, dice=0.9262
# Epoch 897 of 1000 took 11.51s | Training: loss=0.1100, iou=0.8766, dice=0.9341
# Epoch 898 of 1000 took 11.50s | Training: loss=0.1289, iou=0.8541, dice=0.9209
# Epoch 899 of 1000 took 11.54s | Training: loss=0.0981, iou=0.8865, dice=0.9398
# Epoch 900 of 1000 took 11.51s | Training: loss=0.1061, iou=0.8851, dice=0.9388
# Validation: loss=0.3730, iou=0.8415, dice=0.9139
# New best model found with validation loss 0.3730, saving model...
# Epoch 901 of 1000 took 11.55s | Training: loss=0.0975, iou=0.8923, dice=0.9430
# Epoch 902 of 1000 took 11.53s | Training: loss=0.1044, iou=0.8852, dice=0.9389
# Epoch 903 of 1000 took 11.40s | Training: loss=0.1148, iou=0.8783, dice=0.9348
# Epoch 904 of 1000 took 11.54s | Training: loss=0.1006, iou=0.8878, dice=0.9405
# Epoch 905 of 1000 took 11.49s | Training: loss=0.1065, iou=0.8871, dice=0.9400
# Epoch 906 of 1000 took 11.49s | Training: loss=0.0934, iou=0.8947, dice=0.9443
# Epoch 907 of 1000 took 11.50s | Training: loss=0.1233, iou=0.8719, dice=0.9307
# Epoch 908 of 1000 took 11.40s | Training: loss=0.0931, iou=0.8931, dice=0.9434
# Epoch 909 of 1000 took 11.50s | Training: loss=0.1011, iou=0.8864, dice=0.9396
# Epoch 910 of 1000 took 11.50s | Training: loss=0.0989, iou=0.8885, dice=0.9409
# Epoch 911 of 1000 took 11.42s | Training: loss=0.1189, iou=0.8811, dice=0.9366
# Epoch 912 of 1000 took 11.41s | Training: loss=0.1013, iou=0.8901, dice=0.9416
# Epoch 913 of 1000 took 11.53s | Training: loss=0.0956, iou=0.8926, dice=0.9432
# Epoch 914 of 1000 took 11.55s | Training: loss=0.1053, iou=0.8815, dice=0.9365
# Epoch 915 of 1000 took 11.53s | Training: loss=0.0955, iou=0.8883, dice=0.9408
# Epoch 916 of 1000 took 11.55s | Training: loss=0.0965, iou=0.8924, dice=0.9431
# Epoch 917 of 1000 took 11.56s | Training: loss=0.0968, iou=0.8906, dice=0.9421
# Epoch 918 of 1000 took 11.54s | Training: loss=0.0980, iou=0.8948, dice=0.9444
# Epoch 919 of 1000 took 11.40s | Training: loss=0.1075, iou=0.8768, dice=0.9342
# Epoch 920 of 1000 took 11.50s | Training: loss=0.1733, iou=0.8376, dice=0.9070
# Validation: loss=0.3633, iou=0.8381, dice=0.9118
# New best model found with validation loss 0.3633, saving model...
# Epoch 921 of 1000 took 11.58s | Training: loss=0.0925, iou=0.8911, dice=0.9423
# Epoch 922 of 1000 took 11.54s | Training: loss=0.0930, iou=0.8922, dice=0.9429
# Epoch 923 of 1000 took 11.53s | Training: loss=0.0913, iou=0.8948, dice=0.9444
# Epoch 924 of 1000 took 11.41s | Training: loss=0.0942, iou=0.8911, dice=0.9423
# Epoch 925 of 1000 took 11.44s | Training: loss=0.1071, iou=0.8781, dice=0.9350
# Epoch 926 of 1000 took 11.51s | Training: loss=0.1064, iou=0.8862, dice=0.9396
# Epoch 927 of 1000 took 11.53s | Training: loss=0.0894, iou=0.8949, dice=0.9444
# Epoch 928 of 1000 took 11.46s | Training: loss=0.1352, iou=0.8529, dice=0.9151
# Epoch 929 of 1000 took 11.54s | Training: loss=0.1270, iou=0.8495, dice=0.9183
# Epoch 930 of 1000 took 11.46s | Training: loss=0.1180, iou=0.8616, dice=0.9256
# Epoch 931 of 1000 took 11.52s | Training: loss=0.1298, iou=0.8457, dice=0.9158
# Epoch 932 of 1000 took 11.58s | Training: loss=0.1229, iou=0.8483, dice=0.9174
# Epoch 933 of 1000 took 11.44s | Training: loss=0.1303, iou=0.8492, dice=0.9181
# Epoch 934 of 1000 took 11.45s | Training: loss=0.1008, iou=0.8806, dice=0.9364
# Epoch 935 of 1000 took 11.54s | Training: loss=0.1127, iou=0.8740, dice=0.9323
# Epoch 936 of 1000 took 11.55s | Training: loss=0.1191, iou=0.8685, dice=0.9294
# Epoch 937 of 1000 took 11.52s | Training: loss=0.1126, iou=0.8751, dice=0.9331
# Epoch 938 of 1000 took 11.50s | Training: loss=0.0917, iou=0.8932, dice=0.9435
# Epoch 939 of 1000 took 11.40s | Training: loss=0.0888, iou=0.8931, dice=0.9435
# Epoch 940 of 1000 took 11.42s | Training: loss=0.0870, iou=0.8987, dice=0.9466
# Validation: loss=0.3445, iou=0.8508, dice=0.9193
# New best model found with validation loss 0.3445, saving model...
# Epoch 941 of 1000 took 11.54s | Training: loss=0.0856, iou=0.8960, dice=0.9451
# Epoch 942 of 1000 took 11.42s | Training: loss=0.1028, iou=0.8854, dice=0.9390
# Epoch 943 of 1000 took 11.40s | Training: loss=0.0937, iou=0.8903, dice=0.9418
# Epoch 944 of 1000 took 11.41s | Training: loss=0.0971, iou=0.8924, dice=0.9429
# Epoch 945 of 1000 took 11.48s | Training: loss=0.0924, iou=0.8912, dice=0.9424
# Epoch 946 of 1000 took 11.39s | Training: loss=0.0860, iou=0.8995, dice=0.9471
# Epoch 947 of 1000 took 11.39s | Training: loss=0.0867, iou=0.8962, dice=0.9452
# Epoch 948 of 1000 took 11.53s | Training: loss=0.0865, iou=0.8987, dice=0.9466
# Epoch 949 of 1000 took 11.50s | Training: loss=0.0950, iou=0.8908, dice=0.9421
# Epoch 950 of 1000 took 11.40s | Training: loss=0.0931, iou=0.8977, dice=0.9460
# Epoch 951 of 1000 took 11.42s | Training: loss=0.0938, iou=0.8948, dice=0.9444
# Epoch 952 of 1000 took 11.51s | Training: loss=0.0960, iou=0.8987, dice=0.9466
# Epoch 953 of 1000 took 11.45s | Training: loss=0.1018, iou=0.8894, dice=0.9413
# Epoch 954 of 1000 took 11.54s | Training: loss=0.0874, iou=0.8990, dice=0.9467
# Epoch 955 of 1000 took 11.44s | Training: loss=0.0928, iou=0.8950, dice=0.9446
# Epoch 956 of 1000 took 11.54s | Training: loss=0.0973, iou=0.8861, dice=0.9395
# Epoch 957 of 1000 took 11.51s | Training: loss=0.1026, iou=0.8853, dice=0.9389
# Epoch 958 of 1000 took 11.43s | Training: loss=0.0936, iou=0.8894, dice=0.9413
# Epoch 959 of 1000 took 11.49s | Training: loss=0.0843, iou=0.9005, dice=0.9476
# Epoch 960 of 1000 took 11.51s | Training: loss=0.0985, iou=0.8880, dice=0.9403
# Validation: loss=0.3408, iou=0.8424, dice=0.9144
# New best model found with validation loss 0.3408, saving model...
# Epoch 961 of 1000 took 11.53s | Training: loss=0.0898, iou=0.8954, dice=0.9446
# Epoch 962 of 1000 took 11.55s | Training: loss=0.0789, iou=0.9062, dice=0.9507
# Epoch 963 of 1000 took 11.53s | Training: loss=0.0868, iou=0.9003, dice=0.9474
# Epoch 964 of 1000 took 11.51s | Training: loss=0.0835, iou=0.8989, dice=0.9467
# Epoch 965 of 1000 took 11.51s | Training: loss=0.0933, iou=0.8990, dice=0.9467
# Epoch 966 of 1000 took 11.41s | Training: loss=0.0849, iou=0.9015, dice=0.9482
# Epoch 967 of 1000 took 11.40s | Training: loss=0.0879, iou=0.8978, dice=0.9461
# Epoch 968 of 1000 took 11.51s | Training: loss=0.0781, iou=0.9091, dice=0.9523
# Epoch 969 of 1000 took 11.54s | Training: loss=0.0785, iou=0.9088, dice=0.9522
# Epoch 970 of 1000 took 11.55s | Training: loss=0.0881, iou=0.9006, dice=0.9475
# Epoch 971 of 1000 took 11.48s | Training: loss=0.1621, iou=0.8415, dice=0.9096
# Epoch 972 of 1000 took 11.57s | Training: loss=0.0960, iou=0.8822, dice=0.9372
# Epoch 973 of 1000 took 11.57s | Training: loss=0.1187, iou=0.8673, dice=0.9282
# Epoch 974 of 1000 took 11.50s | Training: loss=0.1016, iou=0.8783, dice=0.9351
# Epoch 975 of 1000 took 11.42s | Training: loss=0.1095, iou=0.8678, dice=0.9287
# Epoch 976 of 1000 took 11.39s | Training: loss=0.1056, iou=0.8739, dice=0.9322
# Epoch 977 of 1000 took 11.55s | Training: loss=0.1021, iou=0.8798, dice=0.9360
# Epoch 978 of 1000 took 11.40s | Training: loss=0.0950, iou=0.8855, dice=0.9391
# Epoch 979 of 1000 took 11.52s | Training: loss=0.1154, iou=0.8726, dice=0.9317
# Epoch 980 of 1000 took 11.46s | Training: loss=0.1160, iou=0.8506, dice=0.9188
# Validation: loss=0.3414, iou=0.8300, dice=0.9069
# Epoch 981 of 1000 took 11.50s | Training: loss=0.1241, iou=0.8426, dice=0.9143
# Epoch 982 of 1000 took 11.49s | Training: loss=0.1213, iou=0.8491, dice=0.9181
# Epoch 983 of 1000 took 11.49s | Training: loss=0.1170, iou=0.8582, dice=0.9231
# Epoch 984 of 1000 took 11.48s | Training: loss=0.1096, iou=0.8637, dice=0.9268
# Epoch 985 of 1000 took 11.53s | Training: loss=0.1007, iou=0.8799, dice=0.9360
# Epoch 986 of 1000 took 11.49s | Training: loss=0.1020, iou=0.8738, dice=0.9325
# Epoch 987 of 1000 took 11.50s | Training: loss=0.0870, iou=0.8934, dice=0.9437
# Epoch 988 of 1000 took 11.41s | Training: loss=0.0960, iou=0.8833, dice=0.9379
# Epoch 989 of 1000 took 11.51s | Training: loss=0.1087, iou=0.8781, dice=0.9348
# Epoch 990 of 1000 took 11.42s | Training: loss=0.0997, iou=0.8802, dice=0.9362
# Epoch 991 of 1000 took 11.54s | Training: loss=0.0862, iou=0.8959, dice=0.9450
# Epoch 992 of 1000 took 11.53s | Training: loss=0.1065, iou=0.8757, dice=0.9336
# Epoch 993 of 1000 took 11.52s | Training: loss=0.1221, iou=0.8612, dice=0.9241
# Epoch 994 of 1000 took 11.51s | Training: loss=0.1493, iou=0.8295, dice=0.9044
# Epoch 995 of 1000 took 11.48s | Training: loss=0.1075, iou=0.8676, dice=0.9283
# Epoch 996 of 1000 took 11.47s | Training: loss=0.0889, iou=0.8896, dice=0.9414
# Epoch 997 of 1000 took 11.47s | Training: loss=0.0891, iou=0.8898, dice=0.9416
# Epoch 998 of 1000 took 11.50s | Training: loss=0.0871, iou=0.8936, dice=0.9437
# Epoch 999 of 1000 took 11.51s | Training: loss=0.0899, iou=0.8906, dice=0.9421
# Epoch 1000 of 1000 took 11.41s | Training: loss=0.0854, iou=0.8936, dice=0.9437
# Validation: loss=0.3177, iou=0.8570, dice=0.9230
# New best model found with validation loss 0.3177, saving model...

# %%
best_model, results_train, results_val = results_train

# %%
import pandas as pd
import seaborn as sns

# Create DataFrames for easier plotting with Seaborn
df_train_loss = pd.DataFrame({'Epoch': range(len(results_train['loss'])), 'Value': results_train['loss'], 'Metric': 'Loss', 'Type': 'Train'})
df_val_loss = pd.DataFrame({'Epoch': [validation_freq * (1 + x) for x in range(len(results_val['loss']))], 'Value': results_val['loss'], 'Metric': 'Loss', 'Type': 'Validation'})

df_train_dice = pd.DataFrame({'Epoch': range(len(results_train['dice'])), 'Value': results_train['dice'], 'Metric': 'Dice', 'Type': 'Train'})
df_val_dice = pd.DataFrame({'Epoch': [validation_freq * (1 + x) for x in range(len(results_val['dice']))], 'Value': results_val['dice'], 'Metric': 'Dice', 'Type': 'Validation'})

df_train_iou = pd.DataFrame({'Epoch': range(len(results_train['iou'])), 'Value': results_train['iou'], 'Metric': 'IoU', 'Type': 'Train'})
df_val_iou = pd.DataFrame({'Epoch': [validation_freq * (1 + x) for x in range(len(results_val['iou']))], 'Value': results_val['iou'], 'Metric': 'IoU', 'Type': 'Validation'})

# Combine the DataFrames
df = pd.concat([df_train_loss, df_val_loss, df_train_dice, df_val_dice, df_train_iou, df_val_iou])

# Plot using Seaborn
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

sns.lineplot(data=df[df['Metric'] == 'Loss'], x='Epoch', y='Value', hue='Type', ax=axs[0])
axs[0].set_title('Training and Validation Loss')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')

sns.lineplot(data=df[df['Metric'] == 'Dice'], x='Epoch', y='Value', hue='Type', ax=axs[1])
axs[1].set_title('Training and Validation Dice')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Dice')

sns.lineplot(data=df[df['Metric'] == 'IoU'], x='Epoch', y='Value', hue='Type', ax=axs[2])
axs[2].set_title('Training and Validation IoU')
axs[2].set_xlabel('Epoch')
axs[2].set_ylabel('IoU')

plt.tight_layout()
plt.show()

# %%
torch.save(best_model.state_dict(), 'cuboid_unetr1000epochs.pth')
import joblib

joblib.dump(best_model, 'cuboid_unetr1000epochs.pkl')
# Out:
# ['cuboid_unetr1000epochs.pkl']

# %% [markdown]
# ## Evaluation of model

# %%
image, label = val_dataset[0]
image = image.unsqueeze(0)
image = image.to(device)
with torch.no_grad():
    pred_logits = patched_forward(best_model, image, patch_size, 'cuda')
pred = torch.sigmoid(pred_logits)
pred = pred.squeeze(0, 1)
image = image.squeeze(0, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select the 50th slice along the first axis
slice_index = 60

image_slice = image[slice_index].cpu().numpy()
pred_slice = pred[slice_index].cpu().numpy()
label_slice = label[slice_index].cpu().numpy()

# Create the figure and the axes with 3 subplots side by side
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot the original image slice
axs[0].imshow(image_slice, cmap='gray')
axs[0].set_title('Image Slice')
axs[0].axis('off')

# Plot the prediction slice
axs[1].imshow(pred_slice, vmin=0, vmax=1, cmap='Reds')
axs[1].set_title('Prediction Slice')
axs[1].axis('off')

# Plot the label slice
axs[2].imshow(label_slice, cmap='Greens')
axs[2].set_title('Label Slice')
axs[2].axis('off')

# Display the figure
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select the 50th slice along the first axis
slice_index = 60
image_slice = image[slice_index].cpu().numpy()
pred_slice = pred[slice_index].cpu().numpy()
label_slice = label[slice_index].cpu().numpy()

pred_slice = (pred_slice > 0.5).astype(np.float32)

# Normalize image slice for visualization (if needed)
image_slice = (image_slice - image_slice.min()) / (image_slice.max() - image_slice.min())

# Create an RGB image from the grayscale slice
image_rgb = np.stack([image_slice]*3, axis=-1)

# Create solid colors for the prediction and label overlays
red_overlay = np.zeros_like(image_rgb)
red_overlay[..., 0] = 1  # Red color for prediction

green_overlay = np.zeros_like(image_rgb)
green_overlay[..., 1] = 1  # Green color for label

# Create the prediction and label masks (expanding dims for compatibility)
pred_mask = np.expand_dims(pred_slice, axis=-1)
label_mask = np.expand_dims(label_slice, axis=-1)

# Set the opacity for the overlays (50% opacity)
opacity = 0.5

# Blend the solid color with the original image using the mask
# First, apply the red overlay for predictions
overlay_image = image_rgb * (1 - pred_mask * opacity) + red_overlay * pred_mask * opacity

# Then, apply the green overlay for labels
overlay_image = overlay_image * (1 - label_mask * opacity) + green_overlay * label_mask * opacity

# Plot the resulting image with the 50% opacity overlays
plt.figure(figsize=(10, 10))
plt.imshow(overlay_image)
plt.title('Image with 50% Opacity Prediction and Label Overlays')
plt.axis('off')
plt.show()
